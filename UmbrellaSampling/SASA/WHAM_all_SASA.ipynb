# %%
import pandas as pd
import numpy as np
import os
import plumed
import matplotlib.pyplot as plt

# %% [markdown]
# In order to perform WHAM, I'm going to need:
# - Files containing the timeseries data of my distance CV
# - A metadata file pointing to all of the timeseries data files
#
# I'm going to start with the first point here. I will need to restructure the format of the `COLVAR` files, and do some additional post-processing with `plumed driver` such that my COLVAR file has three columns:
# 1. Time
# 2. Distance (i.e. the instantenous CV value)
# 3. The total potential energy of the system in kJ/mol
#
# Let's break this down into a few subproblems:
# 1. I need a PLUMED script that generates these files for me.
# 2. I need to do some file I/O that calls `plumed driver` and post processess all trajectories it can find from the list of `distances`.
#
# Seems pretty simple. Let's get this working for two test distances first, and then we move on to the creation of the metadata file.

# %%
# Define the test_distances
distances = np.concatenate([np.arange(0.3,7.05,0.1).round(1),np.arange(0.61,0.77,0.05).round(2)])
extra = np.arange(0.61,0.77,0.05).round(2)
temps = [280, 300, 320]

# %%
# Define temps
temps = [280, 300, 320]

# Define distances
old_distances = np.arange(0.3,7.01,0.1).round(1) # First samplings
extra = np.arange(0.61,0.77,0.05).round(2) # Extra sampling in this region
new_distances = np.arange(0.35,7.05,0.1).round(2) # Even more sampling due to unexpected results
distances = np.concatenate([old_distances,extra,new_distances]) # concat everything
distances.sort()

# Store all sims in a nested dict. First dict is temps, second dict is distance: umbrella strength
sims = {temp : {dist: 150 for dist in distances} for temp in temps}
for temp in temps: 
    for x in extra: sims[temp][x] = 300 
    for x in new_distances: sims[temp][x] = 600 if x < 2.0 else 150

# %%
SKIP = 10000 # 10.000 x 0.002 ps = 20 ps or 2 ns
# Discarding the initial part of the trajectory 
for temp in temps:
    for dist in distances:
        if not os.path.exists(f'{temp}/{dist}/TIMESERIES'):
            continue
        # elif os.path.exists(f'{temp}/{dist}/TIMESERIES_TRIMMED'):
        #     continue
        print(f'Now trimming {temp}/{dist}...')
        os.system(f'tail {temp}/{dist}/TIMESERIES -n +{SKIP} >> {temp}/{dist}/TIMESERIES_TRIMMED')
# Out:
# Now trimming 280/0.3...
# Now trimming 280/0.4...
# Now trimming 280/0.5...
# Now trimming 280/0.6...
# Now trimming 280/0.7...
# Now trimming 280/0.8...
# Now trimming 280/0.9...
# Now trimming 280/1.0...
# Now trimming 280/1.1...
# Now trimming 280/1.2...
# Now trimming 280/1.3...
# Now trimming 280/1.4...
# Now trimming 280/1.5...
# Now trimming 280/1.6...
# Now trimming 280/1.7...
# Now trimming 280/1.8...
# Now trimming 280/1.9...
# Now trimming 280/2.0...
# Now trimming 280/2.1...
# Now trimming 280/2.2...
# Now trimming 280/2.3...
# Now trimming 280/2.4...
# Now trimming 280/2.5...
# Now trimming 280/2.6...
# Now trimming 280/2.7...
# Now trimming 280/2.8...
# Now trimming 280/2.9...
# Now trimming 280/3.0...
# Now trimming 280/3.1...
# Now trimming 280/3.2...
# Now trimming 280/3.3...
# Now trimming 280/3.4...
# Now trimming 280/3.5...
# Now trimming 280/3.6...
# Now trimming 280/3.7...
# Now trimming 280/3.8...
# Now trimming 300/0.76...
# Now trimming 320/0.3...
# Now trimming 320/0.4...
# Now trimming 320/0.5...
# Now trimming 320/0.6...
# Now trimming 320/0.7...
# Now trimming 320/0.8...
# Now trimming 320/0.9...
# Now trimming 320/1.0...
# Now trimming 320/1.1...
# Now trimming 320/1.2...
# Now trimming 320/1.3...
# Now trimming 320/1.4...
# Now trimming 320/1.5...
# Now trimming 320/1.6...
# Now trimming 320/1.7...
# Now trimming 320/1.8...
# Now trimming 320/1.9...
# Now trimming 320/2.0...
# Now trimming 320/2.1...
# Now trimming 320/2.2...
# Now trimming 320/2.3...
# Now trimming 320/2.4...
# Now trimming 320/2.5...
# Now trimming 320/2.6...
# Now trimming 320/2.7...
# Now trimming 320/2.8...
# Now trimming 320/2.9...
# Now trimming 320/3.0...
# Now trimming 320/3.1...
# Now trimming 320/3.2...
# Now trimming 320/3.3...
# Now trimming 320/3.4...
# Now trimming 320/3.5...
# Now trimming 320/3.6...
# Now trimming 320/3.7...
# Now trimming 320/3.8...
# Now trimming 320/3.9...
# Now trimming 320/4.0...
# Now trimming 320/4.1...
# Now trimming 320/4.2...
# Now trimming 320/4.3...
# Now trimming 320/4.4...
# Now trimming 320/4.5...
# Now trimming 320/4.6...
# Now trimming 320/4.7...
# Now trimming 320/4.8...
# Now trimming 320/4.9...
# Now trimming 320/5.0...
# Now trimming 320/5.1...
# Now trimming 320/5.2...
# Now trimming 320/5.3...
# Now trimming 320/5.4...
# Now trimming 320/5.5...
# Now trimming 320/5.6...
# Now trimming 320/5.7...
# Now trimming 320/5.8...
# Now trimming 320/5.9...
# Now trimming 320/6.0...
# Now trimming 320/6.1...
# Now trimming 320/6.2...
# Now trimming 320/6.3...
# Now trimming 320/6.4...
# Now trimming 320/6.5...
# Now trimming 320/6.6...
# Now trimming 320/6.7...
# Now trimming 320/6.8...
# Now trimming 320/6.9...
# Now trimming 320/7.0...
# Now trimming 320/0.61...
# Now trimming 320/0.66...
# Now trimming 320/0.71...
# Now trimming 320/0.76...

# %%
SKIP = 10000 # 10.000 x 0.002 ps = 20 ps or 2 ns

# Discarding the initial part of the trajectory 
for temp in sims.keys():
    for dist in sims[temp].keys():
        if not os.path.exists(f'{temp}/{dist}/TIMESERIES'):
            continue
        # elif os.path.exists(f'{temp}/{dist}/TIMESERIES_TRIMMED'):
        #     continue
        print(f'Now trimming {temp}/{dist}...')
        os.system(f'tail {temp}/{dist}/TIMESERIES -n +{SKIP} > {temp}/{dist}/TIMESERIES_TRIMMED')
# Out:
# Now trimming 280/0.3...
# Now trimming 280/0.35...
# Now trimming 280/0.4...
# Now trimming 280/0.45...
# Now trimming 280/0.5...
# Now trimming 280/0.55...
# Now trimming 280/0.6...
# Now trimming 280/0.61...
# Now trimming 280/0.65...
# Now trimming 280/0.66...
# Now trimming 280/0.7...
# Now trimming 280/0.71...
# Now trimming 280/0.75...
# Now trimming 280/0.76...
# Now trimming 280/0.8...
# Now trimming 280/0.85...
# Now trimming 280/0.9...
# Now trimming 320/3.15...
# Now trimming 320/3.2...
# Now trimming 320/3.25...
# Now trimming 320/3.3...
# Now trimming 320/3.35...
# Now trimming 320/3.4...
# Now trimming 320/3.45...
# Now trimming 320/3.5...
# Now trimming 320/3.55...
# Now trimming 320/3.6...
# Now trimming 320/3.65...
# Now trimming 320/3.7...
# Now trimming 320/3.75...
# Now trimming 320/3.8...
# Now trimming 320/3.85...
# Now trimming 320/3.9...
# Now trimming 320/3.95...
# Now trimming 320/4.0...
# Now trimming 320/4.05...
# Now trimming 320/4.1...
# Now trimming 320/4.15...
# Now trimming 320/4.2...
# Now trimming 320/4.25...
# Now trimming 320/4.3...
# Now trimming 320/4.35...
# Now trimming 320/4.4...
# Now trimming 320/4.45...
# Now trimming 320/4.5...
# Now trimming 320/4.55...
# Now trimming 320/4.6...
# Now trimming 320/4.65...
# Now trimming 320/4.7...
# Now trimming 320/4.75...
# Now trimming 320/4.8...
# Now trimming 320/4.85...
# Now trimming 320/4.9...
# Now trimming 320/4.95...
# Now trimming 320/5.0...
# Now trimming 320/5.05...
# Now trimming 320/5.1...
# Now trimming 320/5.15...
# Now trimming 320/5.2...
# Now trimming 320/5.25...
# Now trimming 320/5.3...
# Now trimming 320/5.35...
# Now trimming 320/5.4...
# Now trimming 320/5.45...
# Now trimming 320/5.5...
# Now trimming 320/5.55...
# Now trimming 320/5.6...
# Now trimming 320/5.65...
# Now trimming 320/5.7...
# Now trimming 320/5.75...
# Now trimming 320/5.8...
# Now trimming 320/5.85...
# Now trimming 320/5.9...
# Now trimming 320/5.95...
# Now trimming 320/6.0...
# Now trimming 320/6.05...
# Now trimming 320/6.1...
# Now trimming 320/6.15...
# Now trimming 320/6.2...
# Now trimming 320/6.25...
# Now trimming 320/6.3...
# Now trimming 320/6.35...
# Now trimming 320/6.4...
# Now trimming 320/6.45...
# Now trimming 320/6.5...
# Now trimming 320/6.55...
# Now trimming 320/6.6...
# Now trimming 320/6.65...
# Now trimming 320/6.7...
# Now trimming 320/6.75...
# Now trimming 320/6.8...
# Now trimming 320/6.85...
# Now trimming 320/6.9...
# Now trimming 320/6.95...
# Now trimming 320/7.0...

# %% [markdown]
# ## Part 2: Generating the metadata files

# %%
SPRING = 150
CORREL_TIME = 250 # 250 x 0.002 ps = 0.5 ps
max_dist = {280:0,
            300:0,
            320:0}

for temp in temps:
    with open(f'{temp}/metadata_{temp}.txt', 'w') as f:
        f.write('#/path/to/timeseries/file loc_win_min spring [correl time] [temperature]\n')
        
        for dist in distances:
            SPRING = 150
            if not os.path.exists(f'{temp}/{dist}/TIMESERIES_TRIMMED'):
                continue
            if dist in extra:
                SPRING = 300
            max_dist[temp] = max(max_dist[temp],dist)
            path = f'{temp}/{dist}/TIMESERIES_TRIMMED'
            line = ' '.join(map(str,[path, dist, SPRING, CORREL_TIME,'\n']))
            print(line)
            f.write(line)
# Out:
# 280/0.3/TIMESERIES_TRIMMED 0.3 150 250
#
# 280/0.4/TIMESERIES_TRIMMED 0.4 150 250
#
# 280/0.5/TIMESERIES_TRIMMED 0.5 150 250
#
# 280/0.6/TIMESERIES_TRIMMED 0.6 150 250
#
# 280/0.7/TIMESERIES_TRIMMED 0.7 150 250
#
# 280/0.8/TIMESERIES_TRIMMED 0.8 150 250
#
# 280/0.9/TIMESERIES_TRIMMED 0.9 150 250
#
# 280/1.0/TIMESERIES_TRIMMED 1.0 150 250
#
# 280/1.1/TIMESERIES_TRIMMED 1.1 150 250
#
# 280/1.2/TIMESERIES_TRIMMED 1.2 150 250
#
# 280/1.3/TIMESERIES_TRIMMED 1.3 150 250
#
# 280/1.4/TIMESERIES_TRIMMED 1.4 150 250
#
# 280/1.5/TIMESERIES_TRIMMED 1.5 150 250
#
# 280/1.6/TIMESERIES_TRIMMED 1.6 150 250
#
# 280/1.7/TIMESERIES_TRIMMED 1.7 150 250
#
# 280/1.8/TIMESERIES_TRIMMED 1.8 150 250
#
# 280/1.9/TIMESERIES_TRIMMED 1.9 150 250
#
# 280/2.0/TIMESERIES_TRIMMED 2.0 150 250
#
# 280/2.1/TIMESERIES_TRIMMED 2.1 150 250
#
# 280/2.2/TIMESERIES_TRIMMED 2.2 150 250
#
# 280/2.3/TIMESERIES_TRIMMED 2.3 150 250
#
# 280/2.4/TIMESERIES_TRIMMED 2.4 150 250
#
# 280/2.5/TIMESERIES_TRIMMED 2.5 150 250
#
# 280/2.6/TIMESERIES_TRIMMED 2.6 150 250
#
# 280/2.7/TIMESERIES_TRIMMED 2.7 150 250
#
# 280/2.8/TIMESERIES_TRIMMED 2.8 150 250
#
# 280/2.9/TIMESERIES_TRIMMED 2.9 150 250
#
# 280/3.0/TIMESERIES_TRIMMED 3.0 150 250
#
# 280/3.1/TIMESERIES_TRIMMED 3.1 150 250
#
# 280/3.2/TIMESERIES_TRIMMED 3.2 150 250
#
# 280/3.3/TIMESERIES_TRIMMED 3.3 150 250
#
# 280/3.4/TIMESERIES_TRIMMED 3.4 150 250
#
# 280/3.5/TIMESERIES_TRIMMED 3.5 150 250
#
# 280/3.6/TIMESERIES_TRIMMED 3.6 150 250
#
# 280/3.7/TIMESERIES_TRIMMED 3.7 150 250
#
# 280/3.8/TIMESERIES_TRIMMED 3.8 150 250
#
# 280/3.9/TIMESERIES_TRIMMED 3.9 150 250
#
# 280/4.0/TIMESERIES_TRIMMED 4.0 150 250
#
# 280/4.1/TIMESERIES_TRIMMED 4.1 150 250
#
# 280/4.2/TIMESERIES_TRIMMED 4.2 150 250
#
# 280/4.3/TIMESERIES_TRIMMED 4.3 150 250
#
# 280/4.4/TIMESERIES_TRIMMED 4.4 150 250
#
# 280/4.5/TIMESERIES_TRIMMED 4.5 150 250
#
# 280/4.6/TIMESERIES_TRIMMED 4.6 150 250
#
# 280/4.7/TIMESERIES_TRIMMED 4.7 150 250
#
# 280/4.8/TIMESERIES_TRIMMED 4.8 150 250
#
# 280/4.9/TIMESERIES_TRIMMED 4.9 150 250
#
# 280/5.0/TIMESERIES_TRIMMED 5.0 150 250
#
# 280/5.1/TIMESERIES_TRIMMED 5.1 150 250
#
# 280/5.2/TIMESERIES_TRIMMED 5.2 150 250
#
# 280/5.3/TIMESERIES_TRIMMED 5.3 150 250
#
# 280/5.4/TIMESERIES_TRIMMED 5.4 150 250
#
# 280/5.5/TIMESERIES_TRIMMED 5.5 150 250
#
# 280/5.6/TIMESERIES_TRIMMED 5.6 150 250
#
# 280/5.7/TIMESERIES_TRIMMED 5.7 150 250
#
# 280/5.8/TIMESERIES_TRIMMED 5.8 150 250
#
# 280/5.9/TIMESERIES_TRIMMED 5.9 150 250
#
# 280/6.0/TIMESERIES_TRIMMED 6.0 150 250
#
# 280/6.1/TIMESERIES_TRIMMED 6.1 150 250
#
# 280/6.2/TIMESERIES_TRIMMED 6.2 150 250
#
# 280/6.3/TIMESERIES_TRIMMED 6.3 150 250
#
# 280/6.4/TIMESERIES_TRIMMED 6.4 150 250
#
# 280/6.5/TIMESERIES_TRIMMED 6.5 150 250
#
# 280/6.6/TIMESERIES_TRIMMED 6.6 150 250
#
# 280/6.7/TIMESERIES_TRIMMED 6.7 150 250
#
# 280/6.8/TIMESERIES_TRIMMED 6.8 150 250
#
# 280/6.9/TIMESERIES_TRIMMED 6.9 150 250
#
# 280/7.0/TIMESERIES_TRIMMED 7.0 150 250
#
# 280/0.61/TIMESERIES_TRIMMED 0.61 300 250
#
# 280/0.66/TIMESERIES_TRIMMED 0.66 300 250
#
# 280/0.71/TIMESERIES_TRIMMED 0.71 300 250
#
# 280/0.76/TIMESERIES_TRIMMED 0.76 300 250
#
# 300/0.3/TIMESERIES_TRIMMED 0.3 150 250
#
# 300/0.4/TIMESERIES_TRIMMED 0.4 150 250
#
# 300/0.5/TIMESERIES_TRIMMED 0.5 150 250
#
# 300/0.6/TIMESERIES_TRIMMED 0.6 150 250
#
# 300/0.7/TIMESERIES_TRIMMED 0.7 150 250
#
# 300/0.8/TIMESERIES_TRIMMED 0.8 150 250
#
# 300/0.9/TIMESERIES_TRIMMED 0.9 150 250
#
# 300/1.0/TIMESERIES_TRIMMED 1.0 150 250
#
# 300/1.1/TIMESERIES_TRIMMED 1.1 150 250
#
# 300/1.2/TIMESERIES_TRIMMED 1.2 150 250
#
# 300/1.3/TIMESERIES_TRIMMED 1.3 150 250
#
# 300/1.4/TIMESERIES_TRIMMED 1.4 150 250
#
# 300/1.5/TIMESERIES_TRIMMED 1.5 150 250
#
# 300/1.6/TIMESERIES_TRIMMED 1.6 150 250
#
# 300/1.7/TIMESERIES_TRIMMED 1.7 150 250
#
# 300/1.8/TIMESERIES_TRIMMED 1.8 150 250
#
# 300/1.9/TIMESERIES_TRIMMED 1.9 150 250
#
# 300/2.0/TIMESERIES_TRIMMED 2.0 150 250
#
# 300/2.1/TIMESERIES_TRIMMED 2.1 150 250
#
# 300/2.2/TIMESERIES_TRIMMED 2.2 150 250
#
# 300/2.3/TIMESERIES_TRIMMED 2.3 150 250
#
# 300/2.4/TIMESERIES_TRIMMED 2.4 150 250
#
# 300/2.5/TIMESERIES_TRIMMED 2.5 150 250
#
# 300/2.6/TIMESERIES_TRIMMED 2.6 150 250
#
# 300/2.7/TIMESERIES_TRIMMED 2.7 150 250
#
# 300/2.8/TIMESERIES_TRIMMED 2.8 150 250
#
# 300/2.9/TIMESERIES_TRIMMED 2.9 150 250
#
# 300/3.0/TIMESERIES_TRIMMED 3.0 150 250
#
# 300/3.1/TIMESERIES_TRIMMED 3.1 150 250
#
# 300/3.2/TIMESERIES_TRIMMED 3.2 150 250
#
# 300/3.3/TIMESERIES_TRIMMED 3.3 150 250
#
# 300/3.4/TIMESERIES_TRIMMED 3.4 150 250
#
# 300/3.5/TIMESERIES_TRIMMED 3.5 150 250
#
# 300/3.6/TIMESERIES_TRIMMED 3.6 150 250
#
# 300/3.7/TIMESERIES_TRIMMED 3.7 150 250
#
# 300/3.8/TIMESERIES_TRIMMED 3.8 150 250
#
# 300/3.9/TIMESERIES_TRIMMED 3.9 150 250
#
# 300/4.0/TIMESERIES_TRIMMED 4.0 150 250
#
# 300/4.1/TIMESERIES_TRIMMED 4.1 150 250
#
# 300/4.2/TIMESERIES_TRIMMED 4.2 150 250
#
# 300/4.3/TIMESERIES_TRIMMED 4.3 150 250
#
# 300/4.4/TIMESERIES_TRIMMED 4.4 150 250
#
# 300/4.5/TIMESERIES_TRIMMED 4.5 150 250
#
# 300/4.6/TIMESERIES_TRIMMED 4.6 150 250
#
# 300/4.7/TIMESERIES_TRIMMED 4.7 150 250
#
# 300/4.8/TIMESERIES_TRIMMED 4.8 150 250
#
# 300/4.9/TIMESERIES_TRIMMED 4.9 150 250
#
# 300/5.0/TIMESERIES_TRIMMED 5.0 150 250
#
# 300/5.1/TIMESERIES_TRIMMED 5.1 150 250
#
# 300/5.2/TIMESERIES_TRIMMED 5.2 150 250
#
# 300/5.3/TIMESERIES_TRIMMED 5.3 150 250
#
# 300/5.4/TIMESERIES_TRIMMED 5.4 150 250
#
# 300/5.5/TIMESERIES_TRIMMED 5.5 150 250
#
# 300/5.6/TIMESERIES_TRIMMED 5.6 150 250
#
# 300/5.7/TIMESERIES_TRIMMED 5.7 150 250
#
# 300/5.8/TIMESERIES_TRIMMED 5.8 150 250
#
# 300/5.9/TIMESERIES_TRIMMED 5.9 150 250
#
# 300/6.0/TIMESERIES_TRIMMED 6.0 150 250
#
# 300/6.1/TIMESERIES_TRIMMED 6.1 150 250
#
# 300/6.2/TIMESERIES_TRIMMED 6.2 150 250
#
# 300/6.3/TIMESERIES_TRIMMED 6.3 150 250
#
# 300/6.4/TIMESERIES_TRIMMED 6.4 150 250
#
# 300/6.5/TIMESERIES_TRIMMED 6.5 150 250
#
# 300/6.6/TIMESERIES_TRIMMED 6.6 150 250
#
# 300/6.7/TIMESERIES_TRIMMED 6.7 150 250
#
# 300/6.8/TIMESERIES_TRIMMED 6.8 150 250
#
# 300/6.9/TIMESERIES_TRIMMED 6.9 150 250
#
# 300/7.0/TIMESERIES_TRIMMED 7.0 150 250
#
# 300/0.61/TIMESERIES_TRIMMED 0.61 300 250
#
# 300/0.66/TIMESERIES_TRIMMED 0.66 300 250
#
# 300/0.71/TIMESERIES_TRIMMED 0.71 300 250
#
# 300/0.76/TIMESERIES_TRIMMED 0.76 300 250
#
# 320/0.3/TIMESERIES_TRIMMED 0.3 150 250
#
# 320/0.4/TIMESERIES_TRIMMED 0.4 150 250
#
# 320/0.5/TIMESERIES_TRIMMED 0.5 150 250
#
# 320/0.6/TIMESERIES_TRIMMED 0.6 150 250
#
# 320/0.7/TIMESERIES_TRIMMED 0.7 150 250
#
# 320/0.8/TIMESERIES_TRIMMED 0.8 150 250
#
# 320/0.9/TIMESERIES_TRIMMED 0.9 150 250
#
# 320/1.0/TIMESERIES_TRIMMED 1.0 150 250
#
# 320/1.1/TIMESERIES_TRIMMED 1.1 150 250
#
# 320/1.2/TIMESERIES_TRIMMED 1.2 150 250
#
# 320/1.3/TIMESERIES_TRIMMED 1.3 150 250
#
# 320/1.4/TIMESERIES_TRIMMED 1.4 150 250
#
# 320/1.5/TIMESERIES_TRIMMED 1.5 150 250
#
# 320/1.6/TIMESERIES_TRIMMED 1.6 150 250
#
# 320/1.7/TIMESERIES_TRIMMED 1.7 150 250
#
# 320/1.8/TIMESERIES_TRIMMED 1.8 150 250
#
# 320/1.9/TIMESERIES_TRIMMED 1.9 150 250
#
# 320/2.0/TIMESERIES_TRIMMED 2.0 150 250
#
# 320/2.1/TIMESERIES_TRIMMED 2.1 150 250
#
# 320/2.2/TIMESERIES_TRIMMED 2.2 150 250
#
# 320/2.3/TIMESERIES_TRIMMED 2.3 150 250
#
# 320/2.4/TIMESERIES_TRIMMED 2.4 150 250
#
# 320/2.5/TIMESERIES_TRIMMED 2.5 150 250
#
# 320/2.6/TIMESERIES_TRIMMED 2.6 150 250
#
# 320/2.7/TIMESERIES_TRIMMED 2.7 150 250
#
# 320/2.8/TIMESERIES_TRIMMED 2.8 150 250
#
# 320/2.9/TIMESERIES_TRIMMED 2.9 150 250
#
# 320/3.0/TIMESERIES_TRIMMED 3.0 150 250
#
# 320/3.1/TIMESERIES_TRIMMED 3.1 150 250
#
# 320/3.2/TIMESERIES_TRIMMED 3.2 150 250
#
# 320/3.3/TIMESERIES_TRIMMED 3.3 150 250
#
# 320/3.4/TIMESERIES_TRIMMED 3.4 150 250
#
# 320/3.5/TIMESERIES_TRIMMED 3.5 150 250
#
# 320/3.6/TIMESERIES_TRIMMED 3.6 150 250
#
# 320/3.7/TIMESERIES_TRIMMED 3.7 150 250
#
# 320/3.8/TIMESERIES_TRIMMED 3.8 150 250
#
# 320/3.9/TIMESERIES_TRIMMED 3.9 150 250
#
# 320/4.0/TIMESERIES_TRIMMED 4.0 150 250
#
# 320/4.1/TIMESERIES_TRIMMED 4.1 150 250
#
# 320/4.2/TIMESERIES_TRIMMED 4.2 150 250
#
# 320/4.3/TIMESERIES_TRIMMED 4.3 150 250
#
# 320/4.4/TIMESERIES_TRIMMED 4.4 150 250
#
# 320/4.5/TIMESERIES_TRIMMED 4.5 150 250
#
# 320/4.6/TIMESERIES_TRIMMED 4.6 150 250
#
# 320/4.7/TIMESERIES_TRIMMED 4.7 150 250
#
# 320/4.8/TIMESERIES_TRIMMED 4.8 150 250
#
# 320/4.9/TIMESERIES_TRIMMED 4.9 150 250
#
# 320/5.0/TIMESERIES_TRIMMED 5.0 150 250
#
# 320/5.1/TIMESERIES_TRIMMED 5.1 150 250
#
# 320/5.2/TIMESERIES_TRIMMED 5.2 150 250
#
# 320/5.3/TIMESERIES_TRIMMED 5.3 150 250
#
# 320/5.4/TIMESERIES_TRIMMED 5.4 150 250
#
# 320/5.5/TIMESERIES_TRIMMED 5.5 150 250
#
# 320/5.6/TIMESERIES_TRIMMED 5.6 150 250
#
# 320/5.7/TIMESERIES_TRIMMED 5.7 150 250
#
# 320/5.8/TIMESERIES_TRIMMED 5.8 150 250
#
# 320/5.9/TIMESERIES_TRIMMED 5.9 150 250
#
# 320/6.0/TIMESERIES_TRIMMED 6.0 150 250
#
# 320/6.1/TIMESERIES_TRIMMED 6.1 150 250
#
# 320/6.2/TIMESERIES_TRIMMED 6.2 150 250
#
# 320/6.3/TIMESERIES_TRIMMED 6.3 150 250
#
# 320/6.4/TIMESERIES_TRIMMED 6.4 150 250
#
# 320/6.5/TIMESERIES_TRIMMED 6.5 150 250
#
# 320/6.6/TIMESERIES_TRIMMED 6.6 150 250
#
# 320/6.7/TIMESERIES_TRIMMED 6.7 150 250
#
# 320/6.8/TIMESERIES_TRIMMED 6.8 150 250
#
# 320/6.9/TIMESERIES_TRIMMED 6.9 150 250
#
# 320/7.0/TIMESERIES_TRIMMED 7.0 150 250
#
# 320/0.61/TIMESERIES_TRIMMED 0.61 300 250
#
# 320/0.66/TIMESERIES_TRIMMED 0.66 300 250
#
# 320/0.71/TIMESERIES_TRIMMED 0.71 300 250
#
# 320/0.76/TIMESERIES_TRIMMED 0.76 300 250

# %%
CORREL_TIME = 250 # 250 x 0.002 ps = 0.5 ps
max_dist = {280:0,
            300:0,
            320:0}

for temp in sims.keys():
    with open(f'{temp}/metadata_{temp}.txt', 'w') as f:
        # Generate header
        f.write('#/path/to/timeseries/file loc_win_min spring [correl time] [temperature]\n')
        
        for dist, spring in sims[temp].items():
            SPRING = 150
            
            # In case TRIMMED timeseries does not exist, skip
            if not os.path.exists(f'{temp}/{dist}/TIMESERIES_TRIMMED'):
                continue
            
            # Update max dist that we have in the metadata file
            max_dist[temp] = max(max_dist[temp],dist)
            
            # Write the line
            path = f'{temp}/{dist}/TIMESERIES_TRIMMED'
            line = ' '.join(map(str,[path, dist, spring, CORREL_TIME,'\n']))
            print(line)
            f.write(line)
# Out:
# 280/0.3/TIMESERIES_TRIMMED 0.3 150 250
#
# 280/0.35/TIMESERIES_TRIMMED 0.35 600 250
#
# 280/0.4/TIMESERIES_TRIMMED 0.4 150 250
#
# 280/0.45/TIMESERIES_TRIMMED 0.45 600 250
#
# 280/0.5/TIMESERIES_TRIMMED 0.5 150 250
#
# 280/0.55/TIMESERIES_TRIMMED 0.55 600 250
#
# 280/0.6/TIMESERIES_TRIMMED 0.6 150 250
#
# 280/0.61/TIMESERIES_TRIMMED 0.61 300 250
#
# 280/0.65/TIMESERIES_TRIMMED 0.65 600 250
#
# 280/0.66/TIMESERIES_TRIMMED 0.66 300 250
#
# 280/0.7/TIMESERIES_TRIMMED 0.7 150 250
#
# 280/0.71/TIMESERIES_TRIMMED 0.71 300 250
#
# 280/0.75/TIMESERIES_TRIMMED 0.75 600 250
#
# 280/0.76/TIMESERIES_TRIMMED 0.76 300 250
#
# 280/0.8/TIMESERIES_TRIMMED 0.8 150 250
#
# 280/0.85/TIMESERIES_TRIMMED 0.85 600 250
#
# 280/0.9/TIMESERIES_TRIMMED 0.9 150 250
#
# 280/0.95/TIMESERIES_TRIMMED 0.95 600 250
#
# 280/1.0/TIMESERIES_TRIMMED 1.0 150 250
#
# 280/1.05/TIMESERIES_TRIMMED 1.05 600 250
#
# 280/1.1/TIMESERIES_TRIMMED 1.1 150 250
#
# 280/1.15/TIMESERIES_TRIMMED 1.15 600 250
#
# 280/1.2/TIMESERIES_TRIMMED 1.2 150 250
#
# 280/1.25/TIMESERIES_TRIMMED 1.25 600 250
#
# 280/1.3/TIMESERIES_TRIMMED 1.3 150 250
#
# 280/1.35/TIMESERIES_TRIMMED 1.35 600 250
#
# 280/1.4/TIMESERIES_TRIMMED 1.4 150 250
#
# 280/1.45/TIMESERIES_TRIMMED 1.45 600 250
#
# 280/1.5/TIMESERIES_TRIMMED 1.5 150 250
#
# 280/1.55/TIMESERIES_TRIMMED 1.55 600 250
#
# 280/1.6/TIMESERIES_TRIMMED 1.6 150 250
#
# 280/1.65/TIMESERIES_TRIMMED 1.65 600 250
#
# 280/1.7/TIMESERIES_TRIMMED 1.7 150 250
#
# 280/1.75/TIMESERIES_TRIMMED 1.75 600 250
#
# 280/1.8/TIMESERIES_TRIMMED 1.8 150 250
#
# 280/1.85/TIMESERIES_TRIMMED 1.85 600 250
#
# 280/1.9/TIMESERIES_TRIMMED 1.9 150 250
#
# 280/1.95/TIMESERIES_TRIMMED 1.95 600 250
#
# 280/2.0/TIMESERIES_TRIMMED 2.0 150 250
#
# 280/2.05/TIMESERIES_TRIMMED 2.05 150 250
#
# 280/2.1/TIMESERIES_TRIMMED 2.1 150 250
#
# 280/2.15/TIMESERIES_TRIMMED 2.15 150 250
#
# 280/2.2/TIMESERIES_TRIMMED 2.2 150 250
#
# 280/2.25/TIMESERIES_TRIMMED 2.25 150 250
#
# 280/2.3/TIMESERIES_TRIMMED 2.3 150 250
#
# 280/2.35/TIMESERIES_TRIMMED 2.35 150 250
#
# 280/2.4/TIMESERIES_TRIMMED 2.4 150 250
#
# 280/2.45/TIMESERIES_TRIMMED 2.45 150 250
#
# 280/2.5/TIMESERIES_TRIMMED 2.5 150 250
#
# 280/2.55/TIMESERIES_TRIMMED 2.55 150 250
#
# 280/2.6/TIMESERIES_TRIMMED 2.6 150 250
#
# 280/2.65/TIMESERIES_TRIMMED 2.65 150 250
#
# 280/2.7/TIMESERIES_TRIMMED 2.7 150 250
#
# 280/2.75/TIMESERIES_TRIMMED 2.75 150 250
#
# 280/2.8/TIMESERIES_TRIMMED 2.8 150 250
#
# 280/2.85/TIMESERIES_TRIMMED 2.85 150 250
#
# 280/2.9/TIMESERIES_TRIMMED 2.9 150 250
#
# 280/2.95/TIMESERIES_TRIMMED 2.95 150 250
#
# 280/3.0/TIMESERIES_TRIMMED 3.0 150 250
#
# 280/3.05/TIMESERIES_TRIMMED 3.05 150 250
#
# 280/3.1/TIMESERIES_TRIMMED 3.1 150 250
#
# 280/3.15/TIMESERIES_TRIMMED 3.15 150 250
#
# 280/3.2/TIMESERIES_TRIMMED 3.2 150 250
#
# 280/3.25/TIMESERIES_TRIMMED 3.25 150 250
#
# 280/3.3/TIMESERIES_TRIMMED 3.3 150 250
#
# 280/3.35/TIMESERIES_TRIMMED 3.35 150 250
#
# 280/3.4/TIMESERIES_TRIMMED 3.4 150 250
#
# 280/3.45/TIMESERIES_TRIMMED 3.45 150 250
#
# 280/3.5/TIMESERIES_TRIMMED 3.5 150 250
#
# 280/3.55/TIMESERIES_TRIMMED 3.55 150 250
#
# 280/3.6/TIMESERIES_TRIMMED 3.6 150 250
#
# 280/3.65/TIMESERIES_TRIMMED 3.65 150 250
#
# 280/3.7/TIMESERIES_TRIMMED 3.7 150 250
#
# 280/3.75/TIMESERIES_TRIMMED 3.75 150 250
#
# 280/3.8/TIMESERIES_TRIMMED 3.8 150 250
#
# 280/3.85/TIMESERIES_TRIMMED 3.85 150 250
#
# 280/3.9/TIMESERIES_TRIMMED 3.9 150 250
#
# 280/3.95/TIMESERIES_TRIMMED 3.95 150 250
#
# 280/4.0/TIMESERIES_TRIMMED 4.0 150 250
#
# 280/4.05/TIMESERIES_TRIMMED 4.05 150 250
#
# 280/4.1/TIMESERIES_TRIMMED 4.1 150 250
#
# 280/4.15/TIMESERIES_TRIMMED 4.15 150 250
#
# 280/4.2/TIMESERIES_TRIMMED 4.2 150 250
#
# 280/4.25/TIMESERIES_TRIMMED 4.25 150 250
#
# 280/4.3/TIMESERIES_TRIMMED 4.3 150 250
#
# 280/4.35/TIMESERIES_TRIMMED 4.35 150 250
#
# 280/4.4/TIMESERIES_TRIMMED 4.4 150 250
#
# 280/4.45/TIMESERIES_TRIMMED 4.45 150 250
#
# 280/4.5/TIMESERIES_TRIMMED 4.5 150 250
#
# 280/4.55/TIMESERIES_TRIMMED 4.55 150 250
#
# 280/4.6/TIMESERIES_TRIMMED 4.6 150 250
#
# 280/4.65/TIMESERIES_TRIMMED 4.65 150 250
#
# 280/4.7/TIMESERIES_TRIMMED 4.7 150 250
#
# 300/0.3/TIMESERIES_TRIMMED 0.3 150 250
#
# 300/0.35/TIMESERIES_TRIMMED 0.35 600 250
#
# 300/0.4/TIMESERIES_TRIMMED 0.4 150 250
#
# 300/0.45/TIMESERIES_TRIMMED 0.45 600 250
#
# 300/0.5/TIMESERIES_TRIMMED 0.5 150 250
#
# 300/0.55/TIMESERIES_TRIMMED 0.55 600 250
#
# 300/0.6/TIMESERIES_TRIMMED 0.6 150 250
#
# 300/0.61/TIMESERIES_TRIMMED 0.61 300 250
#
# 300/0.65/TIMESERIES_TRIMMED 0.65 600 250
#
# 300/0.66/TIMESERIES_TRIMMED 0.66 300 250
#
# 300/0.7/TIMESERIES_TRIMMED 0.7 150 250
#
# 300/0.71/TIMESERIES_TRIMMED 0.71 300 250
#
# 300/0.75/TIMESERIES_TRIMMED 0.75 600 250
#
# 300/0.76/TIMESERIES_TRIMMED 0.76 300 250
#
# 300/0.8/TIMESERIES_TRIMMED 0.8 150 250
#
# 300/0.85/TIMESERIES_TRIMMED 0.85 600 250
#
# 300/0.9/TIMESERIES_TRIMMED 0.9 150 250
#
# 300/0.95/TIMESERIES_TRIMMED 0.95 600 250
#
# 300/1.0/TIMESERIES_TRIMMED 1.0 150 250
#
# 300/1.05/TIMESERIES_TRIMMED 1.05 600 250
#
# 300/1.1/TIMESERIES_TRIMMED 1.1 150 250
#
# 300/1.15/TIMESERIES_TRIMMED 1.15 600 250
#
# 300/1.2/TIMESERIES_TRIMMED 1.2 150 250
#
# 300/1.25/TIMESERIES_TRIMMED 1.25 600 250
#
# 300/1.3/TIMESERIES_TRIMMED 1.3 150 250
#
# 300/1.35/TIMESERIES_TRIMMED 1.35 600 250
#
# 300/1.4/TIMESERIES_TRIMMED 1.4 150 250
#
# 300/1.45/TIMESERIES_TRIMMED 1.45 600 250
#
# 300/1.5/TIMESERIES_TRIMMED 1.5 150 250
#
# 300/1.55/TIMESERIES_TRIMMED 1.55 600 250
#
# 300/1.6/TIMESERIES_TRIMMED 1.6 150 250
#
# 300/1.65/TIMESERIES_TRIMMED 1.65 600 250
#
# 300/1.7/TIMESERIES_TRIMMED 1.7 150 250
#
# 300/1.75/TIMESERIES_TRIMMED 1.75 600 250
#
# 300/1.8/TIMESERIES_TRIMMED 1.8 150 250
#
# 300/1.85/TIMESERIES_TRIMMED 1.85 600 250
#
# 300/1.9/TIMESERIES_TRIMMED 1.9 150 250
#
# 300/1.95/TIMESERIES_TRIMMED 1.95 600 250
#
# 300/2.0/TIMESERIES_TRIMMED 2.0 150 250
#
# 300/2.05/TIMESERIES_TRIMMED 2.05 150 250
#
# 300/2.1/TIMESERIES_TRIMMED 2.1 150 250
#
# 300/2.15/TIMESERIES_TRIMMED 2.15 150 250
#
# 300/2.2/TIMESERIES_TRIMMED 2.2 150 250
#
# 300/2.25/TIMESERIES_TRIMMED 2.25 150 250
#
# 300/2.3/TIMESERIES_TRIMMED 2.3 150 250
#
# 300/2.35/TIMESERIES_TRIMMED 2.35 150 250
#
# 300/2.4/TIMESERIES_TRIMMED 2.4 150 250
#
# 300/2.45/TIMESERIES_TRIMMED 2.45 150 250
#
# 300/2.5/TIMESERIES_TRIMMED 2.5 150 250
#
# 300/2.55/TIMESERIES_TRIMMED 2.55 150 250
#
# 300/2.6/TIMESERIES_TRIMMED 2.6 150 250
#
# 300/2.65/TIMESERIES_TRIMMED 2.65 150 250
#
# 300/2.7/TIMESERIES_TRIMMED 2.7 150 250
#
# 300/2.75/TIMESERIES_TRIMMED 2.75 150 250
#
# 300/2.8/TIMESERIES_TRIMMED 2.8 150 250
#
# 300/2.85/TIMESERIES_TRIMMED 2.85 150 250
#
# 300/2.9/TIMESERIES_TRIMMED 2.9 150 250
#
# 300/2.95/TIMESERIES_TRIMMED 2.95 150 250
#
# 300/3.0/TIMESERIES_TRIMMED 3.0 150 250
#
# 300/3.05/TIMESERIES_TRIMMED 3.05 150 250
#
# 300/3.1/TIMESERIES_TRIMMED 3.1 150 250
#
# 300/3.15/TIMESERIES_TRIMMED 3.15 150 250
#
# 300/3.2/TIMESERIES_TRIMMED 3.2 150 250
#
# 300/3.25/TIMESERIES_TRIMMED 3.25 150 250
#
# 300/3.3/TIMESERIES_TRIMMED 3.3 150 250
#
# 300/3.35/TIMESERIES_TRIMMED 3.35 150 250
#
# 300/3.4/TIMESERIES_TRIMMED 3.4 150 250
#
# 300/3.45/TIMESERIES_TRIMMED 3.45 150 250
#
# 300/3.5/TIMESERIES_TRIMMED 3.5 150 250
#
# 300/3.55/TIMESERIES_TRIMMED 3.55 150 250
#
# 300/3.6/TIMESERIES_TRIMMED 3.6 150 250
#
# 300/3.65/TIMESERIES_TRIMMED 3.65 150 250
#
# 300/3.7/TIMESERIES_TRIMMED 3.7 150 250
#
# 300/3.75/TIMESERIES_TRIMMED 3.75 150 250
#
# 300/3.8/TIMESERIES_TRIMMED 3.8 150 250
#
# 300/3.85/TIMESERIES_TRIMMED 3.85 150 250
#
# 300/3.9/TIMESERIES_TRIMMED 3.9 150 250
#
# 300/3.95/TIMESERIES_TRIMMED 3.95 150 250
#
# 300/4.0/TIMESERIES_TRIMMED 4.0 150 250
#
# 300/4.05/TIMESERIES_TRIMMED 4.05 150 250
#
# 300/4.1/TIMESERIES_TRIMMED 4.1 150 250
#
# 300/4.15/TIMESERIES_TRIMMED 4.15 150 250
#
# 300/4.2/TIMESERIES_TRIMMED 4.2 150 250
#
# 300/4.25/TIMESERIES_TRIMMED 4.25 150 250
#
# 300/4.3/TIMESERIES_TRIMMED 4.3 150 250
#
# 300/4.35/TIMESERIES_TRIMMED 4.35 150 250
#
# 300/4.4/TIMESERIES_TRIMMED 4.4 150 250
#
# 300/4.45/TIMESERIES_TRIMMED 4.45 150 250
#
# 300/4.5/TIMESERIES_TRIMMED 4.5 150 250
#
# 300/4.55/TIMESERIES_TRIMMED 4.55 150 250
#
# 300/4.6/TIMESERIES_TRIMMED 4.6 150 250
#
# 300/4.65/TIMESERIES_TRIMMED 4.65 150 250
#
# 300/4.7/TIMESERIES_TRIMMED 4.7 150 250
#
# 300/4.75/TIMESERIES_TRIMMED 4.75 150 250
#
# 300/4.8/TIMESERIES_TRIMMED 4.8 150 250
#
# 300/4.85/TIMESERIES_TRIMMED 4.85 150 250
#
# 300/4.9/TIMESERIES_TRIMMED 4.9 150 250
#
# 300/4.95/TIMESERIES_TRIMMED 4.95 150 250
#
# 300/5.0/TIMESERIES_TRIMMED 5.0 150 250
#
# 300/5.05/TIMESERIES_TRIMMED 5.05 150 250
#
# 300/5.1/TIMESERIES_TRIMMED 5.1 150 250
#
# 300/5.15/TIMESERIES_TRIMMED 5.15 150 250
#
# 300/5.2/TIMESERIES_TRIMMED 5.2 150 250
#
# 300/5.25/TIMESERIES_TRIMMED 5.25 150 250
#
# 300/5.3/TIMESERIES_TRIMMED 5.3 150 250
#
# 300/5.35/TIMESERIES_TRIMMED 5.35 150 250
#
# 300/5.4/TIMESERIES_TRIMMED 5.4 150 250
#
# 300/5.45/TIMESERIES_TRIMMED 5.45 150 250
#
# 300/5.5/TIMESERIES_TRIMMED 5.5 150 250
#
# 300/5.55/TIMESERIES_TRIMMED 5.55 150 250
#
# 300/5.6/TIMESERIES_TRIMMED 5.6 150 250
#
# 300/5.65/TIMESERIES_TRIMMED 5.65 150 250
#
# 300/5.7/TIMESERIES_TRIMMED 5.7 150 250
#
# 300/5.75/TIMESERIES_TRIMMED 5.75 150 250
#
# 300/5.8/TIMESERIES_TRIMMED 5.8 150 250
#
# 300/5.85/TIMESERIES_TRIMMED 5.85 150 250
#
# 300/5.9/TIMESERIES_TRIMMED 5.9 150 250
#
# 300/5.95/TIMESERIES_TRIMMED 5.95 150 250
#
# 300/6.0/TIMESERIES_TRIMMED 6.0 150 250
#
# 300/6.05/TIMESERIES_TRIMMED 6.05 150 250
#
# 300/6.1/TIMESERIES_TRIMMED 6.1 150 250
#
# 300/6.15/TIMESERIES_TRIMMED 6.15 150 250
#
# 300/6.2/TIMESERIES_TRIMMED 6.2 150 250
#
# 300/6.25/TIMESERIES_TRIMMED 6.25 150 250
#
# 300/6.3/TIMESERIES_TRIMMED 6.3 150 250
#
# 300/6.35/TIMESERIES_TRIMMED 6.35 150 250
#
# 300/6.4/TIMESERIES_TRIMMED 6.4 150 250
#
# 300/6.45/TIMESERIES_TRIMMED 6.45 150 250
#
# 300/6.5/TIMESERIES_TRIMMED 6.5 150 250
#
# 300/6.55/TIMESERIES_TRIMMED 6.55 150 250
#
# 300/6.6/TIMESERIES_TRIMMED 6.6 150 250
#
# 300/6.65/TIMESERIES_TRIMMED 6.65 150 250
#
# 300/6.7/TIMESERIES_TRIMMED 6.7 150 250
#
# 300/6.75/TIMESERIES_TRIMMED 6.75 150 250
#
# 300/6.8/TIMESERIES_TRIMMED 6.8 150 250
#
# 300/6.85/TIMESERIES_TRIMMED 6.85 150 250
#
# 300/6.9/TIMESERIES_TRIMMED 6.9 150 250
#
# 300/6.95/TIMESERIES_TRIMMED 6.95 150 250
#
# 300/7.0/TIMESERIES_TRIMMED 7.0 150 250
#
# 320/0.3/TIMESERIES_TRIMMED 0.3 150 250
#
# 320/0.35/TIMESERIES_TRIMMED 0.35 600 250
#
# 320/0.4/TIMESERIES_TRIMMED 0.4 150 250
#
# 320/0.45/TIMESERIES_TRIMMED 0.45 600 250
#
# 320/0.5/TIMESERIES_TRIMMED 0.5 150 250
#
# 320/0.55/TIMESERIES_TRIMMED 0.55 600 250
#
# 320/0.6/TIMESERIES_TRIMMED 0.6 150 250
#
# 320/0.61/TIMESERIES_TRIMMED 0.61 300 250
#
# 320/0.65/TIMESERIES_TRIMMED 0.65 600 250
#
# 320/0.66/TIMESERIES_TRIMMED 0.66 300 250
#
# 320/0.7/TIMESERIES_TRIMMED 0.7 150 250
#
# 320/0.71/TIMESERIES_TRIMMED 0.71 300 250
#
# 320/0.75/TIMESERIES_TRIMMED 0.75 600 250
#
# 320/0.76/TIMESERIES_TRIMMED 0.76 300 250
#
# 320/0.8/TIMESERIES_TRIMMED 0.8 150 250
#
# 320/0.85/TIMESERIES_TRIMMED 0.85 600 250
#
# 320/0.9/TIMESERIES_TRIMMED 0.9 150 250
#
# 320/0.95/TIMESERIES_TRIMMED 0.95 600 250
#
# 320/1.0/TIMESERIES_TRIMMED 1.0 150 250
#
# 320/1.05/TIMESERIES_TRIMMED 1.05 600 250
#
# 320/1.1/TIMESERIES_TRIMMED 1.1 150 250
#
# 320/1.15/TIMESERIES_TRIMMED 1.15 600 250
#
# 320/1.2/TIMESERIES_TRIMMED 1.2 150 250
#
# 320/1.25/TIMESERIES_TRIMMED 1.25 600 250
#
# 320/1.3/TIMESERIES_TRIMMED 1.3 150 250
#
# 320/1.35/TIMESERIES_TRIMMED 1.35 600 250
#
# 320/1.4/TIMESERIES_TRIMMED 1.4 150 250
#
# 320/1.45/TIMESERIES_TRIMMED 1.45 600 250
#
# 320/1.5/TIMESERIES_TRIMMED 1.5 150 250
#
# 320/1.55/TIMESERIES_TRIMMED 1.55 600 250
#
# 320/1.6/TIMESERIES_TRIMMED 1.6 150 250
#
# 320/1.65/TIMESERIES_TRIMMED 1.65 600 250
#
# 320/1.7/TIMESERIES_TRIMMED 1.7 150 250
#
# 320/1.75/TIMESERIES_TRIMMED 1.75 600 250
#
# 320/1.8/TIMESERIES_TRIMMED 1.8 150 250
#
# 320/1.85/TIMESERIES_TRIMMED 1.85 600 250
#
# 320/1.9/TIMESERIES_TRIMMED 1.9 150 250
#
# 320/1.95/TIMESERIES_TRIMMED 1.95 600 250
#
# 320/2.0/TIMESERIES_TRIMMED 2.0 150 250
#
# 320/2.05/TIMESERIES_TRIMMED 2.05 150 250
#
# 320/2.1/TIMESERIES_TRIMMED 2.1 150 250
#
# 320/2.15/TIMESERIES_TRIMMED 2.15 150 250
#
# 320/2.2/TIMESERIES_TRIMMED 2.2 150 250
#
# 320/2.25/TIMESERIES_TRIMMED 2.25 150 250
#
# 320/2.3/TIMESERIES_TRIMMED 2.3 150 250
#
# 320/2.35/TIMESERIES_TRIMMED 2.35 150 250
#
# 320/2.4/TIMESERIES_TRIMMED 2.4 150 250
#
# 320/2.45/TIMESERIES_TRIMMED 2.45 150 250
#
# 320/2.5/TIMESERIES_TRIMMED 2.5 150 250
#
# 320/2.55/TIMESERIES_TRIMMED 2.55 150 250
#
# 320/2.6/TIMESERIES_TRIMMED 2.6 150 250
#
# 320/2.65/TIMESERIES_TRIMMED 2.65 150 250
#
# 320/2.7/TIMESERIES_TRIMMED 2.7 150 250
#
# 320/2.75/TIMESERIES_TRIMMED 2.75 150 250
#
# 320/2.8/TIMESERIES_TRIMMED 2.8 150 250
#
# 320/2.85/TIMESERIES_TRIMMED 2.85 150 250
#
# 320/2.9/TIMESERIES_TRIMMED 2.9 150 250
#
# 320/2.95/TIMESERIES_TRIMMED 2.95 150 250
#
# 320/3.0/TIMESERIES_TRIMMED 3.0 150 250
#
# 320/3.05/TIMESERIES_TRIMMED 3.05 150 250
#
# 320/3.1/TIMESERIES_TRIMMED 3.1 150 250
#
# 320/3.15/TIMESERIES_TRIMMED 3.15 150 250
#
# 320/3.2/TIMESERIES_TRIMMED 3.2 150 250
#
# 320/3.25/TIMESERIES_TRIMMED 3.25 150 250
#
# 320/3.3/TIMESERIES_TRIMMED 3.3 150 250
#
# 320/3.35/TIMESERIES_TRIMMED 3.35 150 250
#
# 320/3.4/TIMESERIES_TRIMMED 3.4 150 250
#
# 320/3.45/TIMESERIES_TRIMMED 3.45 150 250
#
# 320/3.5/TIMESERIES_TRIMMED 3.5 150 250
#
# 320/3.55/TIMESERIES_TRIMMED 3.55 150 250
#
# 320/3.6/TIMESERIES_TRIMMED 3.6 150 250
#
# 320/3.65/TIMESERIES_TRIMMED 3.65 150 250
#
# 320/3.7/TIMESERIES_TRIMMED 3.7 150 250
#
# 320/3.75/TIMESERIES_TRIMMED 3.75 150 250
#
# 320/3.8/TIMESERIES_TRIMMED 3.8 150 250
#
# 320/3.85/TIMESERIES_TRIMMED 3.85 150 250
#
# 320/3.9/TIMESERIES_TRIMMED 3.9 150 250
#
# 320/3.95/TIMESERIES_TRIMMED 3.95 150 250
#
# 320/4.0/TIMESERIES_TRIMMED 4.0 150 250
#
# 320/4.05/TIMESERIES_TRIMMED 4.05 150 250
#
# 320/4.1/TIMESERIES_TRIMMED 4.1 150 250
#
# 320/4.15/TIMESERIES_TRIMMED 4.15 150 250
#
# 320/4.2/TIMESERIES_TRIMMED 4.2 150 250
#
# 320/4.25/TIMESERIES_TRIMMED 4.25 150 250
#
# 320/4.3/TIMESERIES_TRIMMED 4.3 150 250
#
# 320/4.35/TIMESERIES_TRIMMED 4.35 150 250
#
# 320/4.4/TIMESERIES_TRIMMED 4.4 150 250
#
# 320/4.45/TIMESERIES_TRIMMED 4.45 150 250
#
# 320/4.5/TIMESERIES_TRIMMED 4.5 150 250
#
# 320/4.55/TIMESERIES_TRIMMED 4.55 150 250
#
# 320/4.6/TIMESERIES_TRIMMED 4.6 150 250
#
# 320/4.65/TIMESERIES_TRIMMED 4.65 150 250
#
# 320/4.7/TIMESERIES_TRIMMED 4.7 150 250
#
# 320/4.75/TIMESERIES_TRIMMED 4.75 150 250
#
# 320/4.8/TIMESERIES_TRIMMED 4.8 150 250
#
# 320/4.85/TIMESERIES_TRIMMED 4.85 150 250
#
# 320/4.9/TIMESERIES_TRIMMED 4.9 150 250
#
# 320/4.95/TIMESERIES_TRIMMED 4.95 150 250
#
# 320/5.0/TIMESERIES_TRIMMED 5.0 150 250
#
# 320/5.05/TIMESERIES_TRIMMED 5.05 150 250
#
# 320/5.1/TIMESERIES_TRIMMED 5.1 150 250
#
# 320/5.15/TIMESERIES_TRIMMED 5.15 150 250
#
# 320/5.2/TIMESERIES_TRIMMED 5.2 150 250
#
# 320/5.25/TIMESERIES_TRIMMED 5.25 150 250
#
# 320/5.3/TIMESERIES_TRIMMED 5.3 150 250
#
# 320/5.35/TIMESERIES_TRIMMED 5.35 150 250
#
# 320/5.4/TIMESERIES_TRIMMED 5.4 150 250
#
# 320/5.45/TIMESERIES_TRIMMED 5.45 150 250
#
# 320/5.5/TIMESERIES_TRIMMED 5.5 150 250
#
# 320/5.55/TIMESERIES_TRIMMED 5.55 150 250
#
# 320/5.6/TIMESERIES_TRIMMED 5.6 150 250
#
# 320/5.65/TIMESERIES_TRIMMED 5.65 150 250
#
# 320/5.7/TIMESERIES_TRIMMED 5.7 150 250
#
# 320/5.75/TIMESERIES_TRIMMED 5.75 150 250
#
# 320/5.8/TIMESERIES_TRIMMED 5.8 150 250
#
# 320/5.85/TIMESERIES_TRIMMED 5.85 150 250
#
# 320/5.9/TIMESERIES_TRIMMED 5.9 150 250
#
# 320/5.95/TIMESERIES_TRIMMED 5.95 150 250
#
# 320/6.0/TIMESERIES_TRIMMED 6.0 150 250
#
# 320/6.05/TIMESERIES_TRIMMED 6.05 150 250
#
# 320/6.1/TIMESERIES_TRIMMED 6.1 150 250
#
# 320/6.15/TIMESERIES_TRIMMED 6.15 150 250
#
# 320/6.2/TIMESERIES_TRIMMED 6.2 150 250
#
# 320/6.25/TIMESERIES_TRIMMED 6.25 150 250
#
# 320/6.3/TIMESERIES_TRIMMED 6.3 150 250
#
# 320/6.35/TIMESERIES_TRIMMED 6.35 150 250
#
# 320/6.4/TIMESERIES_TRIMMED 6.4 150 250
#
# 320/6.45/TIMESERIES_TRIMMED 6.45 150 250
#
# 320/6.5/TIMESERIES_TRIMMED 6.5 150 250
#
# 320/6.55/TIMESERIES_TRIMMED 6.55 150 250
#
# 320/6.6/TIMESERIES_TRIMMED 6.6 150 250
#
# 320/6.65/TIMESERIES_TRIMMED 6.65 150 250
#
# 320/6.7/TIMESERIES_TRIMMED 6.7 150 250
#
# 320/6.75/TIMESERIES_TRIMMED 6.75 150 250
#
# 320/6.8/TIMESERIES_TRIMMED 6.8 150 250
#
# 320/6.85/TIMESERIES_TRIMMED 6.85 150 250
#
# 320/6.9/TIMESERIES_TRIMMED 6.9 150 250
#
# 320/6.95/TIMESERIES_TRIMMED 6.95 150 250
#
# 320/7.0/TIMESERIES_TRIMMED 7.0 150 250

# %% [markdown]
# ## Part 3: Running WHAM

# %%
for temp in temps:
    # if os.path.exists(f'free_{temp}.txt'):
    #     continue
    if not os.path.exists(f'{temp}/metadata_{temp}.txt'):
        continue
    print(f'~/wham/wham/wham 0.3 {max_dist[temp]} 150 0.00001 {temp} 0 {temp}/metadata_{temp}.txt free_{temp}_new.txt 100 0')
    # os.system(f'~/wham/wham/wham 0.3 {max_dist[temp]} 150 0.1 {temp} 0 {temp}/metadata_{temp}.txt free_{temp}_new.txt 100 0')
# Out:
# ~/wham/wham/wham 0.3 7.0 150 0.00001 280 0 280/metadata_280.txt free_280_new.txt 100 0
# ~/wham/wham/wham 0.3 7.0 150 0.00001 300 0 300/metadata_300.txt free_300_new.txt 100 0
# ~/wham/wham/wham 0.3 7.0 150 0.00001 320 0 320/metadata_320.txt free_320_new.txt 100 0

# %% [markdown]
# ## Part 4: Visualizing the free energy

# %%
for temp in temps:
    if not os.path.exists(f'free_{temp}_new.txt'):
        continue
    fes = pd.read_csv(f'free_{temp}_new.txt', sep='\t', comment='#', names=['dist','free','error','prob','proberror'])
    fes2= pd.read_csv(f'free_{temp}.txt', sep='\t', comment='#', names=['dist','free','error','prob','proberror'])
    plt.plot(fes['dist'], fes['free'], label=f'{temp}K')
    plt.plot(fes2['dist'], fes2['free'], label=f'{temp}K old')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
import plumed
# for temp in temps:
temp = 300
total = np.array([])

for dist in distances:
    t = plumed.read_as_pandas(f'{temp}/{dist}/COLVAR')
    total = np.concatenate([total,t['dist'].values])

plt.hist(total,bins=300)
# Out:
# /scistor/informatica/age206/.conda/envs/AnalysisTools/lib/python3.7/site-packages/ipykernel_launcher.py:8: UserWarning: cannot load PLUMED instance, conversions will not be available
#
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_2325821/2063450443.py in <module>
#       6
#       7 for dist in distances:
# ----> 8     t = plumed.read_as_pandas(f'{temp}/{dist}/COLVAR')
#       9     total = np.concatenate([total,t['dist'].values])
#      10
#
# plumed.pyx in plumed.read_as_pandas()
#
# plumed.pyx in plumed._fix_file()
#
# FileNotFoundError: [Errno 2] No such file or directory: '300/0.5/COLVAR'

# %%
import matplotlib.pyplot as plt
import plumed
# for temp in temps:
temp = 280
total = np.array([])

for dist in distances:
    t = plumed.read_as_pandas(f'{temp}/{dist}/COLVAR')
    total = np.concatenate([total,t['dist'].values])

plt.hist(total,bins=150)

# %%
import matplotlib.pyplot as plt

# for temp in temps:
temp = 320
total = np.array([])

for dist in distances:
    t = plumed.read_as_pandas(f'{temp}/{dist}/COLVAR')
    total = np.concatenate([total,t['dist'].values])

plt.hist(total,bins=150)

# %%
BINS=150

for temp in sims.keys():    
    if not os.path.exists(f'free_{temp}.txt'):
        continue
    
    total = np.array([])
    umb = np.array([])
    
    for dist in sims[temp].keys():
        if not os.path.exists(f'{temp}/{dist}/COLVAR'):
            print(f'skipping {temp}/{dist}/COLVAR')
            continue
        
        t = plumed.read_as_pandas(f'{temp}/{dist}/COLVAR')
        total = np.concatenate([total,t['dist'].values])
        umb = np.concatenate([umb,t['umbrella.bias']])
    
    fes = pd.read_csv(f'free_{temp}_new.txt', sep='\t', comment='#', names=['dist','free','error','prob','proberror'])
    
    # Initialize plot
    fig=plt.figure(dpi=450)
    ax=fig.add_subplot(111, label="1")
    ax2=fig.add_subplot(111, label="2", frame_on=False)
    
    # Histogram
    ax.hist(total,bins=BINS, alpha=0.8, color='red', label='Counts')
    ax.yaxis.tick_right()
    ax.set_ylabel('Counts per 0.2 ps')
    ax.set_xlabel('COM separation (nm)')
    ax.yaxis.set_label_position('right')
    ax.set_xticks(np.arange(0,max_dist[temp],0.5))
    ax.set_xlim([0,max_dist[temp]])


    ax2.plot(fes['dist'],fes['free'], label='Free energy')
    ax2.set_ylabel('FE (kJ/mol)')
    ax2.set_xticks([])
    ax2.set_xlim([0,max_dist[temp]])

                              
#     ax3.scatter(total[::2],[22 for t in total[::2]],alpha=0.3, s=0.5,c=umb[::2],cmap='gray')
#     ax3.set_xticks(np.arange(0.3,1.2,0.1))
#     ax3.set_xlim([0.3,1.2])
#     ax3.set_ylim([0, 25])
#     ax3.set_yticks([])
    
#     ax3.scatter(total[1::2],[24 for t in total[1::2]],alpha=0.3, s=0.5,c=umb[1::2])
#     ax3.set_xticks(np.arange(0.3,1.2,0.1))
#     ax3.set_xlim([0.3,1.2])
#     ax3.set_ylim([0, 25])
#     ax3.set_yticks([])
    
    # Set vertical lines for umbreall Windows
    for dist in sims[temp].keys():
        ax.axvline(x=dist, color='gray', linestyle='--', linewidth=0.8, alpha=0.8)
    # ax.axvline(x=7.1, color='gray', linestyle='--', linewidth=0.8, alpha=0.3, label='Umbrella windows')

    plt.title(f'Free energy surface with histograms\n{temp}K, {BINS} bins, SASA')
    plt.legend()
    plt.show()
# Out:
# +++ Loading the PLUMED kernel runtime +++
# /scistor/informatica/age206/.conda/envs/AnalysisTools/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: cannot load PLUMED instance, conversions will not be available
#   from ipykernel import kernelapp as app
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# /scistor/informatica/age206/.conda/envs/AnalysisTools/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: cannot load PLUMED instance, conversions will not be available
#   from ipykernel import kernelapp as app
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# /scistor/informatica/age206/.conda/envs/AnalysisTools/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: cannot load PLUMED instance, conversions will not be available
#   from ipykernel import kernelapp as app
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/scistor/informatica/age206/plumed/lib/libplumedKernel.so" +++

# %%
cols = ['blue','orange','red']

plt.figure(dpi=300)
for i, temp in enumerate(temps):
    fes = pd.read_csv(f'free_{temp}_new.txt', sep='\t', comment='#', names=['dist','free','error','prob','proberror'])
    plt.plot(fes['dist'],fes['free'], label=f'{temp} K', color=cols[i], alpha=0.75)
plt.legend()
plt.title('Relative FE vs COM Separation\n SASA model')
plt.ylabel('Relative FE (kJ/mol')
plt.ylim([-3,40])
plt.xlabel('COM separation (nm)')
plt.savefig('FES_all_SASA.png')
