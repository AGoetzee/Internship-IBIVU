# %%
import os
import parmed as pmd
from Bio.PDB import *
import pdb4amber
import numpy as np
import subprocess
basepath = os.getcwd()
print(os.getcwd())
# Out:
# /scistor/informatica/age206/simlab/US-final/noSASA

# %%
def reload_struct(path):
    parser = PDBParser()
    return parser.get_structure('halfpdb', path)

def move_chain(d, chain):
    for res in chain:
        for atom in res:
            newcoord = atom.get_coord()
            newcoord[2] = newcoord[2] + d
            atom.set_coord(newcoord)
    return

def save_struct(name):
    if not name.endswith('.pdb'):
        name += '.pdb'
    io = PDBIO()
    io.set_structure(structure)
    io.save(name)
    return

def generate_rst7(tleap_string, dist):
    with open(f'{dist}/resource/tleap_script.in','w') as f:
        f.write(tleap_string.format(dist))
    subprocess.run(['/cm/shared/package/amber/20_v2/bin/tleap', '-f', f'{dist}/resource/tleap_script.in'])
    return
                   
def write_plumed_file(plumed_string, dist, kappa=150):
    with open(f'{dist}/prod/umb-{dist}.dat', 'w') as f:
        f.write(plumed_string.format(dist, kappa))
    return

def create_folders(dist):
    os.mkdir(str(dist))
    os.mkdir((str(dist) + '/prod'))
    os.mkdir((str(dist) + '/heat'))
    os.mkdir((str(dist) + '/EM'))
    os.mkdir((str(dist) + '/resource'))  
    return

def create_EM_param(em_string, dist):
    with open(f'{dist}/EM/EM.in','w') as f:
        f.write(em_string)
    return

def create_heat_param(heat_string, dist, temp=300.0):
    with open(f'{dist}/heat/heat.in','w') as f:
        f.write(heat_string.format(temp))
    return

def create_prod_param(prod_string, dist, temp=300.0):
    with open(f'{dist}/prod/prod.in','w') as f:
        f.write(prod_string.format(temp, dist))
    return

def convert_pdb(pdb_file, outfile):
    pdb4amber.run(arg_pdbin=pdb_file, arg_pdbout=outfile)
    return

# %%
EM_STRING = """IW Minimization
 &cntrl
   imin=1,       ! Run minimization
   ntx=1,        ! Read only coordinates, no velocities
   irest=0,      ! Do not restart
   maxcyc=10000, ! Max 10000 cycles
   ncyc=2000,    ! Steepest descent first 2000 cycles
   ntpr=1000,    ! Update mdout every 1000 cycles
   ntwx=0,       ! No trajectories
   igb=5,        ! GB model
   gbsa=3,       ! SASA is calculated using GPU
   cut=1000,     ! Necesarry for GPU
   saltcon=0.1,  ! salt conc. in M
 /
 """

HEAT_STRING = """IW Heating
 &cntrl
  imin=0,         ! This is an actual MD run
  ntx=1,          ! Read only coordinates, no velocities.
  irest=0,        ! Do not restart.
  nstlim=10000,   ! Number of MD steps (10000*0.002 = 20 ps)
  dt=0.002,       ! Time length of each MD step in ps.
  ntf=2,          ! Do not calculate force for SHAKE constrained bonds
  ntc=2,          ! Allow SHAKE to contrain all bonds
  tempi=0.0,      ! Initial temperature
  temp0={0},    ! Target temperature
  ntpr=100,       ! Print mdout info every 100 cycles.
  ntwx=1000,      ! Write trajectory info every 10000 steps.
  ntb=0           ! No periodic boundary condition
  ntt=3,          ! Langeving thermostat
  gamma_ln=2.0,   ! Colission frequency for langevin
  nmropt=1,       ! NMR restraints
  ig=-1,          ! Randomize the seed
  igb=5,
  gbsa=3,
  saltcon=0.1,
  cut=1000
 /  
&wt type='TEMP0', istep1=0, istep2=9000, value1=0.0, value2={0} /  
&wt type='TEMP0', istep1=9001, istep2=10000, value1={0}, value2={0} /  
&wt type='END' /
"""  

PROD_STRING = """Window run
 &cntrl
  imin=0,  
  ntx=5,  
  irest=1,  
  nstlim=12500000,  ! 25 ns
  dt=0.002,  
  ntf=2,  
  ntc=2,  
  temp0={0},  
  ntpr=2000,  ! Save info every 4 ps
  ntwx=2000,  ! Save traj every 4 ps
  ntb=0,
  ntp=0,    
  ntt=3,  
  barostat=1,  
  gamma_ln=1.0,  
  ig=-1,
  igb=5,
  gbsa=3,
  saltcon=0.1,
  cut=1000,
  plumed=1,
  plumedfile='{1}/prod/umb-{1}.dat'
 /
 """

PLUMED_STRING = """INCLUDE FILE=src/plumed.dat
umbrella: RESTRAINT ARG=dist AT={0} KAPPA={1}

PRINT ARG=* STRIDE=100 FILE={0}/COLVAR
PRINT ARG=dist,energy STRIDE=1 FILE={0}/TIMESERIES"""

TLEAP_STRING = """source leaprc.protein.ff19SB
struct = loadPDB {0}/resource/{0}_cleaned.pdb
setbox struct vdw
saveamberparm struct {0}/resource/{0}_top.parm7 {0}/resource/{0}_start.rst7
quit"""

# %%
# Define temps
temps = [280, 300, 320]

# Define distances
old_distances = np.arange(0.3,7.01,0.1).round(1) # First samplings
extra = np.arange(0.61,0.77,0.05).round(2) # Extra sampling in this region
new_distances = np.arange(0.35,7.05,0.1).round(2) # Even more sampling due to unexpected results
distances = np.concatenate([old_distances,extra,new_distances]) # concat everything
distances.sort()

# Store all sims in a nested dict. First dict is temps, second dict is distance: umbrella strength
sims = {temp : {dist: 150 for dist in distances} for temp in temps}
for temp in temps: 
    for x in extra: sims[temp][x] = 300 
    for x in new_distances: sims[temp][x] = 600 if x < 2.0 else 150
# Out:
# {280: {0.3: 150,
#   0.35: 600,
#   0.4: 150,
#   0.45: 600,
#   0.5: 150,
#   0.55: 600,
#   0.6: 150,
#   0.61: 300,
#   0.65: 600,
#   0.66: 300,
#   0.7: 150,
#   0.71: 300,
#   0.75: 600,
#   0.76: 300,
#   0.8: 150,
#   0.85: 600,
#   0.9: 150,
#   0.95: 600,
#   1.0: 150,
#   1.05: 600,
#   1.1: 150,
#   1.15: 600,
#   1.2: 150,
#   1.25: 600,
#   1.3: 150,
#   1.35: 600,
#   1.4: 150,
#   1.45: 600,
#   1.5: 150,
#   1.55: 600,
#   1.6: 150,
#   1.65: 600,
#   1.7: 150,
#   1.75: 600,
#   1.8: 150,
#   1.85: 600,
#   1.9: 150,
#   1.95: 600,
#   2.0: 150,
#   2.05: 150,
#   2.1: 150,
#   2.15: 150,
#   2.2: 150,
#   2.25: 150,
#   2.3: 150,
#   2.35: 150,
#   2.4: 150,
#   2.45: 150,
#   2.5: 150,
#   2.55: 150,
#   2.6: 150,
#   2.65: 150,
#   2.7: 150,
#   2.75: 150,
#   2.8: 150,
#   2.85: 150,
#   2.9: 150,
#   2.95: 150,
#   3.0: 150,
#   3.05: 150,
#   3.1: 150,
#   3.15: 150,
#   3.2: 150,
#   3.25: 150,
#   3.3: 150,
#   3.35: 150,
#   3.4: 150,
#   3.45: 150,
#   3.5: 150,
#   3.55: 150,
#   3.6: 150,
#   3.65: 150,
#   3.7: 150,
#   3.75: 150,
#   3.8: 150,
#   3.85: 150,
#   3.9: 150,
#   3.95: 150,
#   4.0: 150,
#   4.05: 150,
#   4.1: 150,
#   4.15: 150,
#   4.2: 150,
#   4.25: 150,
#   4.3: 150,
#   4.35: 150,
#   4.4: 150,
#   4.45: 150,
#   4.5: 150,
#   4.55: 150,
#   4.6: 150,
#   4.65: 150,
#   4.7: 150,
#   4.75: 150,
#   4.8: 150,
#   4.85: 150,
#   4.9: 150,
#   4.95: 150,
#   5.0: 150,
#   5.05: 150,
#   5.1: 150,
#   5.15: 150,
#   5.2: 150,
#   5.25: 150,
#   5.3: 150,
#   5.35: 150,
#   5.4: 150,
#   5.45: 150,
#   5.5: 150,
#   5.55: 150,
#   5.6: 150,
#   5.65: 150,
#   5.7: 150,
#   5.75: 150,
#   5.8: 150,
#   5.85: 150,
#   5.9: 150,
#   5.95: 150,
#   6.0: 150,
#   6.05: 150,
#   6.1: 150,
#   6.15: 150,
#   6.2: 150,
#   6.25: 150,
#   6.3: 150,
#   6.35: 150,
#   6.4: 150,
#   6.45: 150,
#   6.5: 150,
#   6.55: 150,
#   6.6: 150,
#   6.65: 150,
#   6.7: 150,
#   6.75: 150,
#   6.8: 150,
#   6.85: 150,
#   6.9: 150,
#   6.95: 150,
#   7.0: 150},
#  300: {0.3: 150,
#   0.35: 600,
#   0.4: 150,
#   0.45: 600,
#   0.5: 150,
#   0.55: 600,
#   0.6: 150,
#   0.61: 300,
#   0.65: 600,
#   0.66: 300,
#   0.7: 150,
#   0.71: 300,
#   0.75: 600,
#   0.76: 300,
#   0.8: 150,
#   0.85: 600,
#   0.9: 150,
#   0.95: 600,
#   1.0: 150,
#   1.05: 600,
#   1.1: 150,
#   1.15: 600,
#   1.2: 150,
#   1.25: 600,
#   1.3: 150,
#   1.35: 600,
#   1.4: 150,
#   1.45: 600,
#   1.5: 150,
#   1.55: 600,
#   1.6: 150,
#   1.65: 600,
#   1.7: 150,
#   1.75: 600,
#   1.8: 150,
#   1.85: 600,
#   1.9: 150,
#   1.95: 600,
#   2.0: 150,
#   2.05: 150,
#   2.1: 150,
#   2.15: 150,
#   2.2: 150,
#   2.25: 150,
#   2.3: 150,
#   2.35: 150,
#   2.4: 150,
#   2.45: 150,
#   2.5: 150,
#   2.55: 150,
#   2.6: 150,
#   2.65: 150,
#   2.7: 150,
#   2.75: 150,
#   2.8: 150,
#   2.85: 150,
#   2.9: 150,
#   2.95: 150,
#   3.0: 150,
#   3.05: 150,
#   3.1: 150,
#   3.15: 150,
#   3.2: 150,
#   3.25: 150,
#   3.3: 150,
#   3.35: 150,
#   3.4: 150,
#   3.45: 150,
#   3.5: 150,
#   3.55: 150,
#   3.6: 150,
#   3.65: 150,
#   3.7: 150,
#   3.75: 150,
#   3.8: 150,
#   3.85: 150,
#   3.9: 150,
#   3.95: 150,
#   4.0: 150,
#   4.05: 150,
#   4.1: 150,
#   4.15: 150,
#   4.2: 150,
#   4.25: 150,
#   4.3: 150,
#   4.35: 150,
#   4.4: 150,
#   4.45: 150,
#   4.5: 150,
#   4.55: 150,
#   4.6: 150,
#   4.65: 150,
#   4.7: 150,
#   4.75: 150,
#   4.8: 150,
#   4.85: 150,
#   4.9: 150,
#   4.95: 150,
#   5.0: 150,
#   5.05: 150,
#   5.1: 150,
#   5.15: 150,
#   5.2: 150,
#   5.25: 150,
#   5.3: 150,
#   5.35: 150,
#   5.4: 150,
#   5.45: 150,
#   5.5: 150,
#   5.55: 150,
#   5.6: 150,
#   5.65: 150,
#   5.7: 150,
#   5.75: 150,
#   5.8: 150,
#   5.85: 150,
#   5.9: 150,
#   5.95: 150,
#   6.0: 150,
#   6.05: 150,
#   6.1: 150,
#   6.15: 150,
#   6.2: 150,
#   6.25: 150,
#   6.3: 150,
#   6.35: 150,
#   6.4: 150,
#   6.45: 150,
#   6.5: 150,
#   6.55: 150,
#   6.6: 150,
#   6.65: 150,
#   6.7: 150,
#   6.75: 150,
#   6.8: 150,
#   6.85: 150,
#   6.9: 150,
#   6.95: 150,
#   7.0: 150},
#  320: {0.3: 150,
#   0.35: 600,
#   0.4: 150,
#   0.45: 600,
#   0.5: 150,
#   0.55: 600,
#   0.6: 150,
#   0.61: 300,
#   0.65: 600,
#   0.66: 300,
#   0.7: 150,
#   0.71: 300,
#   0.75: 600,
#   0.76: 300,
#   0.8: 150,
#   0.85: 600,
#   0.9: 150,
#   0.95: 600,
#   1.0: 150,
#   1.05: 600,
#   1.1: 150,
#   1.15: 600,
#   1.2: 150,
#   1.25: 600,
#   1.3: 150,
#   1.35: 600,
#   1.4: 150,
#   1.45: 600,
#   1.5: 150,
#   1.55: 600,
#   1.6: 150,
#   1.65: 600,
#   1.7: 150,
#   1.75: 600,
#   1.8: 150,
#   1.85: 600,
#   1.9: 150,
#   1.95: 600,
#   2.0: 150,
#   2.05: 150,
#   2.1: 150,
#   2.15: 150,
#   2.2: 150,
#   2.25: 150,
#   2.3: 150,
#   2.35: 150,
#   2.4: 150,
#   2.45: 150,
#   2.5: 150,
#   2.55: 150,
#   2.6: 150,
#   2.65: 150,
#   2.7: 150,
#   2.75: 150,
#   2.8: 150,
#   2.85: 150,
#   2.9: 150,
#   2.95: 150,
#   3.0: 150,
#   3.05: 150,
#   3.1: 150,
#   3.15: 150,
#   3.2: 150,
#   3.25: 150,
#   3.3: 150,
#   3.35: 150,
#   3.4: 150,
#   3.45: 150,
#   3.5: 150,
#   3.55: 150,
#   3.6: 150,
#   3.65: 150,
#   3.7: 150,
#   3.75: 150,
#   3.8: 150,
#   3.85: 150,
#   3.9: 150,
#   3.95: 150,
#   4.0: 150,
#   4.05: 150,
#   4.1: 150,
#   4.15: 150,
#   4.2: 150,
#   4.25: 150,
#   4.3: 150,
#   4.35: 150,
#   4.4: 150,
#   4.45: 150,
#   4.5: 150,
#   4.55: 150,
#   4.6: 150,
#   4.65: 150,
#   4.7: 150,
#   4.75: 150,
#   4.8: 150,
#   4.85: 150,
#   4.9: 150,
#   4.95: 150,
#   5.0: 150,
#   5.05: 150,
#   5.1: 150,
#   5.15: 150,
#   5.2: 150,
#   5.25: 150,
#   5.3: 150,
#   5.35: 150,
#   5.4: 150,
#   5.45: 150,
#   5.5: 150,
#   5.55: 150,
#   5.6: 150,
#   5.65: 150,
#   5.7: 150,
#   5.75: 150,
#   5.8: 150,
#   5.85: 150,
#   5.9: 150,
#   5.95: 150,
#   6.0: 150,
#   6.05: 150,
#   6.1: 150,
#   6.15: 150,
#   6.2: 150,
#   6.25: 150,
#   6.3: 150,
#   6.35: 150,
#   6.4: 150,
#   6.45: 150,
#   6.5: 150,
#   6.55: 150,
#   6.6: 150,
#   6.65: 150,
#   6.7: 150,
#   6.75: 150,
#   6.8: 150,
#   6.85: 150,
#   6.9: 150,
#   6.95: 150,
#   7.0: 150}}

# %%
# Loop over temperatures
for temp in sims.keys():
    
    # Prepare and go to directory
    if not os.path.exists(str(temp)):
        os.mkdir(str(temp))
        os.system(f'cp src/ {temp} -r')
    os.chdir(str(temp))
    print(os.getcwd())
    # Loop over distances 
    for dist, kappa in sims[temp].items():
        
        if os.path.exists(f'{dist}/TIMESERIES'):
            print(f'Skipping {temp}: {dist}')
            continue
        print(f'Now doing run {temp}: {dist}')
        # Create param files
        create_folders(dist)
        create_EM_param(EM_STRING, dist)
        create_heat_param(HEAT_STRING, dist, temp)
        create_prod_param(PROD_STRING, dist, temp)
        write_plumed_file(PLUMED_STRING, dist, kappa)

        # Generate starting config
        structure = reload_struct('src/halfpdb_nosep.pdb')
        chainA = structure[0]['A']
        move_chain(dist * 10, chainA)
        save_struct(f'{dist}/resource/{dist}.pdb')

        # Convert config 
        convert_pdb(f'{dist}/resource/{dist}.pdb', f'{dist}/resource/{dist}_cleaned.pdb')
        generate_rst7(TLEAP_STRING, dist)
        
    # Go back to original dir
    os.chdir(basepath)
# Out:
# /scistor/informatica/age206/simlab/US-final/noSASA/280
# Skipping 280: 0.3
# Now doing run 280: 0.35
# -I: Adding /cm/shared/package/amber/20_v2/dat/leap/prep to search path.
# -I: Adding /cm/shared/package/amber/20_v2/dat/leap/lib to search path.
# -I: Adding /cm/shared/package/amber/20_v2/dat/leap/parm to search path.
# -I: Adding /cm/shared/package/amber/20_v2/dat/leap/cmd to search path.
# -f: Source 0.35/resource/tleap_script.in.
#
# Welcome to LEaP!
# (no leaprc in search path)
# Sourcing: ./0.35/resource/tleap_script.in
# ----- Source: /cm/shared/package/amber/20_v2/dat/leap/cmd/leaprc.protein.ff19SB
# ----- Source of /cm/shared/package/amber/20_v2/dat/leap/cmd/leaprc.protein.ff19SB done
# Log file: ./leap.log
# Loading parameters: /cm/shared/package/amber/20_v2/dat/leap/parm/parm19.dat
# Reading title:
# PARM99 + frcmod.ff99SB + frcmod.parmbsc0 + OL3 for RNA + ff19SB
# Loading parameters: /cm/shared/package/amber/20_v2/dat/leap/parm/frcmod.ff19SB
# Reading force field modification type file (frcmod)
# Reading title:
# ff19SB AA-specific backbone CMAPs for protein 07/25/2019
# Loading library: /cm/shared/package/amber/20_v2/dat/leap/lib/amino19.lib
# Loading library: /cm/shared/package/amber/20_v2/dat/leap/lib/aminoct12.lib
# Loading library: /cm/shared/package/amber/20_v2/dat/leap/lib/aminont12.lib
# Loading PDB file: ./0.35/resource/0.35_cleaned.pdb
#   Added missing heavy atom: .R<CTHR 29>.A<OXT 15>
#   Added missing heavy atom: .R<CTHR 58>.A<OXT 15>
#   Added missing heavy atom: .R<CTHR 87>.A<OXT 15>
#   Added missing heavy atom: .R<CTHR 116>.A<OXT 15>
#   Added missing heavy atom: .R<CTHR 145>.A<OXT 15>
#   Added missing heavy atom: .R<CTHR 174>.A<OXT 15>
#   Added missing heavy atom: .R<CTHR 203>.A<OXT 15>
#   Added missing heavy atom: .R<CTHR 232>.A<OXT 15>
#   total atoms in file: 3744
#   Leap added 24 missing atoms according to residue templates:
#        8 Heavy
#        16 H / lone pairs
# Box dimensions:  34.029200 108.774000 63.520000
# Checking Unit.
# Building topology.
# Building atom parameters.
# Building bond parameters.
# Building angle parameters.
# Building proper torsion parameters.
# Building improper torsion parameters.
#  total 904 improper torsions applied
# Building H-Bond parameters.
# Incorporating Non-Bonded adjustments.
# Not Marking per-residue atom chain types.
# Marking per-residue atom chain types.
#   (Residues lacking connect0/connect1 -
#    these don't have chain types marked:
#
# 	res	total affected
#
# 	CTHR	8
# 	NHID	8
#   )
#  (no restraints)
# 	Quit
#
# Exiting LEaP: Errors = 0; Warnings = 0; Notes = 0.
# Skipping 280: 0.4
# Now doing run 280: 0.45
# -I: Adding /cm/shared/package/amber/20_v2/dat/leap/prep to search path.
# -I: Adding /cm/shared/package/amber/20_v2/dat/leap/lib to search path.
# -I: Adding /cm/shared/package/amber/20_v2/dat/leap/parm to search path.
# -I: Adding /cm/shared/package/amber/20_v2/dat/leap/cmd to search path.
# -f: Source 0.45/resource/tleap_script.in.
#
# Welcome to LEaP!
# (no leaprc in search path)
# Sourcing: ./0.45/resource/tleap_script.in
# ----- Source: /cm/shared/package/amber/20_v2/dat/leap/cmd/leaprc.protein.ff19SB
# ----- Source of /cm/shared/package/amber/20_v2/dat/leap/cmd/leaprc.protein.ff19SB done
# Log file: ./leap.log
# Loading parameters: /cm/shared/package/amber/20_v2/dat/leap/parm/parm19.dat
# Reading title:
# PARM99 + frcmod.ff99SB + frcmod.parmbsc0 + OL3 for RNA + ff19SB
# Loading parameters: /cm/shared/package/amber/20_v2/dat/leap/parm/frcmod.ff19SB
# Reading force field modification type file (frcmod)
# Reading title:
# ff19SB AA-specific backbone CMAPs for protein 07/25/2019
# Loading library: /cm/shared/package/amber/20_v2/dat/leap/lib/amino19.lib
# Loading library: /cm/shared/package/amber/20_v2/dat/leap/lib/aminoct12.lib
# Loading library: /cm/shared/package/amber/20_v2/dat/leap/lib/aminont12.lib
# Loading PDB file: ./0.45/resource/0.45_cleaned.pdb
#   Added missing heavy atom: .R<CTHR 29>.A<OXT 15>
#   Added missing heavy atom: .R<CTHR 58>.A<OXT 15>
#   Added missing heavy atom: .R<CTHR 87>.A<OXT 15>
#   Added missing heavy atom: .R<CTHR 116>.A<OXT 15>
#   Added missing heavy atom: .R<CTHR 145>.A<OXT 15>
#   Added missing heavy atom: .R<CTHR 174>.A<OXT 15>
#   Added missing heavy atom: .R<CTHR 203>.A<OXT 15>
#   Added missing heavy atom: .R<CTHR 232>.A<OXT 15>
#   total atoms in file: 3744
#   Leap added 24 missing atoms according to residue templates:
#        8 Heavy
#        16 H / lone pairs
# Box dimensions:  34.029200 108.774000 64.520000
# Checking Unit.
# Building topology.
# Building atom parameters.
# Building bond parameters.
# Building angle parameters.
# Building proper torsion parameters.
# Building improper torsion parameters.
#  total 904 improper torsions applied
# Building H-Bond parameters.
# Incorporating Non-Bonded adjustments.
# Not Marking per-residue atom chain types.
# Marking per-residue atom chain types.
#   (Residues lacking connect0/connect1 -
#    these don't have chain types marked:
#
# 	res	total affected
#
# 	CTHR	8
# 	NHID	8
#   )
#  (no restraints)
# 	Quit
#
# Exiting LEaP: Errors = 0; Warnings = 0; Notes = 0.
# Skipping 280: 0.5
# Now doing run 280: 0.55
# -I: Adding /cm/shared/package/amber/20_v2/dat/leap/prep to search path.
# -I: Adding /cm/shared/package/amber/20_v2/dat/leap/lib to search path.
# -I: Adding /cm/shared/package/amber/20_v2/dat/leap/parm to search path.
# -I: Adding /cm/shared/package/amber/20_v2/dat/leap/cmd to search path.
# -f: Source 0.55/resource/tleap_script.in.
#
# Welcome to LEaP!
# (no leaprc in search path)
# Sourcing: ./0.55/resource/tleap_script.in
# ----- Source: /cm/shared/package/amber/20_v2/dat/leap/cmd/leaprc.protein.ff19SB
# ----- Source of /cm/shared/package/amber/20_v2/dat/leap/cmd/leaprc.protein.ff19SB done
# Log file: ./leap.log
# Loading parameters: /cm/shared/package/amber/20_v2/dat/leap/parm/parm19.dat
# Reading title:
# PARM99 + frcmod.ff99SB + frcmod.parmbsc0 + OL3 for RNA + ff19SB
# Loading parameters: /cm/shared/package/amber/20_v2/dat/leap/parm/frcmod.ff19SB
# Reading force field modification type file (frcmod)
# Reading title:
# ff19SB AA-specific backbone CMAPs for protein 07/25/2019
# Loading library: /cm/shared/package/amber/20_v2/dat/leap/lib/amino19.lib
# Loading library: /cm/shared/package/amber/20_v2/dat/leap/lib/aminoct12.lib
# Loading library: /cm/shared/package/amber/20_v2/dat/leap/lib/aminont12.lib
# Loading PDB file: ./0.55/resource/0.55_cleaned.pdb
#   Added missing heavy atom: .R<CTHR 29>.A<OXT 15>
#   Added missing heavy atom: .R<CTHR 58>.A<OXT 15>
#   Added missing heavy atom: .R<CTHR 87>.A<OXT 15>
#   Added missing heavy atom: .R<CTHR 116>.A<OXT 15>
#   Added missing heavy atom: .R<CTHR 145>.A<OXT 15>
#   Added missing heavy atom: .R<CTHR 174>.A<OXT 15>
#   Added missing heavy atom: .R<CTHR 203>.A<OXT 15>
#   Added missing heavy atom: .R<CTHR 232>.A<OXT 15>
#   total atoms in file: 3744
#   Leap added 24 missing atoms according to residue templates:
#        8 Heavy
#        16 H / lone pairs
# Box dimensions:  34.029200 108.774000 65.520000
# Checking Unit.
# Building topology.
# Building atom parameters.
# Building bond parameters.
# Building angle parameters.
# Building proper torsion parameters.
# Building improper torsion parameters.
#  total 904 improper torsions applied
# Building H-Bond parameters.
# Incorporating Non-Bonded adjustments.
# Not Marking per-residue atom chain types.
# Marking per-residue atom chain types.
#   (Residues lacking connect0/connect1 -
#    these don't have chain types marked:
#
# 	res	total affected
#
# 	CTHR	8
# 	NHID	8
#   )
#  (no restraints)
# 	Quit
#
# Exiting LEaP: Errors = 0; Warnings = 0; Notes = 0.
# Skipping 280: 0.6
# Skipping 280: 0.61
# Now doing run 280: 0.65
# -I: Adding /cm/shared/package/amber/20_v2/dat/leap/prep to search path.
# -I: Adding /cm/shared/package/amber/20_v2/dat/leap/lib to search path.
# -I: Adding /cm/shared/package/amber/20_v2/dat/leap/parm to search path.
# -I: Adding /cm/shared/package/amber/20_v2/dat/leap/cmd to search path.
# -f: Source 0.65/resource/tleap_script.in.
#
# Welcome to LEaP!
# (no leaprc in search path)
# Sourcing: ./0.65/resource/tleap_script.in
# ----- Source: /cm/shared/package/amber/20_v2/dat/leap/cmd/leaprc.protein.ff19SB
# ----- Source of /cm/shared/package/amber/20_v2/dat/leap/cmd/leaprc.protein.ff19SB done
# Log file: ./leap.log
# Loading parameters: /cm/shared/package/amber/20_v2/dat/leap/parm/parm19.dat
# Reading title:
# PARM99 + frcmod.ff99SB + frcmod.parmbsc0 + OL3 for RNA + ff19SB
# Loading parameters: /cm/shared/package/amber/20_v2/dat/leap/parm/frcmod.ff19SB
# Reading force field modification type file (frcmod)
# Reading title:
# ff19SB AA-specific backbone CMAPs for protein 07/25/2019
# Loading library: /cm/shared/package/amber/20_v2/dat/leap/lib/amino19.lib
# Loading library: /cm/shared/package/amber/20_v2/dat/leap/lib/aminoct12.lib
# Loading library: /cm/shared/package/amber/20_v2/dat/leap/lib/aminont12.lib
# Loading PDB file: ./0.65/resource/0.65_cleaned.pdb
#   Added missing heavy atom: .R<CTHR 29>.A<OXT 15>
#   Added missing heavy atom: .R<CTHR 58>.A<OXT 15>
#   Added missing heavy atom: .R<CTHR 87>.A<OXT 15>
#   Added missing heavy atom: .R<CTHR 116>.A<OXT 15>
#   Added missing heavy atom: .R<CTHR 145>.A<OXT 15>
#   Added missing heavy atom: .R<CTHR 174>.A<OXT 15>
#   Added missing heavy atom: .R<CTHR 203>.A<OXT 15>
#   Added missing heavy atom: .R<CTHR 232>.A<OXT 15>
#   total atoms in file: 3744
#   Leap added 24 missing atoms according to residue templates:
#        8 Heavy
#        16 H / lone pairs
# Box dimensions:  34.029200 108.774000 66.520000
# Checking Unit.
# Building topology.
# Building atom parameters.
# Building bond parameters.
# Building angle parameters.
# Building proper torsion parameters.
# Building improper torsion parameters.
#  total 904 improper torsions applied
# Building H-Bond parameters.
# Incorporating Non-Bonded adjustments.
# Not Marking per-residue atom chain types.
# Marking per-residue atom chain types.
#   (Residues lacking connect0/connect1 -
#    these don't have chain types marked:
#
# 	res	total affected
#
# 	CTHR	8
# 	NHID	8
#   )
#  (no restraints)
# 	Quit
#
# Exiting LEaP: Errors = 0; Warnings = 0; Notes = 0.
# Skipping 280: 0.66
# Skipping 280: 0.7
# Skipping 280: 0.71
# Now doing run 280: 0.75
# -I: Adding /cm/shared/package/amber/20_v2/dat/leap/prep to search path.
# -I: Adding /cm/shared/package/amber/20_v2/dat/leap/lib to search path.
# -I: Adding /cm/shared/package/amber/20_v2/dat/leap/parm to search path.
# -I: Adding /cm/shared/package/amber/20_v2/dat/leap/cmd to search path.
# -f: Source 0.75/resource/tleap_script.in.
#
# Welcome to LEaP!
# (no leaprc in search path)
# Sourcing: ./0.75/resource/tleap_script.in
# ----- Source: /cm/shared/package/amber/20_v2/dat/leap/cmd/leaprc.protein.ff19SB
# ----- Source of /cm/shared/package/amber/20_v2/dat/leap/cmd/leaprc.protein.ff19SB done
# Log file: ./leap.log
# Loading parameters: /cm/shared/package/amber/20_v2/dat/leap/parm/parm19.dat
# Reading title:
# PARM99 + frcmod.ff99SB + frcmod.parmbsc0 + OL3 for RNA + ff19SB
# Loading parameters: /cm/shared/package/amber/20_v2/dat/leap/parm/frcmod.ff19SB
# Reading force field modification type file (frcmod)
# Reading title:
# ff19SB AA-specific backbone CMAPs for protein 07/25/2019
# Loading library: /cm/shared/package/amber/20_v2/dat/leap/lib/amino19.lib
# Loading library: /cm/shared/package/amber/20_v2/dat/leap/lib/aminoct12.lib
# Loading library: /cm/shared/package/amber/20_v2/dat/leap/lib/aminont12.lib
# Loading PDB file: ./0.75/resource/0.75_cleaned.pdb
#   Added missing heavy atom: .R<CTHR 29>.A<OXT 15>
#   Added missing heavy atom: .R<CTHR 58>.A<OXT 15>
#   Added missing heavy atom: .R<CTHR 87>.A<OXT 15>
#   Added missing heavy atom: .R<CTHR 116>.A<OXT 15>
#   Added missing heavy atom: .R<CTHR 145>.A<OXT 15>
#   Added missing heavy atom: .R<CTHR 174>.A<OXT 15>
#   Added missing heavy atom: .R<CTHR 203>.A<OXT 15>
#   Added missing heavy atom: .R<CTHR 232>.A<OXT 15>
#   total atoms in file: 3744
#   Leap added 24 missing atoms according to residue templates:
#        8 Heavy
#        16 H / lone pairs
# Box dimensions:  34.029200 108.774000 67.520000
# Checking Unit.
# Building topology.
# Building atom parameters.
# Building bond parameters.
# Building angle parameters.
# Building proper torsion parameters.
# Building improper torsion parameters.
#  total 904 improper torsions applied
# Building H-Bond parameters.
# Incorporating Non-Bonded adjustments.
# Not Marking per-residue atom chain types.
# Marking per-residue atom chain types.
#   (Residues lacking connect0/connect1 -
#    these don't have chain types marked:
#
# 	res	total affected
#
# 	CTHR	8
# 	NHID	8
#   )
#  (no restraints)
# 	Quit
#
# Exiting LEaP: Errors = 0; Warnings = 0; Notes = 0.
# Skipping 280: 0.76
# Skipping 280: 0.8
# Now doing run 280: 0.85
# -I: Adding /cm/shared/package/amber/20_v2/dat/leap/prep to search path.
# -I: Adding /cm/shared/package/amber/20_v2/dat/leap/lib to search path.
# -I: Adding /cm/shared/package/amber/20_v2/dat/leap/parm to search path.
# -I: Adding /cm/shared/package/amber/20_v2/dat/leap/cmd to search path.
# -f: Source 0.85/resource/tleap_script.in.
#
# Welcome to LEaP!
# (no leaprc in search path)
# Sourcing: ./0.85/resource/tleap_script.in
# ----- Source: /cm/shared/package/amber/20_v2/dat/leap/cmd/leaprc.protein.ff19SB
# ----- Source of /cm/shared/package/amber/20_v2/dat/leap/cmd/leaprc.protein.ff19SB done
# Log file: ./leap.log
# Loading parameters: /cm/shared/package/amber/20_v2/dat/leap/parm/parm19.dat
# Reading title:
# PARM99 + frcmod.ff99SB + frcmod.parmbsc0 + OL3 for RNA + ff19SB
# Loading parameters: /cm/shared/package/amber/20_v2/dat/leap/parm/frcmod.ff19SB
# Reading force field modification type file (frcmod)
# Reading title:
# ff19SB AA-specific backbone CMAPs for protein 07/25/2019
# Loading library: /cm/shared/package/amber/20_v2/dat/leap/lib/amino19.lib
# Loading library: /cm/shared/package/amber/20_v2/dat/leap/lib/aminoct12.lib
# Loading library: /cm/shared/package/amber/20_v2/dat/leap/lib/aminont12.lib
# Loading PDB file: ./0.85/resource/0.85_cleaned.pdb
#   Added missing heavy atom: .R<CTHR 29>.A<OXT 15>
#   Added missing heavy atom: .R<CTHR 58>.A<OXT 15>
#   Added missing heavy atom: .R<CTHR 87>.A<OXT 15>
#   Added missing heavy atom: .R<CTHR 116>.A<OXT 15>
#   Added missing heavy atom: .R<CTHR 145>.A<OXT 15>
#   Added missing heavy atom: .R<CTHR 174>.A<OXT 15>
#   Added missing heavy atom: .R<CTHR 203>.A<OXT 15>
#   Added missing heavy atom: .R<CTHR 232>.A<OXT 15>
#   total atoms in file: 3744
#   Leap added 24 missing atoms according to residue templates:
#        8 Heavy
#        16 H / lone pairs
# Box dimensions:  34.029200 108.774000 68.520000
# Checking Unit.
# Building topology.
# Building atom parameters.
# Building bond parameters.
# Building angle parameters.
# Building proper torsion parameters.
# Building improper torsion parameters.
#  total 904 improper torsions applied
# Building H-Bond parameters.
# Incorporating Non-Bonded adjustments.
# Not Marking per-residue atom chain types.
# Marking per-residue atom chain types.
#   (Residues lacking connect0/connect1 -
#    these don't have chain types marked:
#
# 	res	total affected
#
# 	CTHR	8
# 	NHID	8
#   )
#  (no restraints)
# 	Quit
#
# Exiting LEaP: Errors = 0; Warnings = 0; Notes = 0.
# Skipping 280: 0.9
# Now doing run 280: 0.95
# -I: Adding /cm/shared/package/amber/20_v2/dat/leap/prep to search path.
# -I: Adding /cm/shared/package/amber/20_v2/dat/leap/lib to search path.
# -I: Adding /cm/shared/package/amber/20_v2/dat/leap/parm to search path.
# -I: Adding /cm/shared/package/amber/20_v2/dat/leap/cmd to search path.
# -f: Source 0.95/resource/tleap_script.in.
#
# Welcome to LEaP!
# (no leaprc in search path)
# Sourcing: ./0.95/resource/tleap_script.in
# ----- Source: /cm/shared/package/amber/20_v2/dat/leap/cmd/leaprc.protein.ff19SB
# ----- Source of /cm/shared/package/amber/20_v2/dat/leap/cmd/leaprc.protein.ff19SB done
# Log file: ./leap.log
# Loading parameters: /cm/shared/package/amber/20_v2/dat/leap/parm/parm19.dat
# Reading title:
# PARM99 + frcmod.ff99SB + frcmod.parmbsc0 + OL3 for RNA + ff19SB
# Loading parameters: /cm/shared/package/amber/20_v2/dat/leap/parm/frcmod.ff19SB
# Reading force field modification type file (frcmod)
# Reading title:
# ff19SB AA-specific backbone CMAPs for protein 07/25/2019
# Loading library: /cm/shared/package/amber/20_v2/dat/leap/lib/amino19.lib
# Loading library: /cm/shared/package/amber/20_v2/dat/leap/lib/aminoct12.lib
# Loading library: /cm/shared/package/amber/20_v2/dat/leap/lib/aminont12.lib
# Loading PDB file: ./0.95/resource/0.95_cleaned.pdb
#   Added missing heavy atom: .R<CTHR 29>.A<OXT 15>
#   Added missing heavy atom: .R<CTHR 58>.A<OXT 15>
#   Added missing heavy atom: .R<CTHR 87>.A<OXT 15>
#   Added missing heavy atom: .R<CTHR 116>.A<OXT 15>
#   Added missing heavy atom: .R<CTHR 145>.A<OXT 15>
#   Added missing heavy atom: .R<CTHR 174>.A<OXT 15>
#   Added missing heavy atom: .R<CTHR 203>.A<OXT 15>
#   Added missing heavy atom: .R<CTHR 232>.A<OXT 15>
#   total atoms in file: 3744
#   Leap added 24 missing atoms according to residue templates:
#        8 Heavy
#        16 H / lone pairs
# Box dimensions:  34.029200 108.774000 69.520000
# Checking Unit.
# Building topology.
# Building atom parameters.
# Building bond parameters.
# Building angle parameters.
# Building proper torsion parameters.
# Building improper torsion parameters.
#  total 904 improper torsions applied
# Building H-Bond parameters.
# Incorporating Non-Bonded adjustments.
# Not Marking per-residue atom chain types.
# Marking per-residue atom chain types.
#   (Residues lacking connect0/connect1 -
#    these don't have chain types marked:
#
# 	res	total affected
#
# 	CTHR	8
# 	NHID	8
#   )
#  (no restraints)
# 	Quit
#
# Exiting LEaP: Errors = 0; Warnings = 0; Notes = 0.
# Skipping 280: 1.0
# Now doing run 280: 1.05
# -I: Adding /cm/shared/package/amber/20_v2/dat/leap/prep to search path.
# -I: Adding /cm/shared/package/amber/20_v2/dat/leap/lib to search path.
# -I: Adding /cm/shared/package/amber/20_v2/dat/leap/parm to search path.
# -I: Adding /cm/shared/package/amber/20_v2/dat/leap/cmd to search path.
# -f: Source 1.05/resource/tleap_script.in.
#
# Welcome to LEaP!
# (no leaprc in search path)
# Sourcing: ./1.05/resource/tleap_script.in
# ----- Source: /cm/shared/package/amber/20_v2/dat/leap/cmd/leaprc.protein.ff19SB
# ----- Source of /cm/shared/package/amber/20_v2/dat/leap/cmd/leaprc.protein.ff19SB done
# Log file: ./leap.log
# Loading parameters: /cm/shared/package/amber/20_v2/dat/leap/parm/parm19.dat
# Reading title:
# PARM99 + frcmod.ff99SB + frcmod.parmbsc0 + OL3 for RNA + ff19SB
# Loading parameters: /cm/shared/package/amber/20_v2/dat/leap/parm/frcmod.ff19SB
# Reading force field modification type file (frcmod)
# Reading title:
# ff19SB AA-specific backbone CMAPs for protein 07/25/2019
# Loading library: /cm/shared/package/amber/20_v2/dat/leap/lib/amino19.lib
# Loading library: /cm/shared/package/amber/20_v2/dat/leap/lib/aminoct12.lib
# Loading library: /cm/shared/package/amber/20_v2/dat/leap/lib/aminont12.lib
# Loading PDB file: ./1.05/resource/1.05_cleaned.pdb
#   Added missing heavy atom: .R<CTHR 29>.A<OXT 15>
#   Added missing heavy atom: .R<CTHR 58>.A<OXT 15>
#   Added missing heavy atom: .R<CTHR 87>.A<OXT 15>
#   Added missing heavy atom: .R<CTHR 116>.A<OXT 15>
#   Added missing heavy atom: .R<CTHR 145>.A<OXT 15>
#   Added missing heavy atom: .R<CTHR 174>.A<OXT 15>
#   Added missing heavy atom: .R<CTHR 203>.A<OXT 15>
#   Added missing heavy atom: .R<CTHR 232>.A<OXT 15>
#   total atoms in file: 3744
#   Leap added 24 missing atoms according to residue templates:
#        8 Heavy
#        16 H / lone pairs
# Box dimensions:  34.029200 108.774000 70.520000
# Checking Unit.
# Building topology.
# Building atom parameters.
# Building bond parameters.
# Building angle parameters.
# Building proper torsion parameters.
# Building improper torsion parameters.
#  total 904 improper torsions applied
# Building H-Bond parameters.
# Incorporating Non-Bonded adjustments.
# Not Marking per-residue atom chain types.
# Marking per-residue atom chain types.
#   (Residues lacking connect0/connect1 -
#    these don't have chain types marked:
#
# 	res	total affected
#
# 	CTHR	8
# 	NHID	8
#   )
#  (no restraints)
# 	Quit
#
# Exiting LEaP: Errors = 0; Warnings = 0; Notes = 0.
# Skipping 280: 1.1
# Now doing run 280: 1.15
# -I: Adding /cm/shared/package/amber/20_v2/dat/leap/prep to search path.
# -I: Adding /cm/shared/package/amber/20_v2/dat/leap/lib to search path.
# -I: Adding /cm/shared/package/amber/20_v2/dat/leap/parm to search path.
# -I: Adding /cm/shared/package/amber/20_v2/dat/leap/cmd to search path.
# -f: Source 1.15/resource/tleap_script.in.
#
# Welcome to LEaP!
# (no leaprc in search path)
# Sourcing: ./1.15/resource/tleap_script.in
# ----- Source: /cm/shared/package/amber/20_v2/dat/leap/cmd/leaprc.protein.ff19SB
# ----- Source of /cm/shared/package/amber/20_v2/dat/leap/cmd/leaprc.protein.ff19SB done
# Log file: ./leap.log
# Loading parameters: /cm/shared/package/amber/20_v2/dat/leap/parm/parm19.dat
# Reading title:
# PARM99 + frcmod.ff99SB + frcmod.parmbsc0 + OL3 for RNA + ff19SB
# Loading parameters: /cm/shared/package/amber/20_v2/dat/leap/parm/frcmod.ff19SB
# Reading force field modification type file (frcmod)
# Reading title:
# ff19SB AA-specific backbone CMAPs for protein 07/25/2019
# Loading library: /cm/shared/package/amber/20_v2/dat/leap/lib/amino19.lib
# Loading library: /cm/shared/package/amber/20_v2/dat/leap/lib/aminoct12.lib
# Loading library: /cm/shared/package/amber/20_v2/dat/leap/lib/aminont12.lib
# Loading PDB file: ./1.15/resource/1.15_cleaned.pdb
#   Added missing heavy atom: .R<CTHR 29>.A<OXT 15>
#   Added missing heavy atom: .R<CTHR 58>.A<OXT 15>
#   Added missing heavy atom: .R<CTHR 87>.A<OXT 15>
#   Added missing heavy atom: .R<CTHR 116>.A<OXT 15>
#   Added missing heavy atom: .R<CTHR 145>.A<OXT 15>
#   Added missing heavy atom: .R<CTHR 174>.A<OXT 15>
#   Added missing heavy atom: .R<CTHR 203>.A<OXT 15>
#   Added missing heavy atom: .R<CTHR 232>.A<OXT 15>
#   total atoms in file: 3744
#   Leap added 24 missing atoms according to residue templates:
#        8 Heavy
#        16 H / lone pairs
# Box dimensions:  34.029200 108.774000 71.520000
# Checking Unit.
# Building topology.
# Building atom parameters.
# Building bond parameters.
# Building angle parameters.
# Building proper torsion parameters.
# Building improper torsion parameters.
#  total 904 improper torsions applied
# Building H-Bond parameters.
# Incorporating Non-Bonded adjustments.
# Not Marking per-residue atom chain types.
# Marking per-residue atom chain types.
#   (Residues lacking connect0/connect1 -
#    these don't have chain types marked:
#
# 	res	total affected
#
# 	CTHR	8
# 	NHID	8
#   )
#  (no restraints)
# 	Quit
#
# Exiting LEaP: Errors = 0; Warnings = 0; Notes = 0.
# Skipping 280: 1.2
# Now doing run 280: 1.25
# -I: Adding /cm/shared/package/amber/20_v2/dat/leap/prep to search path.
# -I: Adding /cm/shared/package/amber/20_v2/dat/leap/lib to search path.
# -I: Adding /cm/shared/package/amber/20_v2/dat/leap/parm to search path.
# -I: Adding /cm/shared/package/amber/20_v2/dat/leap/cmd to search path.
# -f: Source 1.25/resource/tleap_script.in.
#
# Welcome to LEaP!
# (no leaprc in search path)
# Sourcing: ./1.25/resource/tleap_script.in
# ----- Source: /cm/shared/package/amber/20_v2/dat/leap/cmd/leaprc.protein.ff19SB
# ----- Source of /cm/shared/package/amber/20_v2/dat/leap/cmd/leaprc.protein.ff19SB done
# Log file: ./leap.log
# Loading parameters: /cm/shared/package/amber/20_v2/dat/leap/parm/parm19.dat
# Reading title:
# PARM99 + frcmod.ff99SB + frcmod.parmbsc0 + OL3 for RNA + ff19SB
# Loading parameters: /cm/shared/package/amber/20_v2/dat/leap/parm/frcmod.ff19SB
# Reading force field modification type file (frcmod)
# Reading title:
# ff19SB AA-specific backbone CMAPs for protein 07/25/2019
# Loading library: /cm/shared/package/amber/20_v2/dat/leap/lib/amino19.lib
# Loading library: /cm/shared/package/amber/20_v2/dat/leap/lib/aminoct12.lib
# Loading library: /cm/shared/package/amber/20_v2/dat/leap/lib/aminont12.lib
# Loading PDB file: ./1.25/resource/1.25_cleaned.pdb
#   Added missing heavy atom: .R<CTHR 29>.A<OXT 15>
#   Added missing heavy atom: .R<CTHR 58>.A<OXT 15>
#   Added missing heavy atom: .R<CTHR 87>.A<OXT 15>
#   Added missing heavy atom: .R<CTHR 116>.A<OXT 15>
#   Added missing heavy atom: .R<CTHR 145>.A<OXT 15>
#   Added missing heavy atom: .R<CTHR 174>.A<OXT 15>
#   Added missing heavy atom: .R<CTHR 203>.A<OXT 15>
#   Added missing heavy atom: .R<CTHR 232>.A<OXT 15>
#   total atoms in file: 3744
#   Leap added 24 missing atoms according to residue templates:
#        8 Heavy
#        16 H / lone pairs
# Box dimensions:  34.029200 108.774000 72.520000
# Checking Unit.
# Building topology.
# Building atom parameters.
# Building bond parameters.
# Building angle parameters.
# Building proper torsion parameters.
# Building improper torsion parameters.
#  total 904 improper torsions applied
# Building H-Bond parameters.
# Incorporating Non-Bonded adjustments.
# Not Marking per-residue atom chain types.
# Marking per-residue atom chain types.
#   (Residues lacking connect0/connect1 -
#    these don't have chain types marked:
#
# 	res	total affected
#
# 	CTHR	8
# 	NHID	8
#   )
#  (no restraints)
# 	Quit
#
# Exiting LEaP: Errors = 0; Warnings = 0; Notes = 0.
# Skipping 280: 1.3
# Now doing run 280: 1.35
# -I: Adding /cm/shared/package/amber/20_v2/dat/leap/prep to search path.
# -I: Adding /cm/shared/package/amber/20_v2/dat/leap/lib to search path.
# -I: Adding /cm/shared/package/amber/20_v2/dat/leap/parm to search path.
# -I: Adding /cm/shared/package/amber/20_v2/dat/leap/cmd to search path.
# -f: Source 1.35/resource/tleap_script.in.
#
# Welcome to LEaP!
# (no leaprc in search path)
# Sourcing: ./1.35/resource/tleap_script.in
# ----- Source: /cm/shared/package/amber/20_v2/dat/leap/cmd/leaprc.protein.ff19SB
# ----- Source of /cm/shared/package/amber/20_v2/dat/leap/cmd/leaprc.protein.ff19SB done
# Log file: ./leap.log
# Loading parameters: /cm/shared/package/amber/20_v2/dat/leap/parm/parm19.dat
# Reading title:
# PARM99 + frcmod.ff99SB + frcmod.parmbsc0 + OL3 for RNA + ff19SB
# Loading parameters: /cm/shared/package/amber/20_v2/dat/leap/parm/frcmod.ff19SB
# Reading force field modification type file (frcmod)
# Reading title:
# ff19SB AA-specific backbone CMAPs for protein 07/25/2019
# Loading library: /cm/shared/package/amber/20_v2/dat/leap/lib/amino19.lib
# Loading library: /cm/shared/package/amber/20_v2/dat/leap/lib/aminoct12.lib
# Loading library: /cm/shared/package/amber/20_v2/dat/leap/lib/aminont12.lib
# Loading PDB file: ./1.35/resource/1.35_cleaned.pdb
#   Added missing heavy atom: .R<CTHR 29>.A<OXT 15>
#   Added missing heavy atom: .R<CTHR 58>.A<OXT 15>
#   Added missing heavy atom: .R<CTHR 87>.A<OXT 15>
#   Added missing heavy atom: .R<CTHR 116>.A<OXT 15>
#   Added missing heavy atom: .R<CTHR 145>.A<OXT 15>
#   Added missing heavy atom: .R<CTHR 174>.A<OXT 15>
#   Added missing heavy atom: .R<CTHR 203>.A<OXT 15>
#   Added missing heavy atom: .R<CTHR 232>.A<OXT 15>
#   total atoms in file: 3744
#   Leap added 24 missing atoms according to residue templates:
#        8 Heavy
#        16 H / lone pairs
# Box dimensions:  34.029200 108.774000 73.520000
# Checking Unit.
# Building topology.
# Building atom parameters.
# Building bond parameters.
# Building angle parameters.
# Building proper torsion parameters.
# Building improper torsion parameters.
#  total 904 improper torsions applied
# Building H-Bond parameters.
# Incorporating Non-Bonded adjustments.
# Not Marking per-residue atom chain types.
# Marking per-residue atom chain types.
#   (Residues lacking connect0/connect1 -
#    these don't have chain types marked:
#
# 	res	total affected
#
# 	CTHR	8
# 	NHID	8
#   )
#  (no restraints)
# 	Quit
#
# Exiting LEaP: Errors = 0; Warnings = 0; Notes = 0.
# Skipping 280: 1.4
# Now doing run 280: 1.45
# -I: Adding /cm/shared/package/amber/20_v2/dat/leap/prep to search path.
# -I: Adding /cm/shared/package/amber/20_v2/dat/leap/lib to search path.
# -I: Adding /cm/shared/package/amber/20_v2/dat/leap/parm to search path.
# -I: Adding /cm/shared/package/amber/20_v2/dat/leap/cmd to search path.
# -f: Source 1.45/resource/tleap_script.in.
#
# Welcome to LEaP!
# (no leaprc in search path)
# Sourcing: ./1.45/resource/tleap_script.in
# ----- Source: /cm/shared/package/amber/20_v2/dat/leap/cmd/leaprc.protein.ff19SB
# ----- Source of /cm/shared/package/amber/20_v2/dat/leap/cmd/leaprc.protein.ff19SB done
# Log file: ./leap.log
# Loading parameters: /cm/shared/package/amber/20_v2/dat/leap/parm/parm19.dat
# Reading title:
# PARM99 + frcmod.ff99SB + frcmod.parmbsc0 + OL3 for RNA + ff19SB
# Loading parameters: /cm/shared/package/amber/20_v2/dat/leap/parm/frcmod.ff19SB
# Reading force field modification type file (frcmod)
# Reading title:
# ff19SB AA-specific backbone CMAPs for protein 07/25/2019
# Loading library: /cm/shared/package/amber/20_v2/dat/leap/lib/amino19.lib
# Loading library: /cm/shared/package/amber/20_v2/dat/leap/lib/aminoct12.lib
# Loading library: /cm/shared/package/amber/20_v2/dat/leap/lib/aminont12.lib
# Loading PDB file: ./1.45/resource/1.45_cleaned.pdb
#   Added missing heavy atom: .R<CTHR 29>.A<OXT 15>
#   Added missing heavy atom: .R<CTHR 58>.A<OXT 15>
#   Added missing heavy atom: .R<CTHR 87>.A<OXT 15>
#   Added missing heavy atom: .R<CTHR 116>.A<OXT 15>
#   Added missing heavy atom: .R<CTHR 145>.A<OXT 15>
#   Added missing heavy atom: .R<CTHR 174>.A<OXT 15>
#   Added missing heavy atom: .R<CTHR 203>.A<OXT 15>
#   Added missing heavy atom: .R<CTHR 232>.A<OXT 15>
#   total atoms in file: 3744
#   Leap added 24 missing atoms according to residue templates:
#        8 Heavy
#        16 H / lone pairs
# Box dimensions:  34.029200 108.774000 74.520000
# Checking Unit.
# Building topology.
# Building atom parameters.
# Building bond parameters.
# Building angle parameters.
# Building proper torsion parameters.
# Building improper torsion parameters.
#  total 904 improper torsions applied
# Building H-Bond parameters.
# Incorporating Non-Bonded adjustments.
# Not Marking per-residue atom chain types.
# Marking per-residue atom chain types.
#   (Residues lacking connect0/connect1 -
#    these don't have chain types marked:
#
# 	res	total affected
#
# 	CTHR	8
# 	NHID	8
#   )
#  (no restraints)
# 	Quit
#
# Exiting LEaP: Errors = 0; Warnings = 0; Notes = 0.
# Skipping 280: 1.5
# Now doing run 280: 1.55
# -I: Adding /cm/shared/package/amber/20_v2/dat/leap/prep to search path.
# -I: Adding /cm/shared/package/amber/20_v2/dat/leap/lib to search path.
# -I: Adding /cm/shared/package/amber/20_v2/dat/leap/parm to search path.
# -I: Adding /cm/shared/package/amber/20_v2/dat/leap/cmd to search path.
# -f: Source 1.55/resource/tleap_script.in.
#
# Welcome to LEaP!
# (no leaprc in search path)
# Sourcing: ./1.55/resource/tleap_script.in
# ----- Source: /cm/shared/package/amber/20_v2/dat/leap/cmd/leaprc.protein.ff19SB
# ----- Source of /cm/shared/package/amber/20_v2/dat/leap/cmd/leaprc.protein.ff19SB done
# Log file: ./leap.log
# Loading parameters: /cm/shared/package/amber/20_v2/dat/leap/parm/parm19.dat
# Reading title:
# PARM99 + frcmod.ff99SB + frcmod.parmbsc0 + OL3 for RNA + ff19SB
# Loading parameters: /cm/shared/package/amber/20_v2/dat/leap/parm/frcmod.ff19SB
# Reading force field modification type file (frcmod)
# Reading title:
# ff19SB AA-specific backbone CMAPs for protein 07/25/2019
# Loading library: /cm/shared/package/amber/20_v2/dat/leap/lib/amino19.lib
# Loading library: /cm/shared/package/amber/20_v2/dat/leap/lib/aminoct12.lib
# Loading library: /cm/shared/package/amber/20_v2/dat/leap/lib/aminont12.lib
# Loading PDB file: ./1.55/resource/1.55_cleaned.pdb
#   Added missing heavy atom: .R<CTHR 29>.A<OXT 15>
#   Added missing heavy atom: .R<CTHR 58>.A<OXT 15>
#   Added missing heavy atom: .R<CTHR 87>.A<OXT 15>
#   Added missing heavy atom: .R<CTHR 116>.A<OXT 15>
#   Added missing heavy atom: .R<CTHR 145>.A<OXT 15>
#   Added missing heavy atom: .R<CTHR 174>.A<OXT 15>
#   Added missing heavy atom: .R<CTHR 203>.A<OXT 15>
#   Added missing heavy atom: .R<CTHR 232>.A<OXT 15>
#   total atoms in file: 3744
#   Leap added 24 missing atoms according to residue templates:
#        8 Heavy
#        16 H / lone pairs
# Box dimensions:  34.029200 108.774000 75.520000
# Checking Unit.
# Building topology.
# Building atom parameters.
# Building bond parameters.
# Building angle parameters.
# Building proper torsion parameters.
# Building improper torsion parameters.
#  total 904 improper torsions applied
# Building H-Bond parameters.
# Incorporating Non-Bonded adjustments.
# Not Marking per-residue atom chain types.
# Marking per-residue atom chain types.
#   (Residues lacking connect0/connect1 -
#    these don't have chain types marked:
#
# 	res	total affected
#
# 	CTHR	8
# 	NHID	8
#   )
#  (no restraints)
# 	Quit
#
# Exiting LEaP: Errors = 0; Warnings = 0; Notes = 0.
# Skipping 280: 1.6
# Now doing run 280: 1.65
# -I: Adding /cm/shared/package/amber/20_v2/dat/leap/prep to search path.
# -I: Adding /cm/shared/package/amber/20_v2/dat/leap/lib to search path.
# -I: Adding /cm/shared/package/amber/20_v2/dat/leap/parm to search path.
# -I: Adding /cm/shared/package/amber/20_v2/dat/leap/cmd to search path.
# -f: Source 1.65/resource/tleap_script.in.
#
# Welcome to LEaP!
# (no leaprc in search path)
# Sourcing: ./1.65/resource/tleap_script.in
# ----- Source: /cm/shared/package/amber/20_v2/dat/leap/cmd/leaprc.protein.ff19SB
# ----- Source of /cm/shared/package/amber/20_v2/dat/leap/cmd/leaprc.protein.ff19SB done
# Log file: ./leap.log
# Loading parameters: /cm/shared/package/amber/20_v2/dat/leap/parm/parm19.dat
# Reading title:
# PARM99 + frcmod.ff99SB + frcmod.parmbsc0 + OL3 for RNA + ff19SB
# Loading parameters: /cm/shared/package/amber/20_v2/dat/leap/parm/frcmod.ff19SB
# Reading force field modification type file (frcmod)
# Reading title:
# ff19SB AA-specific backbone CMAPs for protein 07/25/2019
# Loading library: /cm/shared/package/amber/20_v2/dat/leap/lib/amino19.lib
# Loading library: /cm/shared/package/amber/20_v2/dat/leap/lib/aminoct12.lib
# Loading library: /cm/shared/package/amber/20_v2/dat/leap/lib/aminont12.lib
# Loading PDB file: ./1.65/resource/1.65_cleaned.pdb
#   Added missing heavy atom: .R<CTHR 29>.A<OXT 15>
#   Added missing heavy atom: .R<CTHR 58>.A<OXT 15>
#   Added missing heavy atom: .R<CTHR 87>.A<OXT 15>
#   Added missing heavy atom: .R<CTHR 116>.A<OXT 15>
#   Added missing heavy atom: .R<CTHR 145>.A<OXT 15>
#   Added missing heavy atom: .R<CTHR 174>.A<OXT 15>
#   Added missing heavy atom: .R<CTHR 203>.A<OXT 15>
#   Added missing heavy atom: .R<CTHR 232>.A<OXT 15>
#   total atoms in file: 3744
#   Leap added 24 missing atoms according to residue templates:
#        8 Heavy
#        16 H / lone pairs
# Box dimensions:  34.029200 108.774000 76.520000
# Checking Unit.
# Building topology.
# Building atom parameters.
# Building bond parameters.
# Building angle parameters.
# Building proper torsion parameters.
# Building improper torsion parameters.
#  total 904 improper torsions applied
# Building H-Bond parameters.
# Incorporating Non-Bonded adjustments.
# Not Marking per-residue atom chain types.
# Marking per-residue atom chain types.
#   (Residues lacking connect0/connect1 -
#    these don't have chain types marked:
#
# 	res	total affected
#
# 	CTHR	8
# 	NHID	8
#   )
#  (no restraints)
# 	Quit
#
# Exiting LEaP: Errors = 0; Warnings = 0; Notes = 0.
# Skipping 280: 1.7
# Now doing run 280: 1.75
# -I: Adding /cm/shared/package/amber/20_v2/dat/leap/prep to search path.
# -I: Adding /cm/shared/package/amber/20_v2/dat/leap/lib to search path.
# -I: Adding /cm/shared/package/amber/20_v2/dat/leap/parm to search path.
# -I: Adding /cm/shared/package/amber/20_v2/dat/leap/cmd to search path.
# -f: Source 1.75/resource/tleap_script.in.
#
# Welcome to LEaP!
# (no leaprc in search path)
# Sourcing: ./1.75/resource/tleap_script.in
# ----- Source: /cm/shared/package/amber/20_v2/dat/leap/cmd/leaprc.protein.ff19SB
# ----- Source of /cm/shared/package/amber/20_v2/dat/leap/cmd/leaprc.protein.ff19SB done
# Log file: ./leap.log
# Loading parameters: /cm/shared/package/amber/20_v2/dat/leap/parm/parm19.dat
# Reading title:
# PARM99 + frcmod.ff99SB + frcmod.parmbsc0 + OL3 for RNA + ff19SB
# Loading parameters: /cm/shared/package/amber/20_v2/dat/leap/parm/frcmod.ff19SB
# Reading force field modification type file (frcmod)
# Reading title:
# ff19SB AA-specific backbone CMAPs for protein 07/25/2019
# Loading library: /cm/shared/package/amber/20_v2/dat/leap/lib/amino19.lib
# Loading library: /cm/shared/package/amber/20_v2/dat/leap/lib/aminoct12.lib
# Loading library: /cm/shared/package/amber/20_v2/dat/leap/lib/aminont12.lib
# Loading PDB file: ./1.75/resource/1.75_cleaned.pdb
#   Added missing heavy atom: .R<CTHR 29>.A<OXT 15>
#   Added missing heavy atom: .R<CTHR 58>.A<OXT 15>
#   Added missing heavy atom: .R<CTHR 87>.A<OXT 15>
#   Added missing heavy atom: .R<CTHR 116>.A<OXT 15>
#   Added missing heavy atom: .R<CTHR 145>.A<OXT 15>
#   Added missing heavy atom: .R<CTHR 174>.A<OXT 15>
#   Added missing heavy atom: .R<CTHR 203>.A<OXT 15>
#   Added missing heavy atom: .R<CTHR 232>.A<OXT 15>
#   total atoms in file: 3744
#   Leap added 24 missing atoms according to residue templates:
#        8 Heavy
#        16 H / lone pairs
# Box dimensions:  34.029200 108.774000 77.520000
# Checking Unit.
# Building topology.
# Building atom parameters.
# Building bond parameters.
# Building angle parameters.
# Building proper torsion parameters.
# Building improper torsion parameters.
#  total 904 improper torsions applied
# Building H-Bond parameters.
# Incorporating Non-Bonded adjustments.
# Not Marking per-residue atom chain types.
# Marking per-residue atom chain types.
#   (Residues lacking connect0/connect1 -
#    these don't have chain types marked:
#
# 	res	total affected
#
# 	CTHR	8
# 	NHID	8
#   )
#  (no restraints)
# 	Quit
#
# Exiting LEaP: Errors = 0; Warnings = 0; Notes = 0.
# Skipping 280: 1.8
# Now doing run 280: 1.85
# -I: Adding /cm/shared/package/amber/20_v2/dat/leap/prep to search path.
# -I: Adding /cm/shared/package/amber/20_v2/dat/leap/lib to search path.
# -I: Adding /cm/shared/package/amber/20_v2/dat/leap/parm to search path.
# -I: Adding /cm/shared/package/amber/20_v2/dat/leap/cmd to search path.
# -f: Source 1.85/resource/tleap_script.in.
#
# Welcome to LEaP!
# (no leaprc in search path)
# Sourcing: ./1.85/resource/tleap_script.in
# ----- Source: /cm/shared/package/amber/20_v2/dat/leap/cmd/leaprc.protein.ff19SB
# ----- Source of /cm/shared/package/amber/20_v2/dat/leap/cmd/leaprc.protein.ff19SB done
# Log file: ./leap.log
# Loading parameters: /cm/shared/package/amber/20_v2/dat/leap/parm/parm19.dat
# Reading title:
# PARM99 + frcmod.ff99SB + frcmod.parmbsc0 + OL3 for RNA + ff19SB
# Loading parameters: /cm/shared/package/amber/20_v2/dat/leap/parm/frcmod.ff19SB
# Reading force field modification type file (frcmod)
# Reading title:
# ff19SB AA-specific backbone CMAPs for protein 07/25/2019
# Loading library: /cm/shared/package/amber/20_v2/dat/leap/lib/amino19.lib
# Loading library: /cm/shared/package/amber/20_v2/dat/leap/lib/aminoct12.lib
# Loading library: /cm/shared/package/amber/20_v2/dat/leap/lib/aminont12.lib
# Loading PDB file: ./1.85/resource/1.85_cleaned.pdb
#   Added missing heavy atom: .R<CTHR 29>.A<OXT 15>
#   Added missing heavy atom: .R<CTHR 58>.A<OXT 15>
#   Added missing heavy atom: .R<CTHR 87>.A<OXT 15>
#   Added missing heavy atom: .R<CTHR 116>.A<OXT 15>
#   Added missing heavy atom: .R<CTHR 145>.A<OXT 15>
#   Added missing heavy atom: .R<CTHR 174>.A<OXT 15>
#   Added missing heavy atom: .R<CTHR 203>.A<OXT 15>
#   Added missing heavy atom: .R<CTHR 232>.A<OXT 15>
#   total atoms in file: 3744
#   Leap added 24 missing atoms according to residue templates:
#        8 Heavy
#        16 H / lone pairs
# Box dimensions:  34.029200 108.774000 78.520000
# Checking Unit.
# Building topology.
# Building atom parameters.
# Building bond parameters.
# Building angle parameters.
# Building proper torsion parameters.
# Building improper torsion parameters.
#  total 904 improper torsions applied
# Building H-Bond parameters.
# Incorporating Non-Bonded adjustments.
# Not Marking per-residue atom chain types.
# Marking per-residue atom chain types.
#   (Residues lacking connect0/connect1 -
#    these don't have chain types marked:
#
# 	res	total affected
#
# 	CTHR	8
# 	NHID	8
#   )
#  (no restraints)
# 	Quit
#
# Exiting LEaP: Errors = 0; Warnings = 0; Notes = 0.
# Skipping 280: 1.9
# Now doing run 280: 1.95
# -I: Adding /cm/shared/package/amber/20_v2/dat/leap/prep to search path.
# -I: Adding /cm/shared/package/amber/20_v2/dat/leap/lib to search path.
# -I: Adding /cm/shared/package/amber/20_v2/dat/leap/parm to search path.
# -I: Adding /cm/shared/package/amber/20_v2/dat/leap/cmd to search path.
# -f: Source 1.95/resource/tleap_script.in.
#
# Welcome to LEaP!
# (no leaprc in search path)
# Sourcing: ./1.95/resource/tleap_script.in
# ----- Source: /cm/shared/package/amber/20_v2/dat/leap/cmd/leaprc.protein.ff19SB
# ----- Source of /cm/shared/package/amber/20_v2/dat/leap/cmd/leaprc.protein.ff19SB done
# Log file: ./leap.log
# Loading parameters: /cm/shared/package/amber/20_v2/dat/leap/parm/parm19.dat
# Reading title:
# PARM99 + frcmod.ff99SB + frcmod.parmbsc0 + OL3 for RNA + ff19SB
# Loading parameters: /cm/shared/package/amber/20_v2/dat/leap/parm/frcmod.ff19SB
# Reading force field modification type file (frcmod)
# Reading title:
# ff19SB AA-specific backbone CMAPs for protein 07/25/2019
# Loading library: /cm/shared/package/amber/20_v2/dat/leap/lib/amino19.lib
# Loading library: /cm/shared/package/amber/20_v2/dat/leap/lib/aminoct12.lib
# Loading library: /cm/shared/package/amber/20_v2/dat/leap/lib/aminont12.lib
# Loading PDB file: ./1.95/resource/1.95_cleaned.pdb
#   Added missing heavy atom: .R<CTHR 29>.A<OXT 15>
#   Added missing heavy atom: .R<CTHR 58>.A<OXT 15>
#   Added missing heavy atom: .R<CTHR 87>.A<OXT 15>
#   Added missing heavy atom: .R<CTHR 116>.A<OXT 15>
#   Added missing heavy atom: .R<CTHR 145>.A<OXT 15>
#   Added missing heavy atom: .R<CTHR 174>.A<OXT 15>
#   Added missing heavy atom: .R<CTHR 203>.A<OXT 15>
#   Added missing heavy atom: .R<CTHR 232>.A<OXT 15>
#   total atoms in file: 3744
#   Leap added 24 missing atoms according to residue templates:
#        8 Heavy
#        16 H / lone pairs
# Box dimensions:  34.029200 108.774000 79.520000
# Checking Unit.
# Building topology.
# Building atom parameters.
# Building bond parameters.
# Building angle parameters.
# Building proper torsion parameters.
# Building improper torsion parameters.
#  total 904 improper torsions applied
# Building H-Bond parameters.
# Incorporating Non-Bonded adjustments.
# Not Marking per-residue atom chain types.
# Marking per-residue atom chain types.
#   (Residues lacking connect0/connect1 -
#    these don't have chain types marked:
#
# 	res	total affected
#
# 	CTHR	8
# 	NHID	8
#   )
#  (no restraints)
# 	Quit
#
# Exiting LEaP: Errors = 0; Warnings = 0; Notes = 0.
# Skipping 280: 2.0
# Now doing run 280: 2.05
# -I: Adding /cm/shared/package/amber/20_v2/dat/leap/prep to search path.
# -I: Adding /cm/shared/package/amber/20_v2/dat/leap/lib to search path.
# -I: Adding /cm/shared/package/amber/20_v2/dat/leap/parm to search path.
# -I: Adding /cm/shared/package/amber/20_v2/dat/leap/cmd to search path.
# -f: Source 2.05/resource/tleap_script.in.
#
# Welcome to LEaP!
# (no leaprc in search path)
# Sourcing: ./2.05/resource/tleap_script.in
# ----- Source: /cm/shared/package/amber/20_v2/dat/leap/cmd/leaprc.protein.ff19SB
# ----- Source of /cm/shared/package/amber/20_v2/dat/leap/cmd/leaprc.protein.ff19SB done
# Log file: ./leap.log
# Loading parameters: /cm/shared/package/amber/20_v2/dat/leap/parm/parm19.dat
# Reading title:
# PARM99 + frcmod.ff99SB + frcmod.parmbsc0 + OL3 for RNA + ff19SB
# Loading parameters: /cm/shared/package/amber/20_v2/dat/leap/parm/frcmod.ff19SB
# Reading force field modification type file (frcmod)
# Reading title:
# ff19SB AA-specific backbone CMAPs for protein 07/25/2019
# Loading library: /cm/shared/package/amber/20_v2/dat/leap/lib/amino19.lib
# Loading library: /cm/shared/package/amber/20_v2/dat/leap/lib/aminoct12.lib
# Loading library: /cm/shared/package/amber/20_v2/dat/leap/lib/aminont12.lib
# Loading PDB file: ./2.05/resource/2.05_cleaned.pdb
#   Added missing heavy atom: .R<CTHR 29>.A<OXT 15>
#   Added missing heavy atom: .R<CTHR 58>.A<OXT 15>
#   Added missing heavy atom: .R<CTHR 87>.A<OXT 15>
#   Added missing heavy atom: .R<CTHR 116>.A<OXT 15>
#   Added missing heavy atom: .R<CTHR 145>.A<OXT 15>
#   Added missing heavy atom: .R<CTHR 174>.A<OXT 15>
#   Added missing heavy atom: .R<CTHR 203>.A<OXT 15>
#   Added missing heavy atom: .R<CTHR 232>.A<OXT 15>
#   total atoms in file: 3744
#   Leap added 24 missing atoms according to residue templates:
#        8 Heavy
#        16 H / lone pairs
# Box dimensions:  34.029200 108.774000 80.520000
# Checking Unit.
# Building topology.
# Building atom parameters.
# Building bond parameters.
# Building angle parameters.
# Building proper torsion parameters.
# Building improper torsion parameters.
#  total 904 improper torsions applied
# Building H-Bond parameters.
# Incorporating Non-Bonded adjustments.
# Not Marking per-residue atom chain types.
# Marking per-residue atom chain types.
#   (Residues lacking connect0/connect1 -
#    these don't have chain types marked:
#
# 	res	total affected
#
# 	CTHR	8
# 	NHID	8
#   )
#  (no restraints)
# 	Quit
#
# Exiting LEaP: Errors = 0; Warnings = 0; Notes = 0.
# Skipping 280: 2.1
# Now doing run 280: 2.15
# -I: Adding /cm/shared/package/amber/20_v2/dat/leap/prep to search path.
# -I: Adding /cm/shared/package/amber/20_v2/dat/leap/lib to search path.
# -I: Adding /cm/shared/package/amber/20_v2/dat/leap/parm to search path.
# -I: Adding /cm/shared/package/amber/20_v2/dat/leap/cmd to search path.
# -f: Source 2.15/resource/tleap_script.in.
#
# Welcome to LEaP!
# (no leaprc in search path)
# Sourcing: ./2.15/resource/tleap_script.in
# ----- Source: /cm/shared/package/amber/20_v2/dat/leap/cmd/leaprc.protein.ff19SB
# ----- Source of /cm/shared/package/amber/20_v2/dat/leap/cmd/leaprc.protein.ff19SB done
# Log file: ./leap.log
# Loading parameters: /cm/shared/package/amber/20_v2/dat/leap/parm/parm19.dat
# Reading title:
# PARM99 + frcmod.ff99SB + frcmod.parmbsc0 + OL3 for RNA + ff19SB
# Loading parameters: /cm/shared/package/amber/20_v2/dat/leap/parm/frcmod.ff19SB
# Reading force field modification type file (frcmod)
# Reading title:
# ff19SB AA-specific backbone CMAPs for protein 07/25/2019
# Loading library: /cm/shared/package/amber/20_v2/dat/leap/lib/amino19.lib
# Loading library: /cm/shared/package/amber/20_v2/dat/leap/lib/aminoct12.lib
# Loading library: /cm/shared/package/amber/20_v2/dat/leap/lib/aminont12.lib
# Loading PDB file: ./2.15/resource/2.15_cleaned.pdb
#   Added missing heavy atom: .R<CTHR 29>.A<OXT 15>
#   Added missing heavy atom: .R<CTHR 58>.A<OXT 15>
#   Added missing heavy atom: .R<CTHR 87>.A<OXT 15>
#   Added missing heavy atom: .R<CTHR 116>.A<OXT 15>
#   Added missing heavy atom: .R<CTHR 145>.A<OXT 15>
#   Added missing heavy atom: .R<CTHR 174>.A<OXT 15>
#   Added missing heavy atom: .R<CTHR 203>.A<OXT 15>
#   Added missing heavy atom: .R<CTHR 232>.A<OXT 15>
#   total atoms in file: 3744
#   Leap added 24 missing atoms according to residue templates:
#        8 Heavy
#        16 H / lone pairs
# Box dimensions:  34.029200 108.774000 81.520000
# Checking Unit.
# Building topology.
# Building atom parameters.
# Building bond parameters.
# Building angle parameters.
# Building proper torsion parameters.
# Building improper torsion parameters.
#  total 904 improper torsions applied
# Building H-Bond parameters.
# Incorporating Non-Bonded adjustments.
# Not Marking per-residue atom chain types.
# Marking per-residue atom chain types.
#   (Residues lacking connect0/connect1 -
#    these don't have chain types marked:
#
# 	res	total affected
#
# 	CTHR	8
# 	NHID	8
#   )
#  (no restraints)
# 	Quit
#
# Exiting LEaP: Errors = 0; Warnings = 0; Notes = 0.
# Skipping 280: 2.2
# Now doing run 280: 2.25
# -I: Adding /cm/shared/package/amber/20_v2/dat/leap/prep to search path.
# -I: Adding /cm/shared/package/amber/20_v2/dat/leap/lib to search path.
# -I: Adding /cm/shared/package/amber/20_v2/dat/leap/parm to search path.
# -I: Adding /cm/shared/package/amber/20_v2/dat/leap/cmd to search path.
# -f: Source 2.25/resource/tleap_script.in.
#
# Welcome to LEaP!
# (no leaprc in search path)
# Sourcing: ./2.25/resource/tleap_script.in
# ----- Source: /cm/shared/package/amber/20_v2/dat/leap/cmd/leaprc.protein.ff19SB
# ----- Source of /cm/shared/package/amber/20_v2/dat/leap/cmd/leaprc.protein.ff19SB done
# Log file: ./leap.log
# Loading parameters: /cm/shared/package/amber/20_v2/dat/leap/parm/parm19.dat
# Reading title:
# PARM99 + frcmod.ff99SB + frcmod.parmbsc0 + OL3 for RNA + ff19SB
# Loading parameters: /cm/shared/package/amber/20_v2/dat/leap/parm/frcmod.ff19SB
# Reading force field modification type file (frcmod)
# Reading title:
# ff19SB AA-specific backbone CMAPs for protein 07/25/2019
# Loading library: /cm/shared/package/amber/20_v2/dat/leap/lib/amino19.lib
# Loading library: /cm/shared/package/amber/20_v2/dat/leap/lib/aminoct12.lib
# Loading library: /cm/shared/package/amber/20_v2/dat/leap/lib/aminont12.lib
# Loading PDB file: ./2.25/resource/2.25_cleaned.pdb
#   Added missing heavy atom: .R<CTHR 29>.A<OXT 15>
#   Added missing heavy atom: .R<CTHR 58>.A<OXT 15>
#   Added missing heavy atom: .R<CTHR 87>.A<OXT 15>
#   Added missing heavy atom: .R<CTHR 116>.A<OXT 15>
#   Added missing heavy atom: .R<CTHR 145>.A<OXT 15>
#   Added missing heavy atom: .R<CTHR 174>.A<OXT 15>
#   Added missing heavy atom: .R<CTHR 203>.A<OXT 15>
#   Added missing heavy atom: .R<CTHR 232>.A<OXT 15>
#   total atoms in file: 3744
# ...
# Loading library: /cm/shared/package/amber/20_v2/dat/leap/lib/aminoct12.lib
# Loading library: /cm/shared/package/amber/20_v2/dat/leap/lib/aminont12.lib
# Loading PDB file: ./6.35/resource/6.35_cleaned.pdb
#   Added missing heavy atom: .R<CTHR 29>.A<OXT 15>
#   Added missing heavy atom: .R<CTHR 58>.A<OXT 15>
#   Added missing heavy atom: .R<CTHR 87>.A<OXT 15>
#   Added missing heavy atom: .R<CTHR 116>.A<OXT 15>
#   Added missing heavy atom: .R<CTHR 145>.A<OXT 15>
#   Added missing heavy atom: .R<CTHR 174>.A<OXT 15>
#   Added missing heavy atom: .R<CTHR 203>.A<OXT 15>
#   Added missing heavy atom: .R<CTHR 232>.A<OXT 15>
#   total atoms in file: 3744
#   Leap added 24 missing atoms according to residue templates:
#        8 Heavy
#        16 H / lone pairs
# Box dimensions:  34.029200 108.774000 123.520000
# Checking Unit.
# Building topology.
# Building atom parameters.
# Building bond parameters.
# Building angle parameters.
# Building proper torsion parameters.
# Building improper torsion parameters.
#  total 904 improper torsions applied
# Building H-Bond parameters.
# Incorporating Non-Bonded adjustments.
# Not Marking per-residue atom chain types.
# Marking per-residue atom chain types.
#   (Residues lacking connect0/connect1 -
#    these don't have chain types marked:
#
# 	res	total affected
#
# 	CTHR	8
# 	NHID	8
#   )
#  (no restraints)
# 	Quit
#
# Exiting LEaP: Errors = 0; Warnings = 0; Notes = 0.
# Skipping 320: 6.4
# Now doing run 320: 6.45
# -I: Adding /cm/shared/package/amber/20_v2/dat/leap/prep to search path.
# -I: Adding /cm/shared/package/amber/20_v2/dat/leap/lib to search path.
# -I: Adding /cm/shared/package/amber/20_v2/dat/leap/parm to search path.
# -I: Adding /cm/shared/package/amber/20_v2/dat/leap/cmd to search path.
# -f: Source 6.45/resource/tleap_script.in.
#
# Welcome to LEaP!
# (no leaprc in search path)
# Sourcing: ./6.45/resource/tleap_script.in
# ----- Source: /cm/shared/package/amber/20_v2/dat/leap/cmd/leaprc.protein.ff19SB
# ----- Source of /cm/shared/package/amber/20_v2/dat/leap/cmd/leaprc.protein.ff19SB done
# Log file: ./leap.log
# Loading parameters: /cm/shared/package/amber/20_v2/dat/leap/parm/parm19.dat
# Reading title:
# PARM99 + frcmod.ff99SB + frcmod.parmbsc0 + OL3 for RNA + ff19SB
# Loading parameters: /cm/shared/package/amber/20_v2/dat/leap/parm/frcmod.ff19SB
# Reading force field modification type file (frcmod)
# Reading title:
# ff19SB AA-specific backbone CMAPs for protein 07/25/2019
# Loading library: /cm/shared/package/amber/20_v2/dat/leap/lib/amino19.lib
# Loading library: /cm/shared/package/amber/20_v2/dat/leap/lib/aminoct12.lib
# Loading library: /cm/shared/package/amber/20_v2/dat/leap/lib/aminont12.lib
# Loading PDB file: ./6.45/resource/6.45_cleaned.pdb
#   Added missing heavy atom: .R<CTHR 29>.A<OXT 15>
#   Added missing heavy atom: .R<CTHR 58>.A<OXT 15>
#   Added missing heavy atom: .R<CTHR 87>.A<OXT 15>
#   Added missing heavy atom: .R<CTHR 116>.A<OXT 15>
#   Added missing heavy atom: .R<CTHR 145>.A<OXT 15>
#   Added missing heavy atom: .R<CTHR 174>.A<OXT 15>
#   Added missing heavy atom: .R<CTHR 203>.A<OXT 15>
#   Added missing heavy atom: .R<CTHR 232>.A<OXT 15>
#   total atoms in file: 3744
#   Leap added 24 missing atoms according to residue templates:
#        8 Heavy
#        16 H / lone pairs
# Box dimensions:  34.029200 108.774000 124.520000
# Checking Unit.
# Building topology.
# Building atom parameters.
# Building bond parameters.
# Building angle parameters.
# Building proper torsion parameters.
# Building improper torsion parameters.
#  total 904 improper torsions applied
# Building H-Bond parameters.
# Incorporating Non-Bonded adjustments.
# Not Marking per-residue atom chain types.
# Marking per-residue atom chain types.
#   (Residues lacking connect0/connect1 -
#    these don't have chain types marked:
#
# 	res	total affected
#
# 	CTHR	8
# 	NHID	8
#   )
#  (no restraints)
# 	Quit
#
# Exiting LEaP: Errors = 0; Warnings = 0; Notes = 0.
# Skipping 320: 6.5
# Now doing run 320: 6.55
# -I: Adding /cm/shared/package/amber/20_v2/dat/leap/prep to search path.
# -I: Adding /cm/shared/package/amber/20_v2/dat/leap/lib to search path.
# -I: Adding /cm/shared/package/amber/20_v2/dat/leap/parm to search path.
# -I: Adding /cm/shared/package/amber/20_v2/dat/leap/cmd to search path.
# -f: Source 6.55/resource/tleap_script.in.
#
# Welcome to LEaP!
# (no leaprc in search path)
# Sourcing: ./6.55/resource/tleap_script.in
# ----- Source: /cm/shared/package/amber/20_v2/dat/leap/cmd/leaprc.protein.ff19SB
# ----- Source of /cm/shared/package/amber/20_v2/dat/leap/cmd/leaprc.protein.ff19SB done
# Log file: ./leap.log
# Loading parameters: /cm/shared/package/amber/20_v2/dat/leap/parm/parm19.dat
# Reading title:
# PARM99 + frcmod.ff99SB + frcmod.parmbsc0 + OL3 for RNA + ff19SB
# Loading parameters: /cm/shared/package/amber/20_v2/dat/leap/parm/frcmod.ff19SB
# Reading force field modification type file (frcmod)
# Reading title:
# ff19SB AA-specific backbone CMAPs for protein 07/25/2019
# Loading library: /cm/shared/package/amber/20_v2/dat/leap/lib/amino19.lib
# Loading library: /cm/shared/package/amber/20_v2/dat/leap/lib/aminoct12.lib
# Loading library: /cm/shared/package/amber/20_v2/dat/leap/lib/aminont12.lib
# Loading PDB file: ./6.55/resource/6.55_cleaned.pdb
#   Added missing heavy atom: .R<CTHR 29>.A<OXT 15>
#   Added missing heavy atom: .R<CTHR 58>.A<OXT 15>
#   Added missing heavy atom: .R<CTHR 87>.A<OXT 15>
#   Added missing heavy atom: .R<CTHR 116>.A<OXT 15>
#   Added missing heavy atom: .R<CTHR 145>.A<OXT 15>
#   Added missing heavy atom: .R<CTHR 174>.A<OXT 15>
#   Added missing heavy atom: .R<CTHR 203>.A<OXT 15>
#   Added missing heavy atom: .R<CTHR 232>.A<OXT 15>
#   total atoms in file: 3744
#   Leap added 24 missing atoms according to residue templates:
#        8 Heavy
#        16 H / lone pairs
# Box dimensions:  34.029200 108.774000 125.520000
# Checking Unit.
# Building topology.
# Building atom parameters.
# Building bond parameters.
# Building angle parameters.
# Building proper torsion parameters.
# Building improper torsion parameters.
#  total 904 improper torsions applied
# Building H-Bond parameters.
# Incorporating Non-Bonded adjustments.
# Not Marking per-residue atom chain types.
# Marking per-residue atom chain types.
#   (Residues lacking connect0/connect1 -
#    these don't have chain types marked:
#
# 	res	total affected
#
# 	CTHR	8
# 	NHID	8
#   )
#  (no restraints)
# 	Quit
#
# Exiting LEaP: Errors = 0; Warnings = 0; Notes = 0.
# Skipping 320: 6.6
# Now doing run 320: 6.65
# -I: Adding /cm/shared/package/amber/20_v2/dat/leap/prep to search path.
# -I: Adding /cm/shared/package/amber/20_v2/dat/leap/lib to search path.
# -I: Adding /cm/shared/package/amber/20_v2/dat/leap/parm to search path.
# -I: Adding /cm/shared/package/amber/20_v2/dat/leap/cmd to search path.
# -f: Source 6.65/resource/tleap_script.in.
#
# Welcome to LEaP!
# (no leaprc in search path)
# Sourcing: ./6.65/resource/tleap_script.in
# ----- Source: /cm/shared/package/amber/20_v2/dat/leap/cmd/leaprc.protein.ff19SB
# ----- Source of /cm/shared/package/amber/20_v2/dat/leap/cmd/leaprc.protein.ff19SB done
# Log file: ./leap.log
# Loading parameters: /cm/shared/package/amber/20_v2/dat/leap/parm/parm19.dat
# Reading title:
# PARM99 + frcmod.ff99SB + frcmod.parmbsc0 + OL3 for RNA + ff19SB
# Loading parameters: /cm/shared/package/amber/20_v2/dat/leap/parm/frcmod.ff19SB
# Reading force field modification type file (frcmod)
# Reading title:
# ff19SB AA-specific backbone CMAPs for protein 07/25/2019
# Loading library: /cm/shared/package/amber/20_v2/dat/leap/lib/amino19.lib
# Loading library: /cm/shared/package/amber/20_v2/dat/leap/lib/aminoct12.lib
# Loading library: /cm/shared/package/amber/20_v2/dat/leap/lib/aminont12.lib
# Loading PDB file: ./6.65/resource/6.65_cleaned.pdb
#   Added missing heavy atom: .R<CTHR 29>.A<OXT 15>
#   Added missing heavy atom: .R<CTHR 58>.A<OXT 15>
#   Added missing heavy atom: .R<CTHR 87>.A<OXT 15>
#   Added missing heavy atom: .R<CTHR 116>.A<OXT 15>
#   Added missing heavy atom: .R<CTHR 145>.A<OXT 15>
#   Added missing heavy atom: .R<CTHR 174>.A<OXT 15>
#   Added missing heavy atom: .R<CTHR 203>.A<OXT 15>
#   Added missing heavy atom: .R<CTHR 232>.A<OXT 15>
#   total atoms in file: 3744
#   Leap added 24 missing atoms according to residue templates:
#        8 Heavy
#        16 H / lone pairs
# Box dimensions:  34.029200 108.774000 126.520000
# Checking Unit.
# Building topology.
# Building atom parameters.
# Building bond parameters.
# Building angle parameters.
# Building proper torsion parameters.
# Building improper torsion parameters.
#  total 904 improper torsions applied
# Building H-Bond parameters.
# Incorporating Non-Bonded adjustments.
# Not Marking per-residue atom chain types.
# Marking per-residue atom chain types.
#   (Residues lacking connect0/connect1 -
#    these don't have chain types marked:
#
# 	res	total affected
#
# 	CTHR	8
# 	NHID	8
#   )
#  (no restraints)
# 	Quit
#
# Exiting LEaP: Errors = 0; Warnings = 0; Notes = 0.
# Skipping 320: 6.7
# Now doing run 320: 6.75
# -I: Adding /cm/shared/package/amber/20_v2/dat/leap/prep to search path.
# -I: Adding /cm/shared/package/amber/20_v2/dat/leap/lib to search path.
# -I: Adding /cm/shared/package/amber/20_v2/dat/leap/parm to search path.
# -I: Adding /cm/shared/package/amber/20_v2/dat/leap/cmd to search path.
# -f: Source 6.75/resource/tleap_script.in.
#
# Welcome to LEaP!
# (no leaprc in search path)
# Sourcing: ./6.75/resource/tleap_script.in
# ----- Source: /cm/shared/package/amber/20_v2/dat/leap/cmd/leaprc.protein.ff19SB
# ----- Source of /cm/shared/package/amber/20_v2/dat/leap/cmd/leaprc.protein.ff19SB done
# Log file: ./leap.log
# Loading parameters: /cm/shared/package/amber/20_v2/dat/leap/parm/parm19.dat
# Reading title:
# PARM99 + frcmod.ff99SB + frcmod.parmbsc0 + OL3 for RNA + ff19SB
# Loading parameters: /cm/shared/package/amber/20_v2/dat/leap/parm/frcmod.ff19SB
# Reading force field modification type file (frcmod)
# Reading title:
# ff19SB AA-specific backbone CMAPs for protein 07/25/2019
# Loading library: /cm/shared/package/amber/20_v2/dat/leap/lib/amino19.lib
# Loading library: /cm/shared/package/amber/20_v2/dat/leap/lib/aminoct12.lib
# Loading library: /cm/shared/package/amber/20_v2/dat/leap/lib/aminont12.lib
# Loading PDB file: ./6.75/resource/6.75_cleaned.pdb
#   Added missing heavy atom: .R<CTHR 29>.A<OXT 15>
#   Added missing heavy atom: .R<CTHR 58>.A<OXT 15>
#   Added missing heavy atom: .R<CTHR 87>.A<OXT 15>
#   Added missing heavy atom: .R<CTHR 116>.A<OXT 15>
#   Added missing heavy atom: .R<CTHR 145>.A<OXT 15>
#   Added missing heavy atom: .R<CTHR 174>.A<OXT 15>
#   Added missing heavy atom: .R<CTHR 203>.A<OXT 15>
#   Added missing heavy atom: .R<CTHR 232>.A<OXT 15>
#   total atoms in file: 3744
#   Leap added 24 missing atoms according to residue templates:
#        8 Heavy
#        16 H / lone pairs
# Box dimensions:  34.029200 108.774000 127.520000
# Checking Unit.
# Building topology.
# Building atom parameters.
# Building bond parameters.
# Building angle parameters.
# Building proper torsion parameters.
# Building improper torsion parameters.
#  total 904 improper torsions applied
# Building H-Bond parameters.
# Incorporating Non-Bonded adjustments.
# Not Marking per-residue atom chain types.
# Marking per-residue atom chain types.
#   (Residues lacking connect0/connect1 -
#    these don't have chain types marked:
#
# 	res	total affected
#
# 	CTHR	8
# 	NHID	8
#   )
#  (no restraints)
# 	Quit
#
# Exiting LEaP: Errors = 0; Warnings = 0; Notes = 0.
# Skipping 320: 6.8
# Now doing run 320: 6.85
# -I: Adding /cm/shared/package/amber/20_v2/dat/leap/prep to search path.
# -I: Adding /cm/shared/package/amber/20_v2/dat/leap/lib to search path.
# -I: Adding /cm/shared/package/amber/20_v2/dat/leap/parm to search path.
# -I: Adding /cm/shared/package/amber/20_v2/dat/leap/cmd to search path.
# -f: Source 6.85/resource/tleap_script.in.
#
# Welcome to LEaP!
# (no leaprc in search path)
# Sourcing: ./6.85/resource/tleap_script.in
# ----- Source: /cm/shared/package/amber/20_v2/dat/leap/cmd/leaprc.protein.ff19SB
# ----- Source of /cm/shared/package/amber/20_v2/dat/leap/cmd/leaprc.protein.ff19SB done
# Log file: ./leap.log
# Loading parameters: /cm/shared/package/amber/20_v2/dat/leap/parm/parm19.dat
# Reading title:
# PARM99 + frcmod.ff99SB + frcmod.parmbsc0 + OL3 for RNA + ff19SB
# Loading parameters: /cm/shared/package/amber/20_v2/dat/leap/parm/frcmod.ff19SB
# Reading force field modification type file (frcmod)
# Reading title:
# ff19SB AA-specific backbone CMAPs for protein 07/25/2019
# Loading library: /cm/shared/package/amber/20_v2/dat/leap/lib/amino19.lib
# Loading library: /cm/shared/package/amber/20_v2/dat/leap/lib/aminoct12.lib
# Loading library: /cm/shared/package/amber/20_v2/dat/leap/lib/aminont12.lib
# Loading PDB file: ./6.85/resource/6.85_cleaned.pdb
#   Added missing heavy atom: .R<CTHR 29>.A<OXT 15>
#   Added missing heavy atom: .R<CTHR 58>.A<OXT 15>
#   Added missing heavy atom: .R<CTHR 87>.A<OXT 15>
#   Added missing heavy atom: .R<CTHR 116>.A<OXT 15>
#   Added missing heavy atom: .R<CTHR 145>.A<OXT 15>
#   Added missing heavy atom: .R<CTHR 174>.A<OXT 15>
#   Added missing heavy atom: .R<CTHR 203>.A<OXT 15>
#   Added missing heavy atom: .R<CTHR 232>.A<OXT 15>
#   total atoms in file: 3744
#   Leap added 24 missing atoms according to residue templates:
#        8 Heavy
#        16 H / lone pairs
# Box dimensions:  34.029200 108.774000 128.520000
# Checking Unit.
# Building topology.
# Building atom parameters.
# Building bond parameters.
# Building angle parameters.
# Building proper torsion parameters.
# Building improper torsion parameters.
#  total 904 improper torsions applied
# Building H-Bond parameters.
# Incorporating Non-Bonded adjustments.
# Not Marking per-residue atom chain types.
# Marking per-residue atom chain types.
#   (Residues lacking connect0/connect1 -
#    these don't have chain types marked:
#
# 	res	total affected
#
# 	CTHR	8
# 	NHID	8
#   )
#  (no restraints)
# 	Quit
#
# Exiting LEaP: Errors = 0; Warnings = 0; Notes = 0.
# Skipping 320: 6.9
# Now doing run 320: 6.95
# -I: Adding /cm/shared/package/amber/20_v2/dat/leap/prep to search path.
# -I: Adding /cm/shared/package/amber/20_v2/dat/leap/lib to search path.
# -I: Adding /cm/shared/package/amber/20_v2/dat/leap/parm to search path.
# -I: Adding /cm/shared/package/amber/20_v2/dat/leap/cmd to search path.
# -f: Source 6.95/resource/tleap_script.in.
#
# Welcome to LEaP!
# (no leaprc in search path)
# Sourcing: ./6.95/resource/tleap_script.in
# ----- Source: /cm/shared/package/amber/20_v2/dat/leap/cmd/leaprc.protein.ff19SB
# ----- Source of /cm/shared/package/amber/20_v2/dat/leap/cmd/leaprc.protein.ff19SB done
# Log file: ./leap.log
# Loading parameters: /cm/shared/package/amber/20_v2/dat/leap/parm/parm19.dat
# Reading title:
# PARM99 + frcmod.ff99SB + frcmod.parmbsc0 + OL3 for RNA + ff19SB
# Loading parameters: /cm/shared/package/amber/20_v2/dat/leap/parm/frcmod.ff19SB
# Reading force field modification type file (frcmod)
# Reading title:
# ff19SB AA-specific backbone CMAPs for protein 07/25/2019
# Loading library: /cm/shared/package/amber/20_v2/dat/leap/lib/amino19.lib
# Loading library: /cm/shared/package/amber/20_v2/dat/leap/lib/aminoct12.lib
# Loading library: /cm/shared/package/amber/20_v2/dat/leap/lib/aminont12.lib
# Loading PDB file: ./6.95/resource/6.95_cleaned.pdb
#   Added missing heavy atom: .R<CTHR 29>.A<OXT 15>
#   Added missing heavy atom: .R<CTHR 58>.A<OXT 15>
#   Added missing heavy atom: .R<CTHR 87>.A<OXT 15>
#   Added missing heavy atom: .R<CTHR 116>.A<OXT 15>
#   Added missing heavy atom: .R<CTHR 145>.A<OXT 15>
#   Added missing heavy atom: .R<CTHR 174>.A<OXT 15>
#   Added missing heavy atom: .R<CTHR 203>.A<OXT 15>
#   Added missing heavy atom: .R<CTHR 232>.A<OXT 15>
#   total atoms in file: 3744
#   Leap added 24 missing atoms according to residue templates:
#        8 Heavy
#        16 H / lone pairs
# Box dimensions:  34.029200 108.774000 129.520000
# Checking Unit.
# Building topology.
# Building atom parameters.
# Building bond parameters.
# Building angle parameters.
# Building proper torsion parameters.
# Building improper torsion parameters.
#  total 904 improper torsions applied
# Building H-Bond parameters.
# Incorporating Non-Bonded adjustments.
# Not Marking per-residue atom chain types.
# Marking per-residue atom chain types.
#   (Residues lacking connect0/connect1 -
#    these don't have chain types marked:
#
# 	res	total affected
#
# 	CTHR	8
# 	NHID	8
#   )
#  (no restraints)
# 	Quit
#
# Exiting LEaP: Errors = 0; Warnings = 0; Notes = 0.
# Skipping 320: 7.0

# %%
for temp in temps:
    os.chdir(str(temp))
             
    for dist in new_distances:
        command = f'sbatch -J {temp}-{dist} ../batch_window.sh -e -s {dist} -c {dist}/resource/{dist}_start.rst7 -t src/US_topol.parm7'
        print(command)
        
        # Uncomment only when ready to submit!
        # os.system(command)
             
    os.chdir(basepath)
# Out:
# sbatch -J 280-0.35 ../batch_window.sh -e -s 0.35 -c 0.35/resource/0.35_start.rst7 -t src/US_topol.parm7
# Submitted batch job 130938
# sbatch -J 280-0.45 ../batch_window.sh -e -s 0.45 -c 0.45/resource/0.45_start.rst7 -t src/US_topol.parm7
# Submitted batch job 130939
# sbatch -J 280-0.55 ../batch_window.sh -e -s 0.55 -c 0.55/resource/0.55_start.rst7 -t src/US_topol.parm7
# Submitted batch job 130940
# sbatch -J 280-0.65 ../batch_window.sh -e -s 0.65 -c 0.65/resource/0.65_start.rst7 -t src/US_topol.parm7
# Submitted batch job 130941
# sbatch -J 280-0.75 ../batch_window.sh -e -s 0.75 -c 0.75/resource/0.75_start.rst7 -t src/US_topol.parm7
# Submitted batch job 130942
# sbatch -J 280-0.85 ../batch_window.sh -e -s 0.85 -c 0.85/resource/0.85_start.rst7 -t src/US_topol.parm7
# Submitted batch job 130943
# sbatch -J 280-0.95 ../batch_window.sh -e -s 0.95 -c 0.95/resource/0.95_start.rst7 -t src/US_topol.parm7
# Submitted batch job 130944
# sbatch -J 280-1.05 ../batch_window.sh -e -s 1.05 -c 1.05/resource/1.05_start.rst7 -t src/US_topol.parm7
# Submitted batch job 130945
# sbatch -J 280-1.15 ../batch_window.sh -e -s 1.15 -c 1.15/resource/1.15_start.rst7 -t src/US_topol.parm7
# Submitted batch job 130946
# sbatch -J 280-1.25 ../batch_window.sh -e -s 1.25 -c 1.25/resource/1.25_start.rst7 -t src/US_topol.parm7
# Submitted batch job 130947
# sbatch -J 280-1.35 ../batch_window.sh -e -s 1.35 -c 1.35/resource/1.35_start.rst7 -t src/US_topol.parm7
# Submitted batch job 130948
# sbatch -J 280-1.45 ../batch_window.sh -e -s 1.45 -c 1.45/resource/1.45_start.rst7 -t src/US_topol.parm7
# Submitted batch job 130949
# sbatch -J 280-1.55 ../batch_window.sh -e -s 1.55 -c 1.55/resource/1.55_start.rst7 -t src/US_topol.parm7
# Submitted batch job 130950
# sbatch -J 280-1.65 ../batch_window.sh -e -s 1.65 -c 1.65/resource/1.65_start.rst7 -t src/US_topol.parm7
# Submitted batch job 130951
# sbatch -J 280-1.75 ../batch_window.sh -e -s 1.75 -c 1.75/resource/1.75_start.rst7 -t src/US_topol.parm7
# Submitted batch job 130952
# sbatch -J 280-1.85 ../batch_window.sh -e -s 1.85 -c 1.85/resource/1.85_start.rst7 -t src/US_topol.parm7
# Submitted batch job 130953
# sbatch -J 280-1.95 ../batch_window.sh -e -s 1.95 -c 1.95/resource/1.95_start.rst7 -t src/US_topol.parm7
# Submitted batch job 130954
# sbatch -J 280-2.05 ../batch_window.sh -e -s 2.05 -c 2.05/resource/2.05_start.rst7 -t src/US_topol.parm7
# Submitted batch job 130955
# sbatch -J 280-2.15 ../batch_window.sh -e -s 2.15 -c 2.15/resource/2.15_start.rst7 -t src/US_topol.parm7
# Submitted batch job 130956
# sbatch -J 280-2.25 ../batch_window.sh -e -s 2.25 -c 2.25/resource/2.25_start.rst7 -t src/US_topol.parm7
# Submitted batch job 130957
# sbatch -J 280-2.35 ../batch_window.sh -e -s 2.35 -c 2.35/resource/2.35_start.rst7 -t src/US_topol.parm7
# Submitted batch job 130958
# sbatch -J 280-2.45 ../batch_window.sh -e -s 2.45 -c 2.45/resource/2.45_start.rst7 -t src/US_topol.parm7
# Submitted batch job 130959
# sbatch -J 280-2.55 ../batch_window.sh -e -s 2.55 -c 2.55/resource/2.55_start.rst7 -t src/US_topol.parm7
# Submitted batch job 130960
# sbatch -J 280-2.65 ../batch_window.sh -e -s 2.65 -c 2.65/resource/2.65_start.rst7 -t src/US_topol.parm7
# Submitted batch job 130961
# sbatch -J 280-2.75 ../batch_window.sh -e -s 2.75 -c 2.75/resource/2.75_start.rst7 -t src/US_topol.parm7
# Submitted batch job 130962
# sbatch -J 280-2.85 ../batch_window.sh -e -s 2.85 -c 2.85/resource/2.85_start.rst7 -t src/US_topol.parm7
# Submitted batch job 130963
# sbatch -J 280-2.95 ../batch_window.sh -e -s 2.95 -c 2.95/resource/2.95_start.rst7 -t src/US_topol.parm7
# Submitted batch job 130964
# sbatch -J 280-3.05 ../batch_window.sh -e -s 3.05 -c 3.05/resource/3.05_start.rst7 -t src/US_topol.parm7
# Submitted batch job 130965
# sbatch -J 280-3.15 ../batch_window.sh -e -s 3.15 -c 3.15/resource/3.15_start.rst7 -t src/US_topol.parm7
# Submitted batch job 130966
# sbatch -J 280-3.25 ../batch_window.sh -e -s 3.25 -c 3.25/resource/3.25_start.rst7 -t src/US_topol.parm7
# Submitted batch job 130967
# sbatch -J 280-3.35 ../batch_window.sh -e -s 3.35 -c 3.35/resource/3.35_start.rst7 -t src/US_topol.parm7
# Submitted batch job 130968
# sbatch -J 280-3.45 ../batch_window.sh -e -s 3.45 -c 3.45/resource/3.45_start.rst7 -t src/US_topol.parm7
# Submitted batch job 130969
# sbatch -J 280-3.55 ../batch_window.sh -e -s 3.55 -c 3.55/resource/3.55_start.rst7 -t src/US_topol.parm7
# Submitted batch job 130970
# sbatch -J 280-3.65 ../batch_window.sh -e -s 3.65 -c 3.65/resource/3.65_start.rst7 -t src/US_topol.parm7
# Submitted batch job 130971
# sbatch -J 280-3.75 ../batch_window.sh -e -s 3.75 -c 3.75/resource/3.75_start.rst7 -t src/US_topol.parm7
# Submitted batch job 130972
# sbatch -J 280-3.85 ../batch_window.sh -e -s 3.85 -c 3.85/resource/3.85_start.rst7 -t src/US_topol.parm7
# Submitted batch job 130973
# sbatch -J 280-3.95 ../batch_window.sh -e -s 3.95 -c 3.95/resource/3.95_start.rst7 -t src/US_topol.parm7
# Submitted batch job 130974
# sbatch -J 280-4.05 ../batch_window.sh -e -s 4.05 -c 4.05/resource/4.05_start.rst7 -t src/US_topol.parm7
# Submitted batch job 130975
# sbatch -J 280-4.15 ../batch_window.sh -e -s 4.15 -c 4.15/resource/4.15_start.rst7 -t src/US_topol.parm7
# Submitted batch job 130976
# sbatch -J 280-4.25 ../batch_window.sh -e -s 4.25 -c 4.25/resource/4.25_start.rst7 -t src/US_topol.parm7
# Submitted batch job 130977
# sbatch -J 280-4.35 ../batch_window.sh -e -s 4.35 -c 4.35/resource/4.35_start.rst7 -t src/US_topol.parm7
# Submitted batch job 130978
# sbatch -J 280-4.45 ../batch_window.sh -e -s 4.45 -c 4.45/resource/4.45_start.rst7 -t src/US_topol.parm7
# Submitted batch job 130979
# sbatch -J 280-4.55 ../batch_window.sh -e -s 4.55 -c 4.55/resource/4.55_start.rst7 -t src/US_topol.parm7
# Submitted batch job 130980
# sbatch -J 280-4.65 ../batch_window.sh -e -s 4.65 -c 4.65/resource/4.65_start.rst7 -t src/US_topol.parm7
# Submitted batch job 130981
# sbatch -J 280-4.75 ../batch_window.sh -e -s 4.75 -c 4.75/resource/4.75_start.rst7 -t src/US_topol.parm7
# Submitted batch job 130982
# sbatch -J 280-4.85 ../batch_window.sh -e -s 4.85 -c 4.85/resource/4.85_start.rst7 -t src/US_topol.parm7
# Submitted batch job 130983
# sbatch -J 280-4.95 ../batch_window.sh -e -s 4.95 -c 4.95/resource/4.95_start.rst7 -t src/US_topol.parm7
# Submitted batch job 130984
# sbatch -J 280-5.05 ../batch_window.sh -e -s 5.05 -c 5.05/resource/5.05_start.rst7 -t src/US_topol.parm7
# Submitted batch job 130985
# sbatch -J 280-5.15 ../batch_window.sh -e -s 5.15 -c 5.15/resource/5.15_start.rst7 -t src/US_topol.parm7
# Submitted batch job 130986
# sbatch -J 280-5.25 ../batch_window.sh -e -s 5.25 -c 5.25/resource/5.25_start.rst7 -t src/US_topol.parm7
# Submitted batch job 130987
# sbatch -J 280-5.35 ../batch_window.sh -e -s 5.35 -c 5.35/resource/5.35_start.rst7 -t src/US_topol.parm7
# Submitted batch job 130988
# sbatch -J 280-5.45 ../batch_window.sh -e -s 5.45 -c 5.45/resource/5.45_start.rst7 -t src/US_topol.parm7
# Submitted batch job 130989
# sbatch -J 280-5.55 ../batch_window.sh -e -s 5.55 -c 5.55/resource/5.55_start.rst7 -t src/US_topol.parm7
# Submitted batch job 130990
# sbatch -J 280-5.65 ../batch_window.sh -e -s 5.65 -c 5.65/resource/5.65_start.rst7 -t src/US_topol.parm7
# Submitted batch job 130991
# sbatch -J 280-5.75 ../batch_window.sh -e -s 5.75 -c 5.75/resource/5.75_start.rst7 -t src/US_topol.parm7
# Submitted batch job 130992
# sbatch -J 280-5.85 ../batch_window.sh -e -s 5.85 -c 5.85/resource/5.85_start.rst7 -t src/US_topol.parm7
# Submitted batch job 130993
# sbatch -J 280-5.95 ../batch_window.sh -e -s 5.95 -c 5.95/resource/5.95_start.rst7 -t src/US_topol.parm7
# Submitted batch job 130994
# sbatch -J 280-6.05 ../batch_window.sh -e -s 6.05 -c 6.05/resource/6.05_start.rst7 -t src/US_topol.parm7
# Submitted batch job 130995
# sbatch -J 280-6.15 ../batch_window.sh -e -s 6.15 -c 6.15/resource/6.15_start.rst7 -t src/US_topol.parm7
# Submitted batch job 130996
# sbatch -J 280-6.25 ../batch_window.sh -e -s 6.25 -c 6.25/resource/6.25_start.rst7 -t src/US_topol.parm7
# Submitted batch job 130997
# sbatch -J 280-6.35 ../batch_window.sh -e -s 6.35 -c 6.35/resource/6.35_start.rst7 -t src/US_topol.parm7
# Submitted batch job 130998
# sbatch -J 280-6.45 ../batch_window.sh -e -s 6.45 -c 6.45/resource/6.45_start.rst7 -t src/US_topol.parm7
# Submitted batch job 130999
# sbatch -J 280-6.55 ../batch_window.sh -e -s 6.55 -c 6.55/resource/6.55_start.rst7 -t src/US_topol.parm7
# Submitted batch job 131000
# sbatch -J 280-6.65 ../batch_window.sh -e -s 6.65 -c 6.65/resource/6.65_start.rst7 -t src/US_topol.parm7
# Submitted batch job 131001
# sbatch -J 280-6.75 ../batch_window.sh -e -s 6.75 -c 6.75/resource/6.75_start.rst7 -t src/US_topol.parm7
# Submitted batch job 131002
# sbatch -J 280-6.85 ../batch_window.sh -e -s 6.85 -c 6.85/resource/6.85_start.rst7 -t src/US_topol.parm7
# Submitted batch job 131003
# sbatch -J 280-6.95 ../batch_window.sh -e -s 6.95 -c 6.95/resource/6.95_start.rst7 -t src/US_topol.parm7
# Submitted batch job 131004
# sbatch -J 300-0.35 ../batch_window.sh -e -s 0.35 -c 0.35/resource/0.35_start.rst7 -t src/US_topol.parm7
# Submitted batch job 131005
# sbatch -J 300-0.45 ../batch_window.sh -e -s 0.45 -c 0.45/resource/0.45_start.rst7 -t src/US_topol.parm7
# Submitted batch job 131006
# sbatch -J 300-0.55 ../batch_window.sh -e -s 0.55 -c 0.55/resource/0.55_start.rst7 -t src/US_topol.parm7
# Submitted batch job 131007
# sbatch -J 300-0.65 ../batch_window.sh -e -s 0.65 -c 0.65/resource/0.65_start.rst7 -t src/US_topol.parm7
# Submitted batch job 131008
# sbatch -J 300-0.75 ../batch_window.sh -e -s 0.75 -c 0.75/resource/0.75_start.rst7 -t src/US_topol.parm7
# Submitted batch job 131009
# sbatch -J 300-0.85 ../batch_window.sh -e -s 0.85 -c 0.85/resource/0.85_start.rst7 -t src/US_topol.parm7
# Submitted batch job 131010
# sbatch -J 300-0.95 ../batch_window.sh -e -s 0.95 -c 0.95/resource/0.95_start.rst7 -t src/US_topol.parm7
# Submitted batch job 131011
# sbatch -J 300-1.05 ../batch_window.sh -e -s 1.05 -c 1.05/resource/1.05_start.rst7 -t src/US_topol.parm7
# Submitted batch job 131012
# sbatch -J 300-1.15 ../batch_window.sh -e -s 1.15 -c 1.15/resource/1.15_start.rst7 -t src/US_topol.parm7
# Submitted batch job 131013
# sbatch -J 300-1.25 ../batch_window.sh -e -s 1.25 -c 1.25/resource/1.25_start.rst7 -t src/US_topol.parm7
# Submitted batch job 131014
# sbatch -J 300-1.35 ../batch_window.sh -e -s 1.35 -c 1.35/resource/1.35_start.rst7 -t src/US_topol.parm7
# Submitted batch job 131015
# sbatch -J 300-1.45 ../batch_window.sh -e -s 1.45 -c 1.45/resource/1.45_start.rst7 -t src/US_topol.parm7
# Submitted batch job 131016
# sbatch -J 300-1.55 ../batch_window.sh -e -s 1.55 -c 1.55/resource/1.55_start.rst7 -t src/US_topol.parm7
# Submitted batch job 131017
# sbatch -J 300-1.65 ../batch_window.sh -e -s 1.65 -c 1.65/resource/1.65_start.rst7 -t src/US_topol.parm7
# Submitted batch job 131018
# sbatch -J 300-1.75 ../batch_window.sh -e -s 1.75 -c 1.75/resource/1.75_start.rst7 -t src/US_topol.parm7
# Submitted batch job 131019
# sbatch -J 300-1.85 ../batch_window.sh -e -s 1.85 -c 1.85/resource/1.85_start.rst7 -t src/US_topol.parm7
# Submitted batch job 131020
# sbatch -J 300-1.95 ../batch_window.sh -e -s 1.95 -c 1.95/resource/1.95_start.rst7 -t src/US_topol.parm7
# Submitted batch job 131021
# sbatch -J 300-2.05 ../batch_window.sh -e -s 2.05 -c 2.05/resource/2.05_start.rst7 -t src/US_topol.parm7
# Submitted batch job 131022
# sbatch -J 300-2.15 ../batch_window.sh -e -s 2.15 -c 2.15/resource/2.15_start.rst7 -t src/US_topol.parm7
# Submitted batch job 131023
# sbatch -J 300-2.25 ../batch_window.sh -e -s 2.25 -c 2.25/resource/2.25_start.rst7 -t src/US_topol.parm7
# Submitted batch job 131024
# sbatch -J 300-2.35 ../batch_window.sh -e -s 2.35 -c 2.35/resource/2.35_start.rst7 -t src/US_topol.parm7
# Submitted batch job 131025
# sbatch -J 300-2.45 ../batch_window.sh -e -s 2.45 -c 2.45/resource/2.45_start.rst7 -t src/US_topol.parm7
# Submitted batch job 131026
# sbatch -J 300-2.55 ../batch_window.sh -e -s 2.55 -c 2.55/resource/2.55_start.rst7 -t src/US_topol.parm7
# Submitted batch job 131027
# sbatch -J 300-2.65 ../batch_window.sh -e -s 2.65 -c 2.65/resource/2.65_start.rst7 -t src/US_topol.parm7
# Submitted batch job 131028
# sbatch -J 300-2.75 ../batch_window.sh -e -s 2.75 -c 2.75/resource/2.75_start.rst7 -t src/US_topol.parm7
# Submitted batch job 131029
# sbatch -J 300-2.85 ../batch_window.sh -e -s 2.85 -c 2.85/resource/2.85_start.rst7 -t src/US_topol.parm7
# Submitted batch job 131030
# sbatch -J 300-2.95 ../batch_window.sh -e -s 2.95 -c 2.95/resource/2.95_start.rst7 -t src/US_topol.parm7
# Submitted batch job 131031
# sbatch -J 300-3.05 ../batch_window.sh -e -s 3.05 -c 3.05/resource/3.05_start.rst7 -t src/US_topol.parm7
# Submitted batch job 131032
# sbatch -J 300-3.15 ../batch_window.sh -e -s 3.15 -c 3.15/resource/3.15_start.rst7 -t src/US_topol.parm7
# Submitted batch job 131033
# sbatch -J 300-3.25 ../batch_window.sh -e -s 3.25 -c 3.25/resource/3.25_start.rst7 -t src/US_topol.parm7
# Submitted batch job 131034
# sbatch -J 300-3.35 ../batch_window.sh -e -s 3.35 -c 3.35/resource/3.35_start.rst7 -t src/US_topol.parm7
# Submitted batch job 131035
# sbatch -J 300-3.45 ../batch_window.sh -e -s 3.45 -c 3.45/resource/3.45_start.rst7 -t src/US_topol.parm7
# Submitted batch job 131036
# sbatch -J 300-3.55 ../batch_window.sh -e -s 3.55 -c 3.55/resource/3.55_start.rst7 -t src/US_topol.parm7
# Submitted batch job 131037
# sbatch -J 300-3.65 ../batch_window.sh -e -s 3.65 -c 3.65/resource/3.65_start.rst7 -t src/US_topol.parm7
# Submitted batch job 131038
# sbatch -J 300-3.75 ../batch_window.sh -e -s 3.75 -c 3.75/resource/3.75_start.rst7 -t src/US_topol.parm7
# Submitted batch job 131039
# sbatch -J 300-3.85 ../batch_window.sh -e -s 3.85 -c 3.85/resource/3.85_start.rst7 -t src/US_topol.parm7
# Submitted batch job 131040
# sbatch -J 300-3.95 ../batch_window.sh -e -s 3.95 -c 3.95/resource/3.95_start.rst7 -t src/US_topol.parm7
# Submitted batch job 131041
# sbatch -J 300-4.05 ../batch_window.sh -e -s 4.05 -c 4.05/resource/4.05_start.rst7 -t src/US_topol.parm7
# Submitted batch job 131042
# sbatch -J 300-4.15 ../batch_window.sh -e -s 4.15 -c 4.15/resource/4.15_start.rst7 -t src/US_topol.parm7
# Submitted batch job 131043
# sbatch -J 300-4.25 ../batch_window.sh -e -s 4.25 -c 4.25/resource/4.25_start.rst7 -t src/US_topol.parm7
# Submitted batch job 131044
# sbatch -J 300-4.35 ../batch_window.sh -e -s 4.35 -c 4.35/resource/4.35_start.rst7 -t src/US_topol.parm7
# Submitted batch job 131045
# sbatch -J 300-4.45 ../batch_window.sh -e -s 4.45 -c 4.45/resource/4.45_start.rst7 -t src/US_topol.parm7
# Submitted batch job 131046
# sbatch -J 300-4.55 ../batch_window.sh -e -s 4.55 -c 4.55/resource/4.55_start.rst7 -t src/US_topol.parm7
# Submitted batch job 131047
# sbatch -J 300-4.65 ../batch_window.sh -e -s 4.65 -c 4.65/resource/4.65_start.rst7 -t src/US_topol.parm7
# Submitted batch job 131048
# sbatch -J 300-4.75 ../batch_window.sh -e -s 4.75 -c 4.75/resource/4.75_start.rst7 -t src/US_topol.parm7
# Submitted batch job 131049
# sbatch -J 300-4.85 ../batch_window.sh -e -s 4.85 -c 4.85/resource/4.85_start.rst7 -t src/US_topol.parm7
# Submitted batch job 131050
# sbatch -J 300-4.95 ../batch_window.sh -e -s 4.95 -c 4.95/resource/4.95_start.rst7 -t src/US_topol.parm7
# Submitted batch job 131051
# sbatch -J 300-5.05 ../batch_window.sh -e -s 5.05 -c 5.05/resource/5.05_start.rst7 -t src/US_topol.parm7
# Submitted batch job 131052
# sbatch -J 300-5.15 ../batch_window.sh -e -s 5.15 -c 5.15/resource/5.15_start.rst7 -t src/US_topol.parm7
# Submitted batch job 131053
# sbatch -J 300-5.25 ../batch_window.sh -e -s 5.25 -c 5.25/resource/5.25_start.rst7 -t src/US_topol.parm7
# Submitted batch job 131054
# sbatch -J 300-5.35 ../batch_window.sh -e -s 5.35 -c 5.35/resource/5.35_start.rst7 -t src/US_topol.parm7
# Submitted batch job 131055
# sbatch -J 300-5.45 ../batch_window.sh -e -s 5.45 -c 5.45/resource/5.45_start.rst7 -t src/US_topol.parm7
# Submitted batch job 131056
# sbatch -J 300-5.55 ../batch_window.sh -e -s 5.55 -c 5.55/resource/5.55_start.rst7 -t src/US_topol.parm7
# Submitted batch job 131057
# sbatch -J 300-5.65 ../batch_window.sh -e -s 5.65 -c 5.65/resource/5.65_start.rst7 -t src/US_topol.parm7
# Submitted batch job 131058
# sbatch -J 300-5.75 ../batch_window.sh -e -s 5.75 -c 5.75/resource/5.75_start.rst7 -t src/US_topol.parm7
# Submitted batch job 131059
# sbatch -J 300-5.85 ../batch_window.sh -e -s 5.85 -c 5.85/resource/5.85_start.rst7 -t src/US_topol.parm7
# Submitted batch job 131060
# sbatch -J 300-5.95 ../batch_window.sh -e -s 5.95 -c 5.95/resource/5.95_start.rst7 -t src/US_topol.parm7
# Submitted batch job 131061
# sbatch -J 300-6.05 ../batch_window.sh -e -s 6.05 -c 6.05/resource/6.05_start.rst7 -t src/US_topol.parm7
# Submitted batch job 131062
# sbatch -J 300-6.15 ../batch_window.sh -e -s 6.15 -c 6.15/resource/6.15_start.rst7 -t src/US_topol.parm7
# Submitted batch job 131063
# sbatch -J 300-6.25 ../batch_window.sh -e -s 6.25 -c 6.25/resource/6.25_start.rst7 -t src/US_topol.parm7
# Submitted batch job 131064
# sbatch -J 300-6.35 ../batch_window.sh -e -s 6.35 -c 6.35/resource/6.35_start.rst7 -t src/US_topol.parm7
# Submitted batch job 131065
# sbatch -J 300-6.45 ../batch_window.sh -e -s 6.45 -c 6.45/resource/6.45_start.rst7 -t src/US_topol.parm7
# Submitted batch job 131066
# sbatch -J 300-6.55 ../batch_window.sh -e -s 6.55 -c 6.55/resource/6.55_start.rst7 -t src/US_topol.parm7
# Submitted batch job 131067
# sbatch -J 300-6.65 ../batch_window.sh -e -s 6.65 -c 6.65/resource/6.65_start.rst7 -t src/US_topol.parm7
# Submitted batch job 131068
# sbatch -J 300-6.75 ../batch_window.sh -e -s 6.75 -c 6.75/resource/6.75_start.rst7 -t src/US_topol.parm7
# Submitted batch job 131069
# sbatch -J 300-6.85 ../batch_window.sh -e -s 6.85 -c 6.85/resource/6.85_start.rst7 -t src/US_topol.parm7
# Submitted batch job 131070
# sbatch -J 300-6.95 ../batch_window.sh -e -s 6.95 -c 6.95/resource/6.95_start.rst7 -t src/US_topol.parm7
# Submitted batch job 131071
# sbatch -J 320-0.35 ../batch_window.sh -e -s 0.35 -c 0.35/resource/0.35_start.rst7 -t src/US_topol.parm7
# Submitted batch job 131072
# sbatch -J 320-0.45 ../batch_window.sh -e -s 0.45 -c 0.45/resource/0.45_start.rst7 -t src/US_topol.parm7
# Submitted batch job 131073
# sbatch -J 320-0.55 ../batch_window.sh -e -s 0.55 -c 0.55/resource/0.55_start.rst7 -t src/US_topol.parm7
# Submitted batch job 131074
# sbatch -J 320-0.65 ../batch_window.sh -e -s 0.65 -c 0.65/resource/0.65_start.rst7 -t src/US_topol.parm7
# Submitted batch job 131075
# sbatch -J 320-0.75 ../batch_window.sh -e -s 0.75 -c 0.75/resource/0.75_start.rst7 -t src/US_topol.parm7
# Submitted batch job 131076
# sbatch -J 320-0.85 ../batch_window.sh -e -s 0.85 -c 0.85/resource/0.85_start.rst7 -t src/US_topol.parm7
# Submitted batch job 131077
# sbatch -J 320-0.95 ../batch_window.sh -e -s 0.95 -c 0.95/resource/0.95_start.rst7 -t src/US_topol.parm7
# Submitted batch job 131078
# sbatch -J 320-1.05 ../batch_window.sh -e -s 1.05 -c 1.05/resource/1.05_start.rst7 -t src/US_topol.parm7
# Submitted batch job 131079
# sbatch -J 320-1.15 ../batch_window.sh -e -s 1.15 -c 1.15/resource/1.15_start.rst7 -t src/US_topol.parm7
# Submitted batch job 131080
# sbatch -J 320-1.25 ../batch_window.sh -e -s 1.25 -c 1.25/resource/1.25_start.rst7 -t src/US_topol.parm7
# Submitted batch job 131081
# sbatch -J 320-1.35 ../batch_window.sh -e -s 1.35 -c 1.35/resource/1.35_start.rst7 -t src/US_topol.parm7
# Submitted batch job 131082
# sbatch -J 320-1.45 ../batch_window.sh -e -s 1.45 -c 1.45/resource/1.45_start.rst7 -t src/US_topol.parm7
# Submitted batch job 131083
# sbatch -J 320-1.55 ../batch_window.sh -e -s 1.55 -c 1.55/resource/1.55_start.rst7 -t src/US_topol.parm7
# Submitted batch job 131084
# sbatch -J 320-1.65 ../batch_window.sh -e -s 1.65 -c 1.65/resource/1.65_start.rst7 -t src/US_topol.parm7
# Submitted batch job 131085
# sbatch -J 320-1.75 ../batch_window.sh -e -s 1.75 -c 1.75/resource/1.75_start.rst7 -t src/US_topol.parm7
# Submitted batch job 131086
# sbatch -J 320-1.85 ../batch_window.sh -e -s 1.85 -c 1.85/resource/1.85_start.rst7 -t src/US_topol.parm7
# Submitted batch job 131087
# sbatch -J 320-1.95 ../batch_window.sh -e -s 1.95 -c 1.95/resource/1.95_start.rst7 -t src/US_topol.parm7
# Submitted batch job 131088
# sbatch -J 320-2.05 ../batch_window.sh -e -s 2.05 -c 2.05/resource/2.05_start.rst7 -t src/US_topol.parm7
# Submitted batch job 131089
# sbatch -J 320-2.15 ../batch_window.sh -e -s 2.15 -c 2.15/resource/2.15_start.rst7 -t src/US_topol.parm7
# Submitted batch job 131090
# sbatch -J 320-2.25 ../batch_window.sh -e -s 2.25 -c 2.25/resource/2.25_start.rst7 -t src/US_topol.parm7
# Submitted batch job 131091
# sbatch -J 320-2.35 ../batch_window.sh -e -s 2.35 -c 2.35/resource/2.35_start.rst7 -t src/US_topol.parm7
# Submitted batch job 131092
# sbatch -J 320-2.45 ../batch_window.sh -e -s 2.45 -c 2.45/resource/2.45_start.rst7 -t src/US_topol.parm7
# Submitted batch job 131093
# sbatch -J 320-2.55 ../batch_window.sh -e -s 2.55 -c 2.55/resource/2.55_start.rst7 -t src/US_topol.parm7
# Submitted batch job 131094
# sbatch -J 320-2.65 ../batch_window.sh -e -s 2.65 -c 2.65/resource/2.65_start.rst7 -t src/US_topol.parm7
# Submitted batch job 131095
# sbatch -J 320-2.75 ../batch_window.sh -e -s 2.75 -c 2.75/resource/2.75_start.rst7 -t src/US_topol.parm7
# Submitted batch job 131096
# sbatch -J 320-2.85 ../batch_window.sh -e -s 2.85 -c 2.85/resource/2.85_start.rst7 -t src/US_topol.parm7
# Submitted batch job 131097
# sbatch -J 320-2.95 ../batch_window.sh -e -s 2.95 -c 2.95/resource/2.95_start.rst7 -t src/US_topol.parm7
# Submitted batch job 131098
# sbatch -J 320-3.05 ../batch_window.sh -e -s 3.05 -c 3.05/resource/3.05_start.rst7 -t src/US_topol.parm7
# Submitted batch job 131099
# sbatch -J 320-3.15 ../batch_window.sh -e -s 3.15 -c 3.15/resource/3.15_start.rst7 -t src/US_topol.parm7
# Submitted batch job 131100
# sbatch -J 320-3.25 ../batch_window.sh -e -s 3.25 -c 3.25/resource/3.25_start.rst7 -t src/US_topol.parm7
# Submitted batch job 131101
# sbatch -J 320-3.35 ../batch_window.sh -e -s 3.35 -c 3.35/resource/3.35_start.rst7 -t src/US_topol.parm7
# Submitted batch job 131102
# sbatch -J 320-3.45 ../batch_window.sh -e -s 3.45 -c 3.45/resource/3.45_start.rst7 -t src/US_topol.parm7
# Submitted batch job 131103
# sbatch -J 320-3.55 ../batch_window.sh -e -s 3.55 -c 3.55/resource/3.55_start.rst7 -t src/US_topol.parm7
# Submitted batch job 131104
# sbatch -J 320-3.65 ../batch_window.sh -e -s 3.65 -c 3.65/resource/3.65_start.rst7 -t src/US_topol.parm7
# Submitted batch job 131105
# sbatch -J 320-3.75 ../batch_window.sh -e -s 3.75 -c 3.75/resource/3.75_start.rst7 -t src/US_topol.parm7
# Submitted batch job 131106
# sbatch -J 320-3.85 ../batch_window.sh -e -s 3.85 -c 3.85/resource/3.85_start.rst7 -t src/US_topol.parm7
# Submitted batch job 131107
# sbatch -J 320-3.95 ../batch_window.sh -e -s 3.95 -c 3.95/resource/3.95_start.rst7 -t src/US_topol.parm7
# Submitted batch job 131108
# sbatch -J 320-4.05 ../batch_window.sh -e -s 4.05 -c 4.05/resource/4.05_start.rst7 -t src/US_topol.parm7
# Submitted batch job 131109
# sbatch -J 320-4.15 ../batch_window.sh -e -s 4.15 -c 4.15/resource/4.15_start.rst7 -t src/US_topol.parm7
# Submitted batch job 131110
# sbatch -J 320-4.25 ../batch_window.sh -e -s 4.25 -c 4.25/resource/4.25_start.rst7 -t src/US_topol.parm7
# Submitted batch job 131111
# sbatch -J 320-4.35 ../batch_window.sh -e -s 4.35 -c 4.35/resource/4.35_start.rst7 -t src/US_topol.parm7
# Submitted batch job 131112
# sbatch -J 320-4.45 ../batch_window.sh -e -s 4.45 -c 4.45/resource/4.45_start.rst7 -t src/US_topol.parm7
# Submitted batch job 131113
# sbatch -J 320-4.55 ../batch_window.sh -e -s 4.55 -c 4.55/resource/4.55_start.rst7 -t src/US_topol.parm7
# Submitted batch job 131114
# sbatch -J 320-4.65 ../batch_window.sh -e -s 4.65 -c 4.65/resource/4.65_start.rst7 -t src/US_topol.parm7
# Submitted batch job 131115
# sbatch -J 320-4.75 ../batch_window.sh -e -s 4.75 -c 4.75/resource/4.75_start.rst7 -t src/US_topol.parm7
# Submitted batch job 131116
# sbatch -J 320-4.85 ../batch_window.sh -e -s 4.85 -c 4.85/resource/4.85_start.rst7 -t src/US_topol.parm7
# Submitted batch job 131117
# sbatch -J 320-4.95 ../batch_window.sh -e -s 4.95 -c 4.95/resource/4.95_start.rst7 -t src/US_topol.parm7
# Submitted batch job 131118
# sbatch -J 320-5.05 ../batch_window.sh -e -s 5.05 -c 5.05/resource/5.05_start.rst7 -t src/US_topol.parm7
# Submitted batch job 131119
# sbatch -J 320-5.15 ../batch_window.sh -e -s 5.15 -c 5.15/resource/5.15_start.rst7 -t src/US_topol.parm7
# Submitted batch job 131120
# sbatch -J 320-5.25 ../batch_window.sh -e -s 5.25 -c 5.25/resource/5.25_start.rst7 -t src/US_topol.parm7
# Submitted batch job 131121
# sbatch -J 320-5.35 ../batch_window.sh -e -s 5.35 -c 5.35/resource/5.35_start.rst7 -t src/US_topol.parm7
# Submitted batch job 131122
# sbatch -J 320-5.45 ../batch_window.sh -e -s 5.45 -c 5.45/resource/5.45_start.rst7 -t src/US_topol.parm7
# Submitted batch job 131123
# sbatch -J 320-5.55 ../batch_window.sh -e -s 5.55 -c 5.55/resource/5.55_start.rst7 -t src/US_topol.parm7
# Submitted batch job 131124
# sbatch -J 320-5.65 ../batch_window.sh -e -s 5.65 -c 5.65/resource/5.65_start.rst7 -t src/US_topol.parm7
# Submitted batch job 131125
# sbatch -J 320-5.75 ../batch_window.sh -e -s 5.75 -c 5.75/resource/5.75_start.rst7 -t src/US_topol.parm7
# Submitted batch job 131126
# sbatch -J 320-5.85 ../batch_window.sh -e -s 5.85 -c 5.85/resource/5.85_start.rst7 -t src/US_topol.parm7
# Submitted batch job 131127
# sbatch -J 320-5.95 ../batch_window.sh -e -s 5.95 -c 5.95/resource/5.95_start.rst7 -t src/US_topol.parm7
# Submitted batch job 131128
# sbatch -J 320-6.05 ../batch_window.sh -e -s 6.05 -c 6.05/resource/6.05_start.rst7 -t src/US_topol.parm7
# Submitted batch job 131129
# sbatch -J 320-6.15 ../batch_window.sh -e -s 6.15 -c 6.15/resource/6.15_start.rst7 -t src/US_topol.parm7
# Submitted batch job 131130
# sbatch -J 320-6.25 ../batch_window.sh -e -s 6.25 -c 6.25/resource/6.25_start.rst7 -t src/US_topol.parm7
# Submitted batch job 131131
# sbatch -J 320-6.35 ../batch_window.sh -e -s 6.35 -c 6.35/resource/6.35_start.rst7 -t src/US_topol.parm7
# Submitted batch job 131132
# sbatch -J 320-6.45 ../batch_window.sh -e -s 6.45 -c 6.45/resource/6.45_start.rst7 -t src/US_topol.parm7
# Submitted batch job 131133
# sbatch -J 320-6.55 ../batch_window.sh -e -s 6.55 -c 6.55/resource/6.55_start.rst7 -t src/US_topol.parm7
# Submitted batch job 131134
# sbatch -J 320-6.65 ../batch_window.sh -e -s 6.65 -c 6.65/resource/6.65_start.rst7 -t src/US_topol.parm7
# Submitted batch job 131135
# sbatch -J 320-6.75 ../batch_window.sh -e -s 6.75 -c 6.75/resource/6.75_start.rst7 -t src/US_topol.parm7
# Submitted batch job 131136
# sbatch -J 320-6.85 ../batch_window.sh -e -s 6.85 -c 6.85/resource/6.85_start.rst7 -t src/US_topol.parm7
# Submitted batch job 131137
# sbatch -J 320-6.95 ../batch_window.sh -e -s 6.95 -c 6.95/resource/6.95_start.rst7 -t src/US_topol.parm7
# Submitted batch job 131138
