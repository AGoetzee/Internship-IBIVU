# %%
import numpy as np
import pandas as pd

def colvar_to_df(f):
    colnames=f.readline().strip('#! FIELDS ').split()
    return pd.read_table(f,skiprows=0,header=None,sep=' ',names=colnames).set_index(colnames[0])

# %%
with open('par-restr-rmsd-2\COLVAR_par-restr-rmsd-2','r') as f:
    df = colvar_to_df(f)
df.head()
# Out:
#             c1       c27    combine        d1        d2        d3        d4  \
# time
# 0.0   2.204118  2.538120 -11.300191  9.762466  3.210508  3.042146  2.965473
# 0.2   2.094090  2.560974 -10.943798  9.757474  3.279232  3.033915  2.922847
# 0.4   2.148493  2.544480 -11.090401  9.721391  3.428135  3.099427  2.950251
# 0.6   2.208585  2.530998 -11.283797  9.811573  3.519137  3.198878  2.903110
# 0.8   2.167192  2.541239 -11.154614  9.793604  3.553208  3.280368  2.861970
#
#             d5        d6        d7  ...       c21       c22       c23  \
# time                                ...
# 0.0   2.742020  2.884546  2.684792  ...  2.372461  2.078497  2.555285
# 0.2   2.733456  2.873194  2.705987  ...  2.339501  2.029284  2.548127
# 0.4   2.704195  2.858581  2.731361  ...  2.357397  2.078920  2.560770
# 0.6   2.775799  2.846927  2.753314  ...  2.395250  2.042970  2.528773
# 0.8   2.813697  2.780082  2.746032  ...  2.401140  2.056697  2.490985
#
# ...

# %%
df[['c1','c27']].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df[['c1','c27','t1']].plot(alpha=0.5)
# Out:
# <AxesSubplot:xlabel='time'>

# %%
df['t1'].plot.hist(bins=50)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df['restraint.bias'].plot()
# Out:
# <AxesSubplot:xlabel='time'>

# %%
df[['combine','c1','c27']].plot(alpha=0.5)
# Out:
# <AxesSubplot:xlabel='time'>

# %% [markdown]
# # Par-params

# %%
with open('par-params\\COLVAR_par-params','r') as f:
    df = colvar_to_df(f)
df[['c1','c27','t1']].plot(alpha=0.5)
# Out:
# <AxesSubplot:xlabel='time'>

# %% [markdown]
# ## Using UWALL

# %%
with open('par-uwall\\COLVAR_par-uwall','r') as f:
    df = colvar_to_df(f)
df[['combine','t1']].plot(alpha=0.5)
# Out:
# <AxesSubplot:xlabel='time'>

# %%
df['restraint.bias'].plot()
# Out:
# <AxesSubplot:xlabel='time'>

# %%
df[df['combine']<0.1][['combine','c1','c27']]
# Out:
#           combine        c1       c27
# time
# 18.8     0.083276  0.953727  1.173365
# 19.0     0.061629  0.981750  1.091051
# 19.2     0.055526  0.997154  1.053817
# 19.4     0.034951  1.057537  1.017841
# 19.6     0.023481  1.130942  0.973087
# ...           ...       ...       ...
# 76533.8  0.000302  1.240194  1.104061
# 76534.0  0.006115  1.182828  1.152371
# 76534.2  0.003179  1.186536  1.125909
# 76534.4  0.001634  1.189773  1.093933
# 76534.6  0.014598  1.110230  1.074083
#
# [57023 rows x 3 columns]

# %%
df[['t1','combine']].plot.hist(bins=50,alpha=0.8)
# Out:
# <AxesSubplot:ylabel='Frequency'>
