# %%
import plotly.graph_objects as go
import numpy as np

# %%
x = np.linspace(0, 4, 100)
y = np.linspace(0, 4, 100)
xGrid, yGrid = np.meshgrid(y, x)
a=1
b=2
z = (xGrid - 1.23)**2 + (yGrid -1.09)**2

fig = go.Figure(data=[go.Surface(x=xGrid,y=yGrid,z=z)])
fig.show()

# %%
u,i,c = np.unique(z.round(decimals=2),return_counts=True,return_index=True)
print((c>1).sum())
# u[c>1]
# Out:
# 353
